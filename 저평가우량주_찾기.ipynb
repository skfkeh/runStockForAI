# %% [markdown]
# <a href="https://colab.research.google.com/github/skfkeh/runStockForAI/blob/main/%EC%A0%80%ED%8F%89%EA%B0%80%EC%9A%B0%EB%9F%89%EC%A3%BC_%EC%B0%BE%EA%B8%B0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## 사용방법
# 1. 분석하길 원하는 패턴을 선택한다.<br>
#   (1: 코스피/코스닥 전체, 2: 특정 종목만(엑셀 필요), 3: 테마별)
# 2. 패턴 선택
#   *   패턴 1 선택 시, 아래 셀에서 '1'로 넣는다.
#   *   패턴 2 선택 시, 아래 셀에서 '2'로 넣고 종목을 엑셀파일로 만들어 놓는다.
#   <br>양식은 다음과 같음.<br>
#    ![예시 스크린샷.png](data:image/png;base64,...)
#   *   패턴 3 선택 시, 아래 셀에서 '3'로 넣는다. -> 준비 중
# 2. 좌측탭 메뉴의 "폴더" 아이콘을 클릭하여, 만들어둔 엑셀파일을 업로드한다.
# 3. 업로드한 파일의 경로(path)를 복사하여, 아래 셀에 붙여넣는다.
# 4. 경로를 붙여넣었다면 상단 메뉴탭에 잇는 "모두 실행"을 눌러 전체 실행을 한다.

# %%
#### 원하는 패턴을 ▼ 여기에 숫자로 입력해주세요!!!
pattern =       1
##### 입력한 엑셀파일의 경로를 여기 ▼▼▼ 작은따옴표('') 안에 넣어주세요!!!
filePath = '/content/자동화댕 돌리기.xlsx'

# %%
####################
## 0.선언부        ##
####################
## dart 정보 가져오기
## 참고 사이트
## https://dart-fss.readthedocs.io/en/latest/dart_api.html
import pandas as pd
import requests
from bs4 import BeautifulSoup
import re
import math
import time

start = time.time() ## 시작시점

# !pip install dart-fss --quiet

## 하이퍼링크 추가용
# !pip install XlsxWriter --quiet

import dart_fss as dart
from datetime import datetime
from dateutil.relativedelta import relativedelta

# %%
####################
## 1.조회 종목 설정  ##
####################

## html 태그 제거하는 function
def cleanhtml(raw_html):
  cleanr = re.compile('<.*?>')
  cleantext = re.sub(cleanr, '', raw_html).replace('[','').replace(']','').replace(',','')
  return cleantext

## excel file 읽어오는 function
def read_excel(file_path):
    # excel 파일을 읽어 조회대상 기업을 리스트화
    df = pd.read_excel(file_path, header=None)
    # print(df.head())
    return df.iloc[:, 0]

def getStockListFromNaver():
    headers = {'User-Agent': 'Mozilla/5.0'}

    stock_list = []

    for stockInfo in range(2):
      if   stockInfo == 0: print(' $$$ 코스피 조회 시작 $$$ ')
      elif stockInfo == 1: print(' @@@ 코스닥 조회 시작 @@@ ')
#######
#######   코스닥 확인 필요 / ex, 16페이지, 참좋은여행 or 옵투스제약 등 안나옴
#######
      for page in range(1,50):
        URL = f'https://finance.naver.com/sise/sise_market_sum.naver?sosok={stockInfo}&page={page}'
        response = requests.get(URL, headers=headers)
        soup = BeautifulSoup(response.text, 'html.parser')

        ### 페이지 시작 및 확인
        pageChk = 0
        if (page%10) == 0: print('')
        print('page[' + str(page) + ']', end=" \t ")

        for i in range(2, 80):
          stockName = soup.select(f'#contentarea > div.box_type_l > table.type_2 > tbody > tr:nth-child({i}) > td:nth-child(2) > a')
          stockName = cleanhtml(str(stockName))
          stockTotalPrise = soup.select(f'#contentarea > div.box_type_l > table.type_2 > tbody > tr:nth-child({i}) > td:nth-child(7)')
          stockTotalPrise = cleanhtml(str(stockTotalPrise))

          if (stockName != '') or (stockTotalPrise != ''):
            ### 조회 중
            pageChk += 1
            # print(f'{stockName}: {stockTotalPrise} $$ {pageChk}')

            ### 시가총액 100~1100억 사이만 가져오면
            if (int(stockTotalPrise) >= 100) and (int(stockTotalPrise) <= 1100):
              stock_list.append(stockName) #(, stockTotalPrise)) # 시가총액까지 담는건 불필요

        ## 조회하는게 없으면 종료
        if pageChk == 0:
          if   stockInfo == 0: print('\n $$$ 코스피 조회 종료 $$$ ')
          elif stockInfo == 1: print('\n @@@ 코스닥 조회 종료 @@@ ')
          break

    return stock_list

# %%
corp_list = []
if pattern == 1:
  corp_list = getStockListFromNaver()
# Out:
#  $$$ 코스피 조회 시작 $$$
# page[1] 	 page[2] 	 page[3] 	 page[4] 	 page[5] 	 page[6] 	 page[7] 	 page[8] 	 page[9]
# page[10] 	 page[11] 	 page[12] 	 page[13] 	 page[14] 	 page[15] 	 page[16] 	 page[17] 	 page[18] 	 page[19]
# page[20] 	 page[21] 	 page[22] 	 page[23] 	 page[24] 	 page[25] 	 page[26] 	 page[27] 	 page[28] 	 page[29]
# page[30] 	 page[31] 	 page[32] 	 page[33] 	 page[34] 	 page[35] 	 page[36] 	 page[37] 	 page[38] 	 page[39]
# page[40] 	 page[41] 	 page[42] 	 page[43] 	 page[44] 	 page[45] 	 page[46] 	 page[47] 	 page[48] 	 page[49]
#  $$$ 코스피 조회 종료 $$$
#  @@@ 코스닥 조회 시작 @@@
# page[1] 	 page[2] 	 page[3] 	 page[4] 	 page[5] 	 page[6] 	 page[7] 	 page[8] 	 page[9]
# page[10] 	 page[11] 	 page[12] 	 page[13] 	 page[14] 	 page[15] 	 page[16] 	 page[17] 	 page[18] 	 page[19]
# page[20] 	 page[21] 	 page[22] 	 page[23] 	 page[24] 	 page[25] 	 page[26] 	 page[27] 	 page[28] 	 page[29]
# page[30] 	 page[31] 	 page[32] 	 page[33] 	 page[34] 	 page[35] 	 page[36] 	 page[37] 	 page[38]
#  @@@ 코스닥 조회 종료 @@@

# %%
corp_list = []
if pattern == 1:
  corp_list = getStockListFromNaver()
elif pattern == 2:
  corp_list = read_excel(filePath)

print('조회 종목 수 : ' + str(len(corp_list)))
# Out:
#  $$$ 코스피 조회 시작 $$$
# page[1] 	 page[2] 	 page[3] 	 page[4] 	 page[5] 	 page[6] 	 page[7] 	 page[8] 	 page[9]
# page[10] 	 page[11] 	 page[12] 	 page[13] 	 page[14] 	 page[15] 	 page[16] 	 page[17] 	 page[18] 	 page[19]
# page[20] 	 page[21] 	 page[22] 	 page[23] 	 page[24] 	 page[25] 	 page[26] 	 page[27] 	 page[28] 	 page[29]
# page[30] 	 page[31] 	 page[32] 	 page[33] 	 page[34] 	 page[35] 	 page[36] 	 page[37] 	 page[38] 	 page[39]
# page[40] 	 page[41] 	 page[42] 	 page[43] 	 page[44] 	 page[45] 	 page[46] 	 page[47] 	 page[48] 	 page[49]
#  $$$ 코스피 조회 종료 $$$
#  @@@ 코스닥 조회 시작 @@@
# page[1] 	 page[2] 	 page[3] 	 page[4] 	 page[5] 	 page[6] 	 page[7] 	 page[8] 	 page[9]
# page[10] 	 page[11] 	 page[12] 	 page[13] 	 page[14] 	 page[15] 	 page[16] 	 page[17] 	 page[18] 	 page[19]
# page[20] 	 page[21] 	 page[22] 	 page[23] 	 page[24] 	 page[25] 	 page[26] 	 page[27] 	 page[28] 	 page[29]
# page[30] 	 page[31] 	 page[32] 	 page[33] 	 page[34] 	 page[35] 	 page[36] 	 page[37] 	 page[38]
#  @@@ 코스닥 조회 종료 @@@
# 조회 종목 수 : 2075

# %%
#######################
## 2.dart 정보 조회하기 ##
#######################

# API 키 설정 (개발자 포털에서 발급받은 키로 교체)
api_key = '34862215a48286de874cbf0fee6ffbbecb793b24'
dart.set_api_key(api_key=api_key)

def check_capital_changes(start_date: str, end_date: str, corp_codes: list = None):
    """
    유상증자/무상감자 공시 확인 함수
    :param start_date: 검색 시작일 (YYYYMMDD)
    :param end_date: 검색 종료일 (YYYYMMDD)
    :param corp_codes: 특정 기업 검색시 사용(8자리 corp_code 리스트)
    :return: 검색 결과 DataFrame
    """
    # 공시 검색 조건 설정
    search_params = {
        'bgn_de': start_date,
        'end_de': end_date,
        # 'pblntf_detail_ty': ['A001', 'A002', 'A003'],  # 사업/반기/분기 보고서
        'page_count': 100  # 최대 100건까지 조회
    }

    if corp_codes:
        search_params['corp_code'] = corp_codes

    # 공시 검색 실행
    results = dart.filings.search(**search_params)

    # 결과 필터링
    capital_changes = []
    keywords = ['유상증자','무상감자','단기차입금','전환사채','교환사채','신주인수권부사채','전환청구권','교환청구권','부적정','채무보증','담보제공','횡령','배임','단기과열종목','금전대여']

    for report in results.report_list:
        if any(keyword in report.report_nm for keyword in keywords):
            capital_changes.append({
                # '회사명': report.corp_name,
                # '종목코드': report.corp_code,
                '공시일': report.rcept_dt,
                '보고서명': report.report_nm
            })
    return pd.DataFrame(capital_changes)
    # return capital_changes['공시일']+' / '+capital_changes['보고서명']

# %%
#############################################
## 3.종목코드를 가져오기 위해 한국거래소 정보 조회하기 ##
#############################################

chk_code = []

## 한국거래소 data import하여 상장된 기업의 종목 정보 가져오기
def fetch_krx_list():
    """
    한국거래소 KIND에서 상장회사 리스트 (회사명, 종목코드, 상장일) 가져오기
    """
    url = "https://kind.krx.co.kr/corpgeneral/corpList.do?method=download"
    headers = {
        "User-Agent": "Mozilla/5.0"
    }
    response = requests.get(url, headers=headers)
    response.raise_for_status()

    # 경고 무시
    # 이 옵션을 주석처리하면 종목코드와 상장일 col에서 경고 발생
    pd.set_option('mode.chained_assignment',  None)

    # response.text로 html을 읽고 pandas로 테이블 파싱
    tables = pd.read_html(response.text)
    df = tables[0]  # 첫 번째 테이블이 우리가 원하는 데이터

    # 필요한 열만 추리기
    df = df[['회사명', '종목코드']]

    # try:
    #   df['종목코드'] = df['종목코드'].apply(lambda x: f'{int(x):06d}')  # 종목코드 6자리 문자열
    # except:
    #   chk_code.append(df)
      # print('!!!!! ' + df['회사명'] + '(' + df['종목코드'] + ') 종목코드 확인 필요')
    # df['상장일'] = pd.to_datetime(df['상장일']).dt.strftime('%Y-%m-%d')  # 상장일 포맷 정리

    return df

# %%
## 항목 구분 체크 function
def check_stock_info(chk_var, chk_li):
  if chk_var == 'f':
    if float(chk_li) > 200.0:
      return False
  else:
    if (i > 0 for i in chk_li):
      return False
  return True

## main에서도 사용하기 위해 전역변수로 변경
now = datetime.now()

###############################
## 5.네이버 증권에서 종목정보 크롤링 ##
###############################
def get_stock_info(code):
  # 회사 이름 URL 인코딩
  url = f"https://finance.naver.com/item/main.nhn?code={code}"
  headers = {
      "User-Agent": "Mozilla/5.0"
  }

  response = requests.get(url, headers=headers)
  response.encoding = 'euc-kr'
  soup = BeautifulSoup(response.text, 'html.parser')
  err_list = []
  # 검색 결과 영역에서 주식 링크 찾기 (종목 코드 포함된 링크 찾기)
  link_tag = soup.select_one('#content > div.section.cop_analysis > div.sub_section > table > tbody')
  try:
      link_tag_li = link_tag.find_all("tr")
  except:
      link_tag_li = 'NA'
      err_list.append(str(code) + '_link')

  main_li = []  # 전체 output용
  title_li = [] # 파트 타이틀
  a_li = [] # 매출액
  b_li = [] # 영업이익
  c_li = [] # 당기순이익
  d_li = [] # 현재가
  e_li = [] # 재무제표 결과
  f_li = [] # 부채비율
  h_li = [] # 52주간 최고가
  g_li = [] # 최고가 대비
  i_li = [] # 특이사항
  j_li = [] # 시가총액

  # 내용 담는 용도
  tmp_a_li = []
  tmp_b_li = []
  tmp_c_li = []
  tmp_d_li = []
  tmp_e_li = []
  tmp_f_li = []
  tmp_g_li = []
  tmp_i_li = []

  for i in range(3):
    try:
      tmp_a_li.append(cleanhtml(link_tag_li[0].find_all('td')[i].text).replace('\n', '').replace('\t', '').replace(',', '')) if cleanhtml(link_tag_li[0].find_all('td')[i].text).replace('\n', '').replace('\t', '').replace(',', '') != '' else tmp_a_li.append('NA')
      tmp_b_li.append(cleanhtml(link_tag_li[1].find_all('td')[i].text).replace('\n', '').replace('\t', '').replace(',', '')) if cleanhtml(link_tag_li[1].find_all('td')[i].text).replace('\n', '').replace('\t', '').replace(',', '') != '' else tmp_b_li.append('NA')
      tmp_c_li.append(cleanhtml(link_tag_li[2].find_all('td')[i].text).replace('\n', '').replace('\t', '').replace(',', '')) if cleanhtml(link_tag_li[2].find_all('td')[i].text).replace('\n', '').replace('\t', '').replace(',', '') != '' else tmp_c_li.append('NA')
      tmp_f_li.append(cleanhtml(link_tag_li[6].find_all('td')[i].text).replace('\n', '').replace('\t', '').replace(',', '')) if cleanhtml(link_tag_li[6].find_all('td')[i].text).replace('\n', '').replace('\t', '').replace(',', '') != '' else tmp_f_li.append('NA')
    except:
      # print('!!!!!!!' + code)
      err_list.append(str(code))
      tmp_a_li.append('NA')
      tmp_b_li.append('NA')
      tmp_c_li.append('NA')
      tmp_f_li.append('NA')

  a_li.append(tmp_a_li) # 매출액
  b_li.append(tmp_b_li) # 영업이익
  c_li.append(tmp_c_li) # 당기순이익

  # 시가총액
  try:
      tmp_j_li = cleanhtml(soup.select_one('#_market_sum').text).strip().replace('\n', '').replace('\t', '').replace(',', '').replace('조', '')
  except:
      tmp_j_li = 'NA'
  j_li.append(tmp_j_li)

  # 종목 현재가
  try:
      tmp_d_li = cleanhtml(soup.select_one('#rate_info_krx > div > p.no_today > em.X > span.blind').text)
  except:
      try:
        tmp_d_li = cleanhtml(soup.select_one('#rate_info_krx > div > p.no_today > em.no_up > span.blind').text)
      except:
        try:
          tmp_d_li = cleanhtml(soup.select_one('#rate_info_krx > div > p.no_today > em.no_down > span.blind').text)
        except:
          tmp_d_li = 'NA'
          err_list.append(str(code) + '_now')
  d_li.append(tmp_d_li) # 현재가

  ############# 52주 최고가 왼쪽 : 재무제표 = 매출액, 영업이익, 당기순이익 모두 >0 & 부채비율<200
  chk_stock_status_val = 0
  for a in tmp_a_li:
    try:
      if a == 'NA' or a == '-' or a == '':
        break
      chk_stock_status_val += 1 if int(a) <= 0 else 0
    except:
      chk_stock_status_val += 1
  for b in tmp_b_li:
    try:
      if b == 'NA' or b == '-' or b == '':
        break
      chk_stock_status_val += 1 if int(b) <= 0 else 0
    except:
      chk_stock_status_val += 1
  for c in tmp_c_li:
    try:
      if c == 'NA'or c == '-' or c == '':
        break
      chk_stock_status_val += 1 if int(c) <= 0 else 0
    except:
      chk_stock_status_val += 1
  for f in tmp_f_li:
    # if f == 'NA':
    #   break
    if f == 'NA':
      continue
    elif float(f) > 200.0:
      chk_stock_status_val += 1

  tmp_e_li = 'X' if chk_stock_status_val > 0 else 'O'

  f_li.append(tmp_f_li) # 부채비율
  e_li.append(tmp_e_li) # 재무제표 결과


  #### g.현재가/52주 최고가 start ####
  high_52 = soup.select_one('#tab_con1 > div:nth-child(4) > table')
  try:
      high_52_li = high_52.find_all("em")
      h_li.append(cleanhtml(high_52_li[2].text))
  except:
      high_52_li = 'NA'
      err_list.append(str(code) + '_h_li')

  try:
      tmp_g_li = str(int(round(float(tmp_d_li.replace(',', ''))/float(h_li[0].replace(',', ''))*100, 0))) # 현재가/52주 최고가
      g_li.append(tmp_g_li) # 현재가/52주 최고가
  except:
      tmp_g_li = 'NA'
      err_list.append(str(code) + '_g_li')
  #### g.현재가/52주 최고가 end ####

  #### i.특이사항 start ####
  now_date = now.strftime('%Y%m%d')
  before_date = (now - relativedelta(years=5)).strftime('%Y%m%d')

  # try:
  tmp_i_li = check_capital_changes(before_date, now_date, code)

  if tmp_i_li.empty == True:
    tmp_i_li = 'O'
  i_li.append(tmp_i_li)
  #   i_li.append(tmp_i_li['공시일'] + ' / ' + tmp_i_li['보고서명']) # 특이사항
  # # except:
  # #     tmp_i_li = 'NA'
  # #     err_list.append(str(code) + '_i_li') ## df empty일 경우 모두 append 하므로 주석처리
  #### i.특이사항 end ####

  if len(err_list) > 0:
    print(err_list)

  return a_li[0], b_li[0], c_li[0], d_li, e_li, f_li[0], h_li, g_li, i_li, j_li

# %%
# ### KRX 상에 특수한 기업명으로 되어 있어 데이터를 못가져오는 경우 발생
abnormalStockList = {'KCC':'케이씨씨', 'KCTC':'케이씨티씨', '삼화페인트':'삼화페인트공업', '한국전력':'한국전력공사'}
def abnormalStockName(stockName):
  abnormalStockList = {'KCC':'케이씨씨', 'KCTC':'케이씨티씨', '삼화페인트':'삼화페인트공업', '한국전력':'한국전력공사'}
  if stockName in abnormalStockList.keys():
    return abnormalStockList[stockName]
  return None

# if 'KCC' in abnormalStockList.keys():
#   print(abnormalStockList['KCC'])

# %%
from email.mime.text import MIMEText
from email.mime.multipart import MIMEMultipart
from email.mime.base import MIMEBase
from email import encoders
import smtplib

def send_email(file_name):
    sender_email = "skfkeh0512@naver.com"
    receiver_email = "skfkeh0512@naver.com"
    password = "YVXDJRBGBZBE" ##input("암호를 입력하세요: ").strip()

    # 메일 기본 정보
    message = MIMEMultipart()
    message["From"] = sender_email
    message["To"] = receiver_email
    message["Subject"] = file_name

    # 본문 작성
    body = """안녕하세요, '자동화댕' 으로 발송된 메일입니다.
저평가우량주 주식 정보가 담겨있는 엑셀파일을 첨부했습니다.
함께 확인해 주세요!"""
    message.attach(MIMEText(body, "plain"))

    file_path = "/content/" + file_name  # Colab 업로드 파일 경로
    # 첨부파일 추가
    with open(file_path, "rb") as attachment:
        part = MIMEBase("application", "octet-stream")
        part.set_payload(attachment.read())

    # Base64 인코딩
    encoders.encode_base64(part)
    part.add_header(
        "Content-Disposition",
        f"attachment; filename={file_name}",
    )
    message.attach(part)

    try:
        with smtplib.SMTP("smtp.naver.com", 587) as server:
            server.starttls()
            server.login(sender_email, password)
            server.sendmail(sender_email, receiver_email, message.as_string())
        print("메일 전송 완료 ✅")
    except smtplib.SMTPAuthenticationError as e:
        print("인증 실패:", e)
    except Exception as e:
        print("오류 발생:", e)

# %%
if __name__ == "__main__":
    ### 파일명 변경될 수 있으므로 상단으로 옮김
    # corp_list = read_excel('/content/250602 코스피.xlsx')   # windows 기준

    # 한국거래소에 상장된 리스트 가져오기
    krx_list = fetch_krx_list()

    # dart 정보 가져오기
    # df_listed: 상장, df_non_listed: 비상장
    # df_listed, df_non_listed = dart_info()

    main_li = []
    for i in range(len(corp_list)):
      if corp_list[i].replace('*', '').strip() in abnormalStockList.keys():
        tmp_corp_name = corp_list[i]
        print(tmp_corp_name + '/' + corp_list[i])
        corp_list[i] = abnormalStockList[corp_list[i].replace('*', '').strip()]

      if corp_list[i].replace('*', '').strip() in krx_list['회사명'].values:
        if (corp_list[i] == '옵'):
          print("**********************")
        code = krx_list.loc[krx_list['회사명'] == corp_list[i].replace('*', '').strip(), '종목코드'].values[0]
        print('[' + str(i+1) + ']' + corp_list[i] + "(" + code + ")\t\t start!!!")
        try:
          df = get_stock_info(code)
        except:
          print('!!!!!!' + str(i+1) + ']' + corp_list[i])
        try:
          data = {
              '종목명': corp_list[i],
              '종목코드': code,
              '현재가': df[3][0],
              '시가총액': df[9][0],
              '매출액(2022)': df[0][0],
              '매출액(2023)': df[0][1],
              '매출액(2024)': df[0][2],
              '영업이익(2022)': df[1][0],
              '영업이익(2023)': df[1][1],
              '영업이익(2024)': df[1][2],
              '당기순이익(2022)': df[2][0],
              '당기순이익(2023)': df[2][1],
              '당기순이익(2024)': df[2][2],
              '부채비율(2022)': df[5][0],
              '부채비율(2023)': df[5][1],
              '부채비율(2024)': df[5][2],
              '재무제표': df[4][0],
              '전자공시': df[8][0],
              '52주 최고가': df[6][0],
              '최고가 대비': df[7][0],
              # PER: 시가총액 / 당기순이익(최근) : 소수점 첫째자리까지 (둘째자리에서 반올림)
              # PSR: 시가총액 / 매출액(최근) : 소수점 둘째자리까지 (셋째자리에서 반올림)
              'PER': round(int(df[9][0]) / int(df[2][2]), 1),
              'PSR': round(int(df[9][0]) / int(df[0][2]), 2)
          }

        except:
          print('[' + str(i+1) + ']' + corp_list[i] + '???????')
          data = {
              '종목명': corp_list[i],
              '종목코드': 'NA',
              '현재가': 'NA',
              '시가총액': 'NA',
              '매출액(2022)': 'NA',
              '매출액(2023)': 'NA',
              '매출액(2024)': 'NA',
              '영업이익(2022)': 'NA',
              '영업이익(2023)': 'NA',
              '영업이익(2024)': 'NA',
              '당기순이익(2022)': 'NA',
              '당기순이익(2023)': 'NA',
              '당기순이익(2024)': 'NA',
              '부채비율(2022)': 'NA',
              '부채비율(2023)': 'NA',
              '부채비율(2024)': 'NA',
              '재무제표': 'NA',
              '전자공시': 'NA',
              '52주 최고가': 'NA',
              '최고가 대비': 'NA',
              'PER': 'NA',
              'PSR': 'NA'
          }
        main_li.append(data)
      else:
        print('[' + str(i+1) + ']' + corp_list[i] + "\t\t~~~SKIP!!!")
        data = {
              '종목명': corp_list[i],
              '종목코드': 'NA',
              '현재가': 'NA',
              '시가총액': 'NA',
              '매출액(2022)': 'NA',
              '매출액(2023)': 'NA',
              '매출액(2024)': 'NA',
              '영업이익(2022)': 'NA',
              '영업이익(2023)': 'NA',
              '영업이익(2024)': 'NA',
              '당기순이익(2022)': 'NA',
              '당기순이익(2023)': 'NA',
              '당기순이익(2024)': 'NA',
              '부채비율(2022)': 'NA',
              '부채비율(2023)': 'NA',
              '부채비율(2024)': 'NA',
              '재무제표': 'NA',
              '전자공시': 'NA',
              '52주 최고가': 'NA',
              '최고가 대비': 'NA',
              'PER': 'NA',
              'PSR': 'NA'
          }
        main_li.append(data)
      # if i == 40:
      #   break
    main_df = pd.DataFrame(main_li)


    # hyperlinkInsert(main_df)
    # main_df.to_excel(f'주식_정보.xlsx', index=False)

    # 엑셀로 저장 (xlsxwriter 사용)
    excelName = '주식_정보_' + now.strftime("%Y%m%d") + '.xlsx'
    with pd.ExcelWriter(excelName, engine='xlsxwriter') as writer:
        main_df.to_excel(writer, sheet_name=now.strftime("%Y%m%d"), index=False, startrow=0)

        # 워크북과 시트 객체 얻기
        workbook  = writer.book
        worksheet = writer.sheets[now.strftime("%Y%m%d")]

        # 반복문으로 하이퍼링크 삽입 (row=2부터 데이터 시작)
        for row_num, (code, name) in enumerate(zip(main_df['종목코드'], main_df['종목명']), start=0):
            url = f"https://finance.naver.com/item/main.nhn?code={code}"
            worksheet.write_url(row_num + 1, 0, url, string=name)  # col=0 → '종목명' 열

    send_email(excelName)

    print("##################################")
    print("############## Done ##############")
    print("##################################")

    end = time.time()   ## 종료시점

    print(f"\n프로그램이 종료되었습니다.\n{int((end - start)/60)} 분 {int((end - start)%60)} 초 ({end - start:.5f} sec) 소요")
# Out:
# /tmp/ipython-input-624711923.py:24: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   tables = pd.read_html(response.text)
# [1]세원정공(021820)		 start!!!
# [2]STX(011810)		 start!!!
# [3]세이브존I&amp;C		~~~SKIP!!!
# [4]두올(016740)		 start!!!
# [5]NI스틸(008260)		 start!!!
# [6]마이티 26-09 특수채(AAA)액티브		~~~SKIP!!!
# [7]BNK 26-06 특수채(AAA이상)액티브		~~~SKIP!!!
# [8]TIGER 2차전지TOP10레버리지		~~~SKIP!!!
# [9]KODEX 메타버스액티브		~~~SKIP!!!
# [10]휴비스(079980)		 start!!!
# [11]KODEX 코리아배당성장채권혼합		~~~SKIP!!!
# [12]태경케미컬(006890)		 start!!!
# [13]메리츠 미국채30년 ETN(H)		~~~SKIP!!!
# [14]ACE 11월만기자동연장회사채AA-이상액티브		~~~SKIP!!!
# [15]진흥기업(002780)		 start!!!
# [16]HANARO Fn조선해운		~~~SKIP!!!
# [17]TIMEFOLIO 코스피액티브		~~~SKIP!!!
# [18]HS화성(002460)		 start!!!
# [19]TIGER 인터넷TOP10		~~~SKIP!!!
# [20]CJ씨푸드(011150)		 start!!!
# [21]아남전자(008700)		 start!!!
# [22]화천기계(010660)		 start!!!
# [23]삼성 인버스 2X 천연가스 선물 ETN D		~~~SKIP!!!
# [24]TIGER 리츠부동산인프라TOP10액티브		~~~SKIP!!!
# [25]신한 WTI원유 선물 ETN		~~~SKIP!!!
# [26]TIGER 차이나CSI300레버리지(합성)		~~~SKIP!!!
# [27]SOL 화장품TOP3플러스		~~~SKIP!!!
# [28]KTis(058860)		 start!!!
# [29]CS홀딩스(000590)		 start!!!
# [30]키움 레버리지 조선TOP10 ETN		~~~SKIP!!!
# [31]화승코퍼레이션(013520)		 start!!!
# [32]KC코트렐(119650)		 start!!!
# [33]한국특강(007280)		 start!!!
# [34]제일연마(001560)		 start!!!
# [35]DRB동일(004840)		 start!!!
# [36]ACE 미국반도체데일리타겟커버드콜(합성)		~~~SKIP!!!
# [37]SK우		~~~SKIP!!!
# [38]동일산업(004890)		 start!!!
# [39]팜스코(036580)		 start!!!
# [40]인스코비(006490)		 start!!!
# [41]미래에셋 레버리지 코스피200 선물 ETN		~~~SKIP!!!
# [42]삼원강재(023000)		 start!!!
# [43]KB 레버리지 나스닥 100 ETN		~~~SKIP!!!
# [44]국제약품(002720)		 start!!!
# [45]두산퓨얼셀1우		~~~SKIP!!!
# [46]RISE 코스닥150선물레버리지		~~~SKIP!!!
# [47]KIWOOM 단기채권ESG액티브		~~~SKIP!!!
# [48]황금에스티(032560)		 start!!!
# [49]RISE 대형고배당10TR		~~~SKIP!!!
# [50]TIGER 미국초단기(3개월이하)국채		~~~SKIP!!!
# [51]RISE 미국S&amp;P500(H)		~~~SKIP!!!
# [52]인지컨트롤스(023800)		 start!!!
# [53]ACE 우량회사채(AA-이상)액티브		~~~SKIP!!!
# [54]동일고무벨트(163560)		 start!!!
# [55]사조오양(006090)		 start!!!
# [56]신일전자(002700)		 start!!!
# [57]TIGER 200선물레버리지		~~~SKIP!!!
# [58]KODEX 미국10년국채선물		~~~SKIP!!!
# [59]SOL CD금리&amp;머니마켓액티브		~~~SKIP!!!
# [60]조흥(002600)		 start!!!
# [61]SOL K방산		~~~SKIP!!!
# [62]HL D&amp;I		~~~SKIP!!!
# [63]한신공영(004960)		 start!!!
# [64]모나리자(012690)		 start!!!
# [65]TIGER 증권		~~~SKIP!!!
# [66]TIGER 글로벌AI&amp;로보틱스 INDXX		~~~SKIP!!!
# [67]TIGER 중국소비테마		~~~SKIP!!!
# [68]진양산업(003780)		 start!!!
# [69]파워 200		~~~SKIP!!!
# [70]RISE 플랫폼테마		~~~SKIP!!!
# [71]한국내화(010040)		 start!!!
# [72]ACE 8월만기자동연장회사채AA-이상액티브		~~~SKIP!!!
# [73]KODEX TRF5050		~~~SKIP!!!
# [74]하이스틸(071090)		 start!!!
# [75]TIGER 차이나반도체FACTSET		~~~SKIP!!!
# [76]RISE 2차전지TOP10인버스(합성)		~~~SKIP!!!
# [77]영보화학(014440)		 start!!!
# [78]삼성 레버리지 금 선물 ETN(H)		~~~SKIP!!!
# [79]상상인증권(001290)		 start!!!
# [80]삼호개발(010960)		 start!!!
# [81]KODEX 미국S&amp;P500변동성확대시커버드콜		~~~SKIP!!!
# [82]PLUS 코스피TR		~~~SKIP!!!
# [83]동인기연(111380)		 start!!!
# [84]TP(007980)		 start!!!
# [85]NH프라임리츠(338100)		 start!!!
# ['338100_link', '338100', '338100', '338100', '338100_h_li', '338100_g_li']
# [85]NH프라임리츠???????
# [86]한투 인버스 2X 코스닥150선물 ETN		~~~SKIP!!!
# [87]SK이노베이션우		~~~SKIP!!!
# [88]TIGER Fn메타버스		~~~SKIP!!!
# [89]팜젠사이언스(004720)		 start!!!
# [90]덕성(004830)		 start!!!
# [91]신한 레버리지 코스닥 150 선물 ETN		~~~SKIP!!!
# [92]한일철강(002220)		 start!!!
# [93]KODEX 헬스케어		~~~SKIP!!!
# [94]RISE 고배당		~~~SKIP!!!
# [95]부산산업(011390)		 start!!!
# [96]ACE 미국30년국채선물레버리지(합성 H)		~~~SKIP!!!
# [97]TIGER AI반도체핵심공정		~~~SKIP!!!
# [98]무림페이퍼(009200)		 start!!!
# [99]ACE 포스코그룹포커스		~~~SKIP!!!
# [100]동방아그로(007590)		 start!!!
# [101]TIGER 글로벌4차산업혁신기술(합성 H)		~~~SKIP!!!
# [102]ACE 미국주식베스트셀러		~~~SKIP!!!
# [103]삼성 레버리지 은 선물 ETN(H)		~~~SKIP!!!
# [104]KODEX 미국나스닥AI테크액티브		~~~SKIP!!!
# [105]신한 레버리지 S&amp;P500 선물 ETN		~~~SKIP!!!
# [106]TIGER 미국AI소프트웨어TOP4Plus		~~~SKIP!!!
# [107]KB 레버리지 S&amp;P 500 선물 ETN(H)		~~~SKIP!!!
# [108]KoAct K수출핵심기업TOP30액티브		~~~SKIP!!!
# [109]KODEX 차이나테크TOP10		~~~SKIP!!!
# [110]한솔로지스틱스(009180)		 start!!!
# [111]부국증권우		~~~SKIP!!!
# [112]인디에프(014990)		 start!!!
# [113]KB 블룸버그 인버스2X 천연가스선물 ETN(H)		~~~SKIP!!!
# [114]인터지스(129260)		 start!!!
# [115]대현(016090)		 start!!!
# [116]ACE 주주환원가치주액티브		~~~SKIP!!!
# [117]KODEX iShares미국하이일드액티브		~~~SKIP!!!
# [118]PLUS 신흥국MSCI(합성 H)		~~~SKIP!!!
# [119]RISE 미국배당100데일리고정커버드콜		~~~SKIP!!!
# [120]신송홀딩스(006880)		 start!!!
# [121]SOL 미국S&amp;P500ESG		~~~SKIP!!!
# [122]신한 S&amp;P500 VIX S/T 선물 ETN E		~~~SKIP!!!
# [123]삼부토건(001470)		 start!!!
# [124]SOL 미국TOP5채권혼합40 Solactive		~~~SKIP!!!
# [125]태양금속		~~~SKIP!!!
# [126]TIGER 현대차그룹+펀더멘털		~~~SKIP!!!
# [127]대림바스(005750)		 start!!!
# [128]남양유업우		~~~SKIP!!!
# [129]KODEX K콘텐츠		~~~SKIP!!!
# [130]한컴라이프케어(372910)		 start!!!
# [131]RISE ESG사회책임투자		~~~SKIP!!!
# [132]SG글로벌(001380)		 start!!!
# [133]깨끗한나라(004540)		 start!!!
# [134]GS우		~~~SKIP!!!
# [135]HANARO CAPEX설비투자iSelect		~~~SKIP!!!
# [136]TIGER 글로벌온디바이스AI		~~~SKIP!!!
# [137]남광토건(001260)		 start!!!
# [138]지엠비코리아(013870)		 start!!!
# [139]ACE 단기채권알파액티브		~~~SKIP!!!
# [140]RISE 중국본토대형주CSI100		~~~SKIP!!!
# [141]IHQ		~~~SKIP!!!
# [142]기신정기(092440)		 start!!!
# [143]한투 인버스2X천연가스선물 ETN B		~~~SKIP!!!
# [144]ACE 원자력테마딥서치		~~~SKIP!!!
# [145]KoAct 글로벌AI&amp;로봇액티브		~~~SKIP!!!
# [146]대구백화점(006370)		 start!!!
# [147]TIGER 200선물인버스2X		~~~SKIP!!!
# [148]일성건설(013360)		 start!!!
# [149]아이티센씨티에스(031820)		 start!!!
# [150]비상교육(100220)		 start!!!
# [151]디와이덕양(024900)		 start!!!
# [152]유유제약(000220)		 start!!!
# [153]신한 WTI원유 선물 ETN(H)		~~~SKIP!!!
# [154]HANARO Fn K-POP&amp;미디어		~~~SKIP!!!
# [155]호전실업(111110)		 start!!!
# [156]유엔젤(072130)		 start!!!
# [157]조광페인트(004910)		 start!!!
# [158]아모레퍼시픽홀딩스우		~~~SKIP!!!
# [159]삼화왕관(004450)		 start!!!
# [160]KODEX 미국달러선물인버스		~~~SKIP!!!
# [161]TIGER 차이나전기차레버리지(합성)		~~~SKIP!!!
# [162]TIGER 차이나바이오테크SOLACTIVE		~~~SKIP!!!
# [163]유니온(000910)		 start!!!
# [164]오리엔트바이오(002630)		 start!!!
# [165]KIWOOM 미국S&amp;P500		~~~SKIP!!!
# [166]HANARO 머니마켓액티브		~~~SKIP!!!
# [167]한투 레버리지 금 선물 ETN		~~~SKIP!!!
# [168]테이팩스(055490)		 start!!!
# [169]KODEX TRF7030		~~~SKIP!!!
# [170]PLUS 미국S&amp;P500(H)		~~~SKIP!!!
# [171]미래에셋맵스리츠(357250)		 start!!!
# ['357250_link', '357250', '357250', '357250', '357250_h_li', '357250_g_li']
# [171]미래에셋맵스리츠???????
# [172]쌍방울(102280)		 start!!!
# [173]화천기공(000850)		 start!!!
# [174]RISE 버크셔포트폴리오TOP10		~~~SKIP!!!
# [175]혜인(003010)		 start!!!
# [176]삼성 미국 대형 성장주 ETN		~~~SKIP!!!
# [177]대양금속(009190)		 start!!!
# [178]KODEX 미국S&amp;P500버퍼3월액티브		~~~SKIP!!!
# [179]KB Wise 분할매매 ETN		~~~SKIP!!!
# [180]WON 25-09 회사채(AA-이상)액티브		~~~SKIP!!!
# [181]RISE 미국AI밸류체인TOP3Plus		~~~SKIP!!!
# [182]삼정펄프(009770)		 start!!!
# [183]KODEX K원자력SMR		~~~SKIP!!!
# [184]미래에셋 레버리지 코스닥150 선물 ETN		~~~SKIP!!!
# [185]TIGER 코스닥150 레버리지		~~~SKIP!!!
# [186]까뮤이앤씨(013700)		 start!!!
# [187]PLUS 고배당주위클리고정커버드콜		~~~SKIP!!!
# [188]TIGER 차이나글로벌리더스TOP3+		~~~SKIP!!!
# [189]세원이앤씨(091090)		 start!!!
# [190]고려산업(002140)		 start!!!
# [191]TIGER 미국배당다우존스타겟커버드콜1호		~~~SKIP!!!
# [192]전방(000950)		 start!!!
# [193]성안머티리얼스(011300)		 start!!!
# [194]코오롱인더우		~~~SKIP!!!
# [195]KIWOOM 미국나스닥100(H)		~~~SKIP!!!
# [196]KIWOOM 25-09 회사채(AA-이상)액티브		~~~SKIP!!!
# [197]인팩(023810)		 start!!!
# [198]KODEX 글로벌비만치료제TOP2 Plus		~~~SKIP!!!
# [199]제이준코스메틱(025620)		 start!!!
# [200]SG세계물산(004060)		 start!!!
# [201]KODEX 코스피TR		~~~SKIP!!!
# [202]TIGER 경기방어		~~~SKIP!!!
# [203]화승알앤에이(378850)		 start!!!
# [204]TIGER 미국나스닥바이오		~~~SKIP!!!
# [205]DL이앤씨2우(전환)		~~~SKIP!!!
# [206]메리츠 KAP 통안채 3개월 ETN		~~~SKIP!!!
# [207]ACE 글로벌인컴TOP10 SOLACTIVE		~~~SKIP!!!
# [208]화인베스틸(133820)		 start!!!
# [209]미래에셋 인버스 2X 코스닥150 선물 ETN		~~~SKIP!!!
# [210]TIGER 글로벌비만치료제TOP2Plus		~~~SKIP!!!
# [211]WON 대한민국국고채액티브		~~~SKIP!!!
# [212]티웨이홀딩스(004870)		 start!!!
# [213]PLUS 미국채30년액티브		~~~SKIP!!!
# [214]KODEX 아시아달러채권ESG플러스액티브		~~~SKIP!!!
# [215]KODEX 친환경조선해운액티브		~~~SKIP!!!
# [216]ACE 중장기국공채액티브		~~~SKIP!!!
# [217]씨아이테크(004920)		 start!!!
# [218]보락(002760)		 start!!!
# [219]삼일씨엔에스(004440)		 start!!!
# [220]한투 레버리지일본니케이225선물 ETN(H)		~~~SKIP!!!
# [221]ACE 200TR		~~~SKIP!!!
# [222]HANARO 200선물레버리지		~~~SKIP!!!
# [223]N2 방위산업 Top5 ETN		~~~SKIP!!!
# [224]RISE 5G테크		~~~SKIP!!!
# [225]신한글로벌액티브리츠(481850)		 start!!!
# ['481850_link', '481850', '481850', '481850', '481850_h_li', '481850_g_li']
# [225]신한글로벌액티브리츠???????
# [226]RISE 국고채3년		~~~SKIP!!!
# [227]KODEX WTI원유선물(H)		~~~SKIP!!!
# [228]신풍제약우		~~~SKIP!!!
# [229]조비(001550)		 start!!!
# [230]TIGER 미국S&amp;P500레버리지(합성 H)		~~~SKIP!!!
# [231]SOL 자동차TOP3플러스		~~~SKIP!!!
# [232]TIGER 코스피고배당		~~~SKIP!!!
# [233]TIMEFOLIO 미국S&amp;P500액티브		~~~SKIP!!!
# [234]보해양조(000890)		 start!!!
# [235]형지엘리트(093240)		 start!!!
# [236]새론오토모티브(075180)		 start!!!
# [237]TIMEFOLIO 미국나스닥100채권혼합50액티브		~~~SKIP!!!
# [238]유니온머티리얼(047400)		 start!!!
# [239]갤럭시아에스엠(011420)		 start!!!
# [240]미래에셋 0.5X 코스피200 선물 ETN		~~~SKIP!!!
# [241]KIWOOM 코리아밸류업		~~~SKIP!!!
# [242]동원금속(018500)		 start!!!
# [243]KB 인버스 천연가스 선물 ETN		~~~SKIP!!!
# [244]KODEX 미국AI소프트웨어TOP10		~~~SKIP!!!
# [245]KODEX Top10동일가중		~~~SKIP!!!
# [246]한투 인버스2X 나스닥100 ETN B		~~~SKIP!!!
# [247]금비(008870)		 start!!!
# [248]삼화전자		~~~SKIP!!!
# [249]KODEX 코리아배당성장		~~~SKIP!!!
# [250]DSR(155660)		 start!!!
# [251]상신브레이크(041650)		 start!!!
# [252]서울식품		~~~SKIP!!!
# [253]마이다스 코스피액티브		~~~SKIP!!!
# [254]KODEX 미국달러선물		~~~SKIP!!!
# [255]키움 미국달러선물 ETN B		~~~SKIP!!!
# [256]TIGER 레버리지		~~~SKIP!!!
# [257]에셋플러스 글로벌플랫폼액티브		~~~SKIP!!!
# [258]한화솔루션우		~~~SKIP!!!
# [259]TIGER 일본엔선물		~~~SKIP!!!
# [260]영흥(012160)		 start!!!
# [261]N2 레버리지 금 선물 ETN(H)		~~~SKIP!!!
# [262]명문제약(017180)		 start!!!
# [263]1Q 미국S&amp;P500미국채혼합50액티브		~~~SKIP!!!
# [264]메리츠 레버리지 금 선물 ETN(H)		~~~SKIP!!!
# [265]평화홀딩스(010770)		 start!!!
# [266]써니전자(004770)		 start!!!
# [267]천일고속(000650)		 start!!!
# [268]영풍제지(006740)		 start!!!
# [269]삼성 KRX 금현물 ETN		~~~SKIP!!!
# [270]코오롱모빌리티그룹우		~~~SKIP!!!
# [271]키움 코스피 200 TR ETN		~~~SKIP!!!
# [272]삼성 블룸버그 인버스2X WTI원유선물 ETN B		~~~SKIP!!!
# [273]하나 Solactive US Tech Top 10 ETN(H)		~~~SKIP!!!
# [274]삼성 미국 대형 성장주 ETN(H)		~~~SKIP!!!
# [275]SB성보(003080)		 start!!!
# [276]TIMEFOLIO K컬처액티브		~~~SKIP!!!
# [277]메타케어(118000)		 start!!!
# [278]KIWOOM 미국달러선물인버스		~~~SKIP!!!
# [279]TIGER Fn신재생에너지		~~~SKIP!!!
# [280]SK케미칼우		~~~SKIP!!!
# [281]하나 레버리지 반도체 ETN		~~~SKIP!!!
# [282]한솔홈데코(025750)		 start!!!
# [283]SOL 미국30년국채액티브(H)		~~~SKIP!!!
# [284]삼성 인버스0.5X S&amp;P500 VIX S/T선물 ETN B		~~~SKIP!!!
# [285]KODEX TDF2030액티브		~~~SKIP!!!
# [286]HANARO e커머스		~~~SKIP!!!
# [287]KODEX TDF2040액티브		~~~SKIP!!!
# [288]TIGER 배당성장		~~~SKIP!!!
# [289]다스코(058730)		 start!!!
# [290]BYC우		~~~SKIP!!!
# [291]서원(021050)		 start!!!
# [292]ACE AI반도체포커스		~~~SKIP!!!
# [293]메리츠 3X 레버리지 미국채30년 ETN		~~~SKIP!!!
# [294]아이엠에셋 200		~~~SKIP!!!
# [295]현대건설우		~~~SKIP!!!
# [296]미래에셋 레버리지 KRX 금현물 ETN		~~~SKIP!!!
# [297]SJM		~~~SKIP!!!
# [298]미래에셋 0.5X 코스닥150 선물 ETN		~~~SKIP!!!
# [299]평화산업(090080)		 start!!!
# [300]ACE 인도컨슈머파워액티브		~~~SKIP!!!
# [301]DSR제강(069730)		 start!!!
# [302]STX그린로지스(465770)		 start!!!
# [303]ACE 삼성그룹섹터가중		~~~SKIP!!!
# [304]마니커(027740)		 start!!!
# [305]KODEX 미국S&amp;P500버퍼6월액티브		~~~SKIP!!!
# [306]롯데칠성우		~~~SKIP!!!
# [307]금호전기(001210)		 start!!!
# [308]대유에이텍(002880)		 start!!!
# [309]선도전기(007610)		 start!!!
# [310]KODEX 차이나H레버리지(H)		~~~SKIP!!!
# [311]TIGER 차이나HSCEI		~~~SKIP!!!
# [312]TIGER 엔비디아미국채커버드콜밸런스(합성)		~~~SKIP!!!
# [313]케이비아이동국실업(001620)		 start!!!
# [314]미래에셋 CAPE 실러 US Core Sector ETN		~~~SKIP!!!
# [315]SJM홀딩스		~~~SKIP!!!
# [316]ACE 라이프자산주주가치액티브		~~~SKIP!!!
# [317]이건산업(008250)		 start!!!
# [318]범양건영(002410)		 start!!!
# [319]HANARO K-뷰티		~~~SKIP!!!
# [320]신한 레버리지 다우존스지수 선물 ETN(H)		~~~SKIP!!!
# [321]1Q 종합채권(AA-이상)액티브		~~~SKIP!!!
# [322]신한 금 선물 ETN(H)		~~~SKIP!!!
# [323]한국종합기술(023350)		 start!!!
# [324]WON 200		~~~SKIP!!!
# [325]DYP(092780)		 start!!!
# [326]WON 종합채권(AA-이상)액티브		~~~SKIP!!!
# [327]유성기업(002920)		 start!!!
# [328]미래에셋 미국 테크&amp;반도체 TOP3 ETN		~~~SKIP!!!
# [329]PLUS 우주항공&amp;UAM		~~~SKIP!!!
# [330]엑시큐어하이트론(019490)		 start!!!
# [331]우성(006980)		 start!!!
# [332]KIWOOM 국고채30년액티브		~~~SKIP!!!
# [333]RISE 미국30년국채커버드콜(합성)		~~~SKIP!!!
# [334]미래산업(025560)		 start!!!
# [335]아진전자부품(009320)		 start!!!
# [336]신한 블룸버그 2X 천연가스 선물 ETN		~~~SKIP!!!
# [337]삼성 미국 대형 가치주 ETN		~~~SKIP!!!
# [338]RISE 미국달러SOFR금리액티브(합성)		~~~SKIP!!!
# [339]플레이그램(009810)		 start!!!
# [340]SOL 미국나스닥100		~~~SKIP!!!
# [341]SOL 한국형글로벌반도체액티브		~~~SKIP!!!
# [342]KODEX 차이나H		~~~SKIP!!!
# [343]SOL 한국원자력SMR		~~~SKIP!!!
# [344]PLUS 자사주매입고배당주		~~~SKIP!!!
# [345]삼성 레버리지 나스닥 100 TR ETN		~~~SKIP!!!
# [346]미래에셋-0.5X S&amp;P500 VIX S/T선물 ETN(H)B		~~~SKIP!!!
# [347]진양화학(051630)		 start!!!
# [348]웰바이오텍(010600)		 start!!!
# [349]시디즈(134790)		 start!!!
# [350]ACE 2월만기자동연장회사채AA-이상액티브		~~~SKIP!!!
# [351]RISE 2차전지TOP10		~~~SKIP!!!
# [352]광명전기(017040)		 start!!!
# [353]문배철강(008420)		 start!!!
# [354]신한 레버리지 코스피 200 선물 ETN		~~~SKIP!!!
# [355]삼성 레버리지 코스피200 선물 ETN		~~~SKIP!!!
# [356]삼성 레버리지 항셍테크 TR ETN(H) B		~~~SKIP!!!
# [357]부국철강(026940)		 start!!!
# [358]SK디스커버리우		~~~SKIP!!!
# [359]유안타증권우		~~~SKIP!!!
# [360]주성코퍼레이션(109070)		 start!!!
# [361]미래에셋 인버스 천연가스 선물 ETN B		~~~SKIP!!!
# [362]KIWOOM 고배당		~~~SKIP!!!
# [363]SOL 코리아밸류업TR		~~~SKIP!!!
# [364]마스턴프리미어리츠(357430)		 start!!!
# ['357430_link', '357430', '357430', '357430', '357430_h_li', '357430_g_li']
# [364]마스턴프리미어리츠???????
# [365]미래에셋 2X 미국 테크&amp;반도체 TOP3 ETN		~~~SKIP!!!
# [366]메리츠 레버리지 미국채30년 ETN(H)		~~~SKIP!!!
# [367]HANARO MSCI Korea TR		~~~SKIP!!!
# [368]PLUS 단기채권액티브		~~~SKIP!!!
# [369]SH에너지화학(002360)		 start!!!
# [370]미래에셋 -1.5X 천연가스 선물 ETN		~~~SKIP!!!
# [371]메리츠 국채30년 ETN		~~~SKIP!!!
# [372]KODEX 미국S&amp;P500헬스케어		~~~SKIP!!!
# [373]KODEX 200IT TR		~~~SKIP!!!
# [374]일진디스플(020760)		 start!!!
# [375]영화금속(012280)		 start!!!
# [376]케이탑리츠(145270)		 start!!!
# ['145270_link', '145270', '145270', '145270', '145270_h_li', '145270_g_li']
# [376]케이탑리츠???????
# [377]에쓰씨엔지니어링(023960)		 start!!!
# [378]미래에셋 미국 AI TOP3 ETN		~~~SKIP!!!
# [379]유화증권우		~~~SKIP!!!
# [380]KR모터스(000040)		 start!!!
# [381]삼성 레버리지 China A50 선물 ETN(H)		~~~SKIP!!!
# [382]PLUS 국고채10년액티브		~~~SKIP!!!
# [383]RISE 금융채액티브		~~~SKIP!!!
# [384]ACE 글로벌자율주행액티브		~~~SKIP!!!
# [385]KoAct 코리아밸류업액티브		~~~SKIP!!!
# [386]진양폴리		~~~SKIP!!!
# [387]미래에셋 2X 홍콩H 선물 ETN		~~~SKIP!!!
# [388]씨티알모빌리티(308170)		 start!!!
# [389]TIGER 인버스		~~~SKIP!!!
# [390]신한 은 선물 ETN(H)		~~~SKIP!!!
# [391]ACE 미국배당퀄리티+커버드콜액티브		~~~SKIP!!!
# [392]한투 블룸버그레버리지WTI원유선물 ETN B		~~~SKIP!!!
# [393]우진플라임(049800)		 start!!!
# [394]KB 레버리지 FANG 플러스 ETN(H)		~~~SKIP!!!
# [395]KoAct 미국나스닥성장기업액티브		~~~SKIP!!!
# [396]신한 인버스 2X 코스닥 150 선물 ETN		~~~SKIP!!!
# [397]DAISHIN343 K200		~~~SKIP!!!
# [398]KIWOOM 통안채1년		~~~SKIP!!!
# [399]KODEX 200ESG		~~~SKIP!!!
# [400]ACE 5월만기자동연장회사채AA-이상액티브		~~~SKIP!!!
# [401]KODEX 미국러셀2000(H)		~~~SKIP!!!
# [402]KODEX 미국S&amp;P500금융		~~~SKIP!!!
# [403]1Q 미국메디컬AI		~~~SKIP!!!
# [404]삼성 미국 대형 가치주 ETN(H)		~~~SKIP!!!
# [405]삼성 레버리지 S&amp;P500 선물 ETN		~~~SKIP!!!
# [406]WON 미국S&amp;P500		~~~SKIP!!!
# [407]PLUS 글로벌방산		~~~SKIP!!!
# [408]DL이앤씨우		~~~SKIP!!!
# [409]KODEX 미국S&amp;P500산업재(합성)		~~~SKIP!!!
# [410]신한 인버스 2X WTI원유 선물 ETN(H)		~~~SKIP!!!
# [411]TIGER 차이나항셍테크레버리지(합성 H)		~~~SKIP!!!
# [412]유니드비티플러스(446070)		 start!!!
# [413]삼성 S&amp;P500 VIX S/T 선물 ETN B		~~~SKIP!!!
# [414]KODEX 차이나심천ChiNext(합성)		~~~SKIP!!!
# [415]PLUS 글로벌원자력밸류체인		~~~SKIP!!!
# [416]신한 구리 선물 ETN(H)		~~~SKIP!!!
# [417]SOL 팔란티어미국채커버드콜혼합		~~~SKIP!!!
# [418]HANARO 글로벌생성형AI액티브		~~~SKIP!!!
# [419]TIGER 구리실물		~~~SKIP!!!
# [420]한투 코스피 양매도 3% OTM ETN		~~~SKIP!!!
# [421]DL우		~~~SKIP!!!
# [422]한투 레버리지 은 선물 ETN		~~~SKIP!!!
# [423]삼성 China A50 선물 ETN(H)		~~~SKIP!!!
# [424]미래에셋 미국 방위산업 TOP3 ETN		~~~SKIP!!!
# [425]한익스프레스(014130)		 start!!!
# [426]RISE 컨택트대표		~~~SKIP!!!
# [427]계양전기(012200)		 start!!!
# [428]대림통상(006570)		 start!!!
# [429]RISE TDF2050액티브		~~~SKIP!!!
# [430]WON 국공채머니마켓액티브		~~~SKIP!!!
# [431]KODEX 건설		~~~SKIP!!!
# [432]N2 전력인프라 Top5 ETN		~~~SKIP!!!
# [433]ACE 미국배당퀄리티		~~~SKIP!!!
# [434]한솔PNS		~~~SKIP!!!
# [435]TIGER 200 헬스케어		~~~SKIP!!!
# [436]한화투자증권우		~~~SKIP!!!
# [437]부산주공(005030)		 start!!!
# [438]모나미(005360)		 start!!!
# [439]KoAct 팔란티어밸류체인액티브		~~~SKIP!!!
# [440]SOL 의료기기소부장Fn		~~~SKIP!!!
# [441]ACE 인도네시아MSCI(합성)		~~~SKIP!!!
# [442]N2 미국 IT TOP5 ETN(H)		~~~SKIP!!!
# [443]MH에탄올(023150)		 start!!!
# [444]KB 인버스 2X 천연가스 선물 ETN B		~~~SKIP!!!
# [445]KB 천연가스 선물 ETN(H)		~~~SKIP!!!
# [446]RISE 중국본토CSI300		~~~SKIP!!!
# [447]이엔플러스(074610)		 start!!!
# [448]HANARO Fn K-뉴딜디지털플러스		~~~SKIP!!!
# [449]한창제지(009460)		 start!!!
# [450]한세엠케이(069640)		 start!!!
# [451]주연테크(044380)		 start!!!
# [452]미래에셋 레버리지 미국 AI TOP3 ETN		~~~SKIP!!!
# [453]TIGER 반도체TOP10레버리지		~~~SKIP!!!
# [454]남성(004270)		 start!!!
# [455]TIGER 200 건설		~~~SKIP!!!
# [456]TIGER 게임TOP10		~~~SKIP!!!
# [457]TIGER 유로스탁스50(합성 H)		~~~SKIP!!!
# [458]신풍(002870)		 start!!!
# [459]KIWOOM 미국달러선물		~~~SKIP!!!
# [460]KB 일본 로보틱스 TOP 10 ETN		~~~SKIP!!!
# [461]핸즈코퍼레이션(143210)		 start!!!
# [462]온타이드(005320)		 start!!!
# [463]KODEX 미국S&amp;P500배당귀족커버드콜(합성 H)		~~~SKIP!!!
# [464]미래에셋 미국 자율주행대표기업 ETN		~~~SKIP!!!
# [465]에넥스(011090)		 start!!!
# [466]RISE 코리아금융고배당		~~~SKIP!!!
# [467]1Q 코리아밸류업		~~~SKIP!!!
# [468]KODEX 인도타타그룹		~~~SKIP!!!
# [469]한투 일본니케이225선물 ETN(H)		~~~SKIP!!!
# [470]체시스(033250)		 start!!!
# [471]대원화성(024890)		 start!!!
# [472]한성기업(003680)		 start!!!
# [473]KODEX 미국달러선물레버리지		~~~SKIP!!!
# [474]RISE 글로벌리얼티인컴		~~~SKIP!!!
# [475]FOCUS AI코리아액티브		~~~SKIP!!!
# [476]HANARO 32-10 국고채액티브		~~~SKIP!!!
# [477]이화산업(000760)		 start!!!
# [478]삼성 인버스 2X 나스닥 100 TR ETN		~~~SKIP!!!
# [479]대한방직(001070)		 start!!!
# [480]미래에셋 천연가스 선물 ETN B		~~~SKIP!!!
# [481]RISE 미국30년국채액티브		~~~SKIP!!!
# [482]비비안(002070)		 start!!!
# [483]한투 레버리지 천연가스 선물 ETN B		~~~SKIP!!!
# [484]PLUS 코리아밸류업		~~~SKIP!!!
# [485]메리츠 3X 레버리지 미국채10년 ETN		~~~SKIP!!!
# [486]SUN&amp;L		~~~SKIP!!!
# [487]하나 레버리지 코스닥150 선물 ETN		~~~SKIP!!!
# [488]RISE 팔란티어고정테크100		~~~SKIP!!!
# [489]RISE 미국반도체NYSE(H)		~~~SKIP!!!
# [490]한투 레버리지 코스닥150선물 ETN		~~~SKIP!!!
# [491]KODEX 미국부동산리츠(H)		~~~SKIP!!!
# [492]한국전자홀딩스(006200)		 start!!!
# [493]삼성 레버리지 코스닥150 선물 ETN		~~~SKIP!!!
# [494]세방우		~~~SKIP!!!
# [495]HANARO 전력설비투자		~~~SKIP!!!
# [496]KoAct 배당성장액티브		~~~SKIP!!!
# [497]RISE 미국AI테크액티브		~~~SKIP!!!
# [498]두산퓨얼셀2우B		~~~SKIP!!!
# [499]KIWOOM 국고채10년레버리지		~~~SKIP!!!
# [500]메리츠 레버리지 은 선물 ETN(H)		~~~SKIP!!!
# [501]국보(001140)		 start!!!
# [502]세기상사(002420)		 start!!!
# [503]하나 블룸버그 -2X 천연가스 선물 ETN(H)		~~~SKIP!!!
# [504]KODEX 한국대만IT프리미어		~~~SKIP!!!
# [505]원림(005820)		 start!!!
# [506]동일제강(002690)		 start!!!
# [507]KODEX K방산TOP10레버리지		~~~SKIP!!!
# [508]삼성 iSelect 레버리지 조선 TOP10 TR ETN		~~~SKIP!!!
# [509]메리츠 블룸버그 -2X 천연가스 선물 ETN(H)		~~~SKIP!!!
# [510]메타랩스(090370)		 start!!!
# [511]N2 레버리지 은 선물 ETN(H)		~~~SKIP!!!
# [512]키움 레버리지 반도체TOP10 ETN		~~~SKIP!!!
# [513]N2 월간 레버리지 코스피 200 선물 ETN		~~~SKIP!!!
# [514]호텔신라우		~~~SKIP!!!
# [515]KODEX 차이나2차전지MSCI(합성)		~~~SKIP!!!
# [516]SOL 미국배당다우존스2호		~~~SKIP!!!
# [517]KODEX 보험		~~~SKIP!!!
# [518]PLUS 미국단기회사채(AAA~A)		~~~SKIP!!!
# [519]삼성 코스닥 150 TR ETN		~~~SKIP!!!
# [520]TIGER 글로벌AI사이버보안		~~~SKIP!!!
# [521]PLUS 미국장기우량회사채		~~~SKIP!!!
# [522]PLUS 미국나스닥테크		~~~SKIP!!!
# [523]TIMEFOLIO K신재생에너지액티브		~~~SKIP!!!
# [524]메리츠 KAP 통안채 6개월 ETN		~~~SKIP!!!
# [525]경인전자(009140)		 start!!!
# [526]대신 S&amp;P 인버스 2X 천연가스 선물 ETN		~~~SKIP!!!
# [527]KIWOOM 독일DAX		~~~SKIP!!!
# [528]SOL KIS단기통안채		~~~SKIP!!!
# [529]WON 미국우주항공방산		~~~SKIP!!!
# [530]키움 INDXX 미국테크탑10 ETN		~~~SKIP!!!
# [531]KODEX 미국S&amp;P500테크놀로지		~~~SKIP!!!
# [532]SOL 국제금커버드콜액티브		~~~SKIP!!!
# [533]TIGER 코스닥150바이오테크		~~~SKIP!!!
# [534]솔루스첨단소재1우		~~~SKIP!!!
# [535]TIGER 200 금융		~~~SKIP!!!
# [536]KODEX 200롱코스닥150숏선물		~~~SKIP!!!
# [537]KODEX 3대농산물선물(H)		~~~SKIP!!!
# [538]HANARO 코리아밸류업		~~~SKIP!!!
# [539]신한 레버리지 미국달러 선물 ETN		~~~SKIP!!!
# [540]세우글로벌(013000)		 start!!!
# [541]미래에셋 레버리지 미국 방위산업 TOP3 ETN		~~~SKIP!!!
# [542]TIGER 인도니프티50레버리지(합성)		~~~SKIP!!!
# [543]미래에셋 인버스 2X 코스피200 선물 ETN		~~~SKIP!!!
# [544]TIGER 200IT레버리지		~~~SKIP!!!
# [545]메리츠 KAP 레버리지 일본 엔화 ETN		~~~SKIP!!!
# [546]DAISHIN343 AI반도체&amp;인프라액티브		~~~SKIP!!!
# [547]KODEX 구리선물(H)		~~~SKIP!!!
# [548]미래에셋 인버스 2X 옥수수 선물 ETN		~~~SKIP!!!
# [549]한투 레버리지 베트남 VN30 선물 ETN(H)		~~~SKIP!!!
# [550]한투 레버리지 플래티넘 선물 ETN		~~~SKIP!!!
# [551]KODEX 일본TOPIX100		~~~SKIP!!!
# [552]KIWOOM 국고채3년		~~~SKIP!!!
# [553]WISCOM(024070)		 start!!!
# [554]RISE 게임테마		~~~SKIP!!!
# [555]RISE 내수주플러스		~~~SKIP!!!
# [556]KIWOOM 미국S&amp;P500(H)		~~~SKIP!!!
# [557]HANARO 글로벌금채굴기업		~~~SKIP!!!
# [558]KB 레버리지 금 선물 ETN(H)		~~~SKIP!!!
# [559]TIGER 글로벌클라우드컴퓨팅INDXX		~~~SKIP!!!
# [560]TBH글로벌		~~~SKIP!!!
# [561]메리츠 레버리지 국채30년 ETN		~~~SKIP!!!
# [562]KODEX 유럽탄소배출권선물ICE(H)		~~~SKIP!!!
# [563]WON 미국빌리어네어		~~~SKIP!!!
# [564]TIGER 모멘텀		~~~SKIP!!!
# [565]KODEX 미국테크TOP3플러스		~~~SKIP!!!
# [566]WON 반도체밸류체인액티브		~~~SKIP!!!
# [567]KODEX TDF2060액티브		~~~SKIP!!!
# [568]KODEX 차이나AI테크액티브		~~~SKIP!!!
# [569]한투 블룸버그인버스2XWTI원유선물 ETN B		~~~SKIP!!!
# [570]N2 코스피 200 TR ETN		~~~SKIP!!!
# [571]이스타코(015020)		 start!!!
# [572]WON K-글로벌수급상위		~~~SKIP!!!
# [573]PLUS 미국S&amp;P500성장주		~~~SKIP!!!
# [574]SOL 전고체배터리&amp;실리콘음극재		~~~SKIP!!!
# [575]1Q 미국나스닥100		~~~SKIP!!!
# [576]삼성 코리아 밸류업 TR ETN		~~~SKIP!!!
# [577]동원수산(030720)		 start!!!
# [578]ACE 구글밸류체인액티브		~~~SKIP!!!
# [579]KODEX 33-06 국고채액티브		~~~SKIP!!!
# [580]KODEX 철강		~~~SKIP!!!
# [581]RISE 글로벌테크놀로지(합성 H)		~~~SKIP!!!
# [582]KB 일본 컨슈머 TOP 10 ETN		~~~SKIP!!!
# [583]KODEX 탄소효율그린뉴딜		~~~SKIP!!!
# [584]메리츠 인버스 2X 대표 농산물 선물 ETN(H)		~~~SKIP!!!
# [585]SOL 반도체전공정		~~~SKIP!!!
# [586]SOL 미국AI반도체칩메이커		~~~SKIP!!!
# [587]RISE 200선물레버리지		~~~SKIP!!!
# [588]ACE 일본TOPIX레버리지(H)		~~~SKIP!!!
# [589]SOL 코스닥150		~~~SKIP!!!
# [590]KODEX 일본부동산리츠(H)		~~~SKIP!!!
# [591]한투 레버리지 나스닥100 ETN B		~~~SKIP!!!
# [592]미래에셋 미국 제약 TOP3 ETN		~~~SKIP!!!
# [593]미래에셋 인버스 2X 원유선물혼합 ETN(H)		~~~SKIP!!!
# [594]한투 인버스2X일본니케이225선물 ETN(H)		~~~SKIP!!!
# [595]TIMEFOLIO 코리아밸류업액티브		~~~SKIP!!!
# [596]KODEX KRX300		~~~SKIP!!!
# [597]RISE AI반도체TOP10		~~~SKIP!!!
# [598]KODEX 미국금융테크액티브		~~~SKIP!!!
# [599]KODEX 에너지화학		~~~SKIP!!!
# [600]한창(005110)		 start!!!
# [601]TIGER 유로스탁스배당30		~~~SKIP!!!
# [602]대한항공우		~~~SKIP!!!
# [603]KIWOOM 글로벌AI반도체		~~~SKIP!!!
# [604]미래아이앤지(007120)		 start!!!
# [605]KODEX 미국S&amp;P500에너지(합성)		~~~SKIP!!!
# [606]TIGER AI코리아그로스액티브		~~~SKIP!!!
# [607]미래에셋 -2X 미국채울트라30년 선물 ETN		~~~SKIP!!!
# [608]ACE 코스닥150		~~~SKIP!!!
# [609]KODEX IT		~~~SKIP!!!
# [610]성문전자(014910)		 start!!!
# [611]키움 인버스 미국달러선물 ETN		~~~SKIP!!!
# [612]삼성 레버리지 일본니케이225선물 ETN(H)		~~~SKIP!!!
# [613]메리츠 레버리지 미국채30년 스트립 ETN(H)		~~~SKIP!!!
# [614]동성제약(002210)		 start!!!
# [615]ACE 미국10년국채액티브		~~~SKIP!!!
# [616]메리츠 미국채10년 ETN(H)		~~~SKIP!!!
# [617]KODEX 글로벌로봇(합성)		~~~SKIP!!!
# [618]하나 인버스 2X 옥수수 선물 ETN(H)		~~~SKIP!!!
# [619]KB 인디아 디지털 Select 5 ETN		~~~SKIP!!!
# [620]마이티 다이나믹퀀트액티브		~~~SKIP!!!
# [621]미래에셋 2X 미국 자율주행대표기업 ETN		~~~SKIP!!!
# [622]PLUS 코스피50		~~~SKIP!!!
# [623]태원물산(001420)		 start!!!
# [624]TIGER 200커버드콜		~~~SKIP!!!
# [625]KB 레버리지 항셍테크 선물 ETN(H) B		~~~SKIP!!!
# [626]RISE 중장기국공채액티브		~~~SKIP!!!
# [627]RISE 미국단기투자등급회사채액티브		~~~SKIP!!!
# [628]ACE BYD밸류체인액티브		~~~SKIP!!!
# [629]PLUS 200TR		~~~SKIP!!!
# [630]메리츠 인플레이션 국채 ETN		~~~SKIP!!!
# [631]롯데지주우		~~~SKIP!!!
# [632]TIGER 차이나AI소프트웨어		~~~SKIP!!!
# [633]미래에셋 S&amp;P500 VIX S/T 선물 ETN(H)		~~~SKIP!!!
# [634]대교우B		~~~SKIP!!!
# [635]KODEX 인도Nifty50레버리지(합성)		~~~SKIP!!!
# [636]KODEX 미국나스닥100선물인버스(H)		~~~SKIP!!!
# [637]N2 레버리지 코스닥150 선물 ETN		~~~SKIP!!!
# [638]TIGER 글로벌이노베이션액티브		~~~SKIP!!!
# [639]미래에셋 레버리지 은 선물 ETN B		~~~SKIP!!!
# [640]KODEX 차이나A50		~~~SKIP!!!
# [641]ACE ESG액티브		~~~SKIP!!!
# [642]KODEX 미국S&amp;P500액티브		~~~SKIP!!!
# [643]KB 레버리지 KOSPI 200 선물 ETN		~~~SKIP!!!
# [644]KODEX iShares미국투자등급회사채액티브		~~~SKIP!!!
# [645]신한 콩 선물 ETN(H)		~~~SKIP!!!
# [646]TIGER S&amp;P글로벌헬스케어(합성)		~~~SKIP!!!
# [647]KoAct 미국천연가스인프라액티브		~~~SKIP!!!
# [648]HK 200		~~~SKIP!!!
# [649]녹십자홀딩스2우		~~~SKIP!!!
# [650]미래에셋 코스피200 선물 ETN		~~~SKIP!!!
# [651]PLUS KOFR금리		~~~SKIP!!!
# [652]동양고속(084670)		 start!!!
# [653]KODEX 게임산업		~~~SKIP!!!
# [654]다이나믹디자인(145210)		 start!!!
# [655]KB CSI 500 ETN		~~~SKIP!!!
# [656]진도(088790)		 start!!!
# [657]KB CSI 300 ETN		~~~SKIP!!!
# [658]윌비스(008600)		 start!!!
# [659]TIGER 미국나스닥100ETF선물		~~~SKIP!!!
# [660]TIGER 미국AI반도체팹리스		~~~SKIP!!!
# [661]우진아이엔에스(010400)		 start!!!
# [662]한투 FTSE100 ETN		~~~SKIP!!!
# [663]한투 금 선물 ETN		~~~SKIP!!!
# [664]N2 미국달러 SOFR금리 플러스 ETN		~~~SKIP!!!
# [665]대상우		~~~SKIP!!!
# [666]코오롱우		~~~SKIP!!!
# [667]KODEX KRX300레버리지		~~~SKIP!!!
# [668]KIWOOM 미국성장기업30액티브		~~~SKIP!!!
# [669]한투 인버스일본니케이225선물 ETN(H)		~~~SKIP!!!
# [670]RISE 차이나HSCEI(H)		~~~SKIP!!!
# [671]BNK 주주가치액티브		~~~SKIP!!!
# [672]TIGER 미국달러선물인버스2X		~~~SKIP!!!
# [673]ACE 미국하이일드액티브(H)		~~~SKIP!!!
# [674]KIWOOM 한국고배당&amp;미국AI테크		~~~SKIP!!!
# [675]PLUS 선진국MSCI(합성 H)		~~~SKIP!!!
# [676]KODEX 테슬라밸류체인FactSet		~~~SKIP!!!
# [677]KCGI 미국S&amp;P500 TOP10		~~~SKIP!!!
# [678]TIGER 은행		~~~SKIP!!!
# [679]삼성 인버스 2X 구리 선물 ETN(H)		~~~SKIP!!!
# [680]KODEX 차이나과창판STAR50(합성)		~~~SKIP!!!
# [681]아센디오(012170)		 start!!!
# [682]에이엔피(015260)		 start!!!
# [683]ACE 일본Nikkei225(H)		~~~SKIP!!!
# [684]TIGER 미국방산TOP10		~~~SKIP!!!
# [685]KODEX WTI원유선물인버스(H)		~~~SKIP!!!
# [686]KIWOOM 팔란티어미국30년국채혼합액티브(H)		~~~SKIP!!!
# [687]ACE 미국달러단기채권액티브		~~~SKIP!!!
# [688]PLUS 미국S&amp;P500		~~~SKIP!!!
# [689]미래에셋 1.5X 천연가스 선물 ETN		~~~SKIP!!!
# [690]RISE 삼성그룹Top3채권혼합		~~~SKIP!!!
# [691]메리츠 솔랙티브 2X WTI원유 선물 ETN(H)		~~~SKIP!!!
# [692]한국주강(025890)		 start!!!
# [693]신한 33-12 국고채 플러스 ETN		~~~SKIP!!!
# [694]참엔지니어링(009310)		 start!!!
# [695]HANARO 글로벌피지컬AI액티브		~~~SKIP!!!
# [696]하나 S&amp;P 레버리지 WTI원유 선물 ETN B		~~~SKIP!!!
# [697]KB S&amp;P 레버리지 WTI원유 선물 ETN B		~~~SKIP!!!
# [698]삼성 블룸버그 레버리지 WTI원유선물 ETN B		~~~SKIP!!!
# [699]신한 블룸버그 레버리지 WTI원유선물 ETN B		~~~SKIP!!!
# [700]메리츠 국채10년 ETN		~~~SKIP!!!
# [701]SHD(001770)		 start!!!
# [702]KB 인디아 대형 성장주 Select 5 ETN		~~~SKIP!!!
# [703]PLUS 국채선물3년		~~~SKIP!!!
# [704]메리츠 -2X 천연가스 선물 ETN(H)		~~~SKIP!!!
# [705]넥센타이어1우B		~~~SKIP!!!
# [706]KB 인버스 2X 밀 선물 ETN		~~~SKIP!!!
# [707]하나 인버스 2X 천연가스 선물 ETN(H)		~~~SKIP!!!
# [708]SOL 국고채3년		~~~SKIP!!!
# [709]KODEX 53-09 국고채액티브		~~~SKIP!!!
# [710]신한 2X 26-05 공사채(AAA) ETN		~~~SKIP!!!
# [711]신한 2X 26-05 은행채(AAA) ETN		~~~SKIP!!!
# [712]신한 26-05 공사채(AAA) ETN		~~~SKIP!!!
# [713]신한 26-05 은행채(AAA) ETN		~~~SKIP!!!
# [714]키움 코스닥 150 TR ETN		~~~SKIP!!!
# [715]HANARO K고배당		~~~SKIP!!!
# [716]신한 인버스 옥수수 선물 ETN(H)		~~~SKIP!!!
# [717]미래에셋 코스닥150 선물 ETN		~~~SKIP!!!
# [718]N2 코스닥 150 TR ETN		~~~SKIP!!!
# [719]메리츠 인버스 국채3년 ETN		~~~SKIP!!!
# [720]ACE 마이크로소프트밸류체인액티브		~~~SKIP!!!
# [721]삼성 레버리지 미국다우존스 선물 ETN		~~~SKIP!!!
# [722]ACE 미국10년국채액티브(H)		~~~SKIP!!!
# [723]ACE FTSE WGBI Korea		~~~SKIP!!!
# [724]PLUS 애플채권혼합		~~~SKIP!!!
# [725]한투 레버리지 유로스탁스50 ETN(H) B		~~~SKIP!!!
# [726]파워 코스피100		~~~SKIP!!!
# [727]N2 선진국 1등주 ETN		~~~SKIP!!!
# [728]신한 금 선물 ETN		~~~SKIP!!!
# [729]코리아써우		~~~SKIP!!!
# [730]PLUS 글로벌희토류&amp;전략자원생산기업		~~~SKIP!!!
# [731]TIMEFOLIO 미국배당다우존스액티브		~~~SKIP!!!
# [732]하나 레버리지 콩 선물 ETN(H)		~~~SKIP!!!
# [733]에셋플러스 차이나일등기업포커스10액티브		~~~SKIP!!!
# [734]TIGER 200 에너지화학		~~~SKIP!!!
# [735]HANARO Fn K-푸드		~~~SKIP!!!
# [736]대덕전자1우		~~~SKIP!!!
# [737]한진칼우		~~~SKIP!!!
# [738]TIGER TSMC파운드리밸류체인		~~~SKIP!!!
# [739]N2 월간 레버리지 선진국 1등주 ETN		~~~SKIP!!!
# [740]KODEX S&amp;P글로벌인프라(합성)		~~~SKIP!!!
# [741]KODEX 인도Nifty미드캡100		~~~SKIP!!!
# [742]KB 레버리지 2차전지 TOP 10 TR ETN		~~~SKIP!!!
# [743]코아스(071950)		 start!!!
# [744]삼성 KRX 레버리지 2차전지 TOP10 TR ETN		~~~SKIP!!!
# [745]한투 인버스0.5X S&amp;P500 VIX S/T선물 ETN B		~~~SKIP!!!
# [746]삼성 금 선물 ETN(H)		~~~SKIP!!!
# [747]신한 레버리지 구리 선물 ETN		~~~SKIP!!!
# [748]TIGER 우선주		~~~SKIP!!!
# [749]PLUS 미국배당증가성장주데일리커버드콜		~~~SKIP!!!
# [750]UNICORN SK하이닉스밸류체인액티브		~~~SKIP!!!
# [751]PLUS 미국다우존스고배당주(합성 H)		~~~SKIP!!!
# [752]KODEX 코스피대형주		~~~SKIP!!!
# [753]메리츠 미국 인플레이션 국채 ETN(H)		~~~SKIP!!!
# [754]TIGER 차이나클린에너지SOLACTIVE		~~~SKIP!!!
# [755]삼성 인버스 2X 코스피200 선물 ETN		~~~SKIP!!!
# [756]ACE 레버리지		~~~SKIP!!!
# [757]HANARO 글로벌럭셔리S&amp;P(합성)		~~~SKIP!!!
# [758]메리츠 2X 천연가스 선물 ETN(H)		~~~SKIP!!!
# [759]한투 은 선물 ETN		~~~SKIP!!!
# [760]하나 레버리지 천연가스 선물 ETN(H)		~~~SKIP!!!
# [761]TIGER 원유선물Enhanced(H)		~~~SKIP!!!
# [762]PLUS 일본엔화초단기국채(합성)		~~~SKIP!!!
# [763]PLUS TDF2060액티브		~~~SKIP!!!
# [764]RISE 200고배당커버드콜ATM		~~~SKIP!!!
# [765]넥센우		~~~SKIP!!!
# [766]RISE 미국반도체NYSE		~~~SKIP!!!
# [767]LX하우시스우		~~~SKIP!!!
# [768]TIGER 리츠부동산인프라채권		~~~SKIP!!!
# [769]ACE 미국IT인터넷S&amp;P(합성 H)		~~~SKIP!!!
# [770]RISE 글로벌수소경제		~~~SKIP!!!
# [771]RISE 200금융		~~~SKIP!!!
# [772]KODEX 자율주행액티브		~~~SKIP!!!
# [773]KC그린홀딩스(009440)		 start!!!
# [774]RISE 바이오TOP10액티브		~~~SKIP!!!
# [775]하이트진로2우B		~~~SKIP!!!
# [776]KIWOOM 코스닥150		~~~SKIP!!!
# [777]TIGER 일본반도체FACTSET		~~~SKIP!!!
# [778]RISE 테슬라미국채타겟커버드콜혼합(합성)		~~~SKIP!!!
# [779]SOL 차이나육성산업액티브(합성)		~~~SKIP!!!
# [780]키움 조선TOP10 ETN		~~~SKIP!!!
# [781]삼성 인버스 2X 미국다우존스 선물 ETN		~~~SKIP!!!
# [782]PLUS 미국테크TOP10레버리지(합성)		~~~SKIP!!!
# [783]한투 레버리지 구리 선물 ETN		~~~SKIP!!!
# [784]ACE 아시아TOP50S&amp;P		~~~SKIP!!!
# [785]PLUS 국고채30년액티브		~~~SKIP!!!
# [786]에셋플러스 코리아플랫폼액티브		~~~SKIP!!!
# [787]RISE 글로벌주식분산액티브		~~~SKIP!!!
# [788]HANARO 코스닥150		~~~SKIP!!!
# [789]TRUSTON 코리아밸류업액티브		~~~SKIP!!!
# [790]삼성 항셍테크 TR ETN(H) B		~~~SKIP!!!
# [791]RISE 차이나항셍테크		~~~SKIP!!!
# [792]PLUS 글로벌수소&amp;차세대연료전지		~~~SKIP!!!
# [793]TIGER 코스닥150선물인버스		~~~SKIP!!!
# [794]KODEX 필수소비재		~~~SKIP!!!
# [795]KB 레버리지 KOSDAQ 150 선물 ETN		~~~SKIP!!!
# [796]PLUS 우량회사채50		~~~SKIP!!!
# [797]TIMEFOLIO 글로벌소비트렌드액티브		~~~SKIP!!!
# [798]TIGER 한중반도체(합성)		~~~SKIP!!!
# [799]SOL 미국S&amp;P500미국채혼합50		~~~SKIP!!!
# [800]삼성 S&amp;P500 TR ETN		~~~SKIP!!!
# [801]한국ANKOR유전(152550)		 start!!!
# ['152550_link', '152550', '152550', '152550', '152550_h_li', '152550_g_li']
# [801]한국ANKOR유전???????
# [802]RISE 미국고정배당우선증권		~~~SKIP!!!
# [803]VITA MZ소비액티브		~~~SKIP!!!
# [804]HANARO Fn전기&amp;수소차		~~~SKIP!!!
# [805]TIGER 글로벌멀티에셋TIF액티브		~~~SKIP!!!
# [806]KB 레버리지 은 선물 ETN(H)		~~~SKIP!!!
# [807]한투 일본종합상사TOP5 ETN		~~~SKIP!!!
# [808]RISE 채권혼합		~~~SKIP!!!
# [809]RISE 미국휴머노이드로봇		~~~SKIP!!!
# [810]RISE 미국S&amp;P배당킹		~~~SKIP!!!
# [811]대한제당우		~~~SKIP!!!
# [812]삼성 은 선물 ETN(H)		~~~SKIP!!!
# [813]KODEX 미국S&amp;P바이오(합성)		~~~SKIP!!!
# [814]ACE 차이나항셍테크		~~~SKIP!!!
# [815]RISE 미국S&amp;P원유생산기업(합성 H)		~~~SKIP!!!
# [816]미래에셋 인버스 2X 은 선물 ETN B		~~~SKIP!!!
# [817]TIGER 코스닥150IT		~~~SKIP!!!
# [818]메리츠 인버스 2X 미국채30년 ETN(H)		~~~SKIP!!!
# [819]파워 K-주주가치액티브		~~~SKIP!!!
# [820]스타에스엠리츠(204210)		 start!!!
# ['204210_link', '204210', '204210', '204210', '204210_h_li', '204210_g_li']
# [820]스타에스엠리츠???????
# [821]미래에셋 인버스 코스피200 선물 ETN		~~~SKIP!!!
# [822]ACE 미국배당퀄리티채권혼합50		~~~SKIP!!!
# [823]신한 인버스 코스피 200 선물 ETN		~~~SKIP!!!
# [824]신한 인버스 콩 선물 ETN(H)		~~~SKIP!!!
# [825]ACE 러시아MSCI(합성)		~~~SKIP!!!
# [826]RISE V&amp;S셀렉트밸류채권혼합		~~~SKIP!!!
# [827]N2 인버스 2X 코스닥150 선물 ETN		~~~SKIP!!!
# [828]ACE TDF2050액티브		~~~SKIP!!!
# [829]메리츠 솔랙티브 -2X WTI원유 선물 ETN(H)		~~~SKIP!!!
# [830]PLUS 태양광&amp;ESS		~~~SKIP!!!
# [831]KODEX 우량주		~~~SKIP!!!
# [832]PLUS 글로벌휴머노이드로봇액티브		~~~SKIP!!!
# [833]KIWOOM KRX100		~~~SKIP!!!
# [834]ACE 2차전지&amp;친환경차액티브		~~~SKIP!!!
# [835]KODEX 기계장비		~~~SKIP!!!
# [836]KIWOOM 25-09 미국채권(AA-이상)액티브		~~~SKIP!!!
# [837]KB 인버스 2X 콩 선물 ETN		~~~SKIP!!!
# [838]1Q 샤오미밸류체인액티브		~~~SKIP!!!
# [839]KODEX 200 중소형		~~~SKIP!!!
# [840]KODEX 200exTOP		~~~SKIP!!!
# [841]신한 옥수수 선물 ETN(H)		~~~SKIP!!!
# [842]PLUS 일본반도체소부장		~~~SKIP!!!
# [843]KIWOOM 200선물레버리지		~~~SKIP!!!
# [844]TIGER 리츠부동산인프라10채권혼합액티브		~~~SKIP!!!
# [845]RISE 헬스케어채권혼합		~~~SKIP!!!
# [846]TIGER KEDI혁신기업ESG30		~~~SKIP!!!
# [847]TRUSTON 주주가치액티브		~~~SKIP!!!
# [848]KODEX MSCI Korea		~~~SKIP!!!
# [849]신한 레버리지 Russell 2000 ETN		~~~SKIP!!!
# [850]RISE 5대그룹주		~~~SKIP!!!
# [851]메리츠 인버스 2X 미국채10년 ETN(H)		~~~SKIP!!!
# [852]ITF K-AI반도체코어테크		~~~SKIP!!!
# [853]KODEX 200가치저변동		~~~SKIP!!!
# [854]에셋플러스 글로벌일등기업포커스10액티브		~~~SKIP!!!
# [855]TIGER 퓨처모빌리티액티브		~~~SKIP!!!
# [856]TIGER K게임		~~~SKIP!!!
# [857]한투 S&amp;P500 VIX S/T선물 ETN(H) B		~~~SKIP!!!
# [858]메리츠 레버리지 구리 선물 ETN(H)		~~~SKIP!!!
# [859]신한 코스피 200 TR ETN		~~~SKIP!!!
# [860]N2 레버리지 구리 선물 ETN(H)		~~~SKIP!!!
# [861]삼성 레버리지 구리 선물 ETN(H)		~~~SKIP!!!
# [862]삼성 코스피 200 TR ETN		~~~SKIP!!!
# [863]신한 인버스 코스닥 150 선물 ETN		~~~SKIP!!!
# [864]ACE 멕시코MSCI(합성)		~~~SKIP!!!
# [865]하나 S&amp;P 인버스 2X WTI원유 선물 ETN B		~~~SKIP!!!
# [866]KB S&amp;P 인버스 2X WTI원유 선물 ETN B		~~~SKIP!!!
# [867]신한 블룸버그 인버스2X WTI원유선물 ETN B		~~~SKIP!!!
# [868]미래에셋 인버스 코스닥150 선물 ETN		~~~SKIP!!!
# [869]에셋플러스 글로벌대장장이액티브		~~~SKIP!!!
# [870]미래에셋 2X 미국채울트라30년 선물 ETN		~~~SKIP!!!
# [871]에셋플러스 코리아대장장이액티브		~~~SKIP!!!
# [872]ACE 코스피		~~~SKIP!!!
# [873]하나 반도체 ETN		~~~SKIP!!!
# [874]KODEX 모멘텀주		~~~SKIP!!!
# [875]ITF 200		~~~SKIP!!!
# [876]미래에셋 레버리지 미국 제약 TOP3 ETN		~~~SKIP!!!
# [877]솔루스첨단소재2우B		~~~SKIP!!!
# [878]KODEX 미국ETF산업Top10 Indxx		~~~SKIP!!!
# [879]HANARO 200 TOP10		~~~SKIP!!!
# [880]일정실업(008500)		 start!!!
# [881]TIGER 농산물선물Enhanced(H)		~~~SKIP!!!
# [882]미래에셋 S&amp;P 유럽탄소배출권 선물 ETN		~~~SKIP!!!
# [883]KODEX 유럽명품TOP10 STOXX		~~~SKIP!!!
# [884]SOL 반도체후공정		~~~SKIP!!!
# [885]RISE 배터리 리사이클링		~~~SKIP!!!
# [886]에이리츠(140910)		 start!!!
# ['140910_link', '140910', '140910', '140910', '140910_h_li', '140910_g_li']
# [886]에이리츠???????
# [887]ACE 중국과창판STAR50		~~~SKIP!!!
# [888]하나 인버스 2X 콩 선물 ETN(H)		~~~SKIP!!!
# [889]한투 베트남 VN30 선물 ETN(H)		~~~SKIP!!!
# [890]KODEX 코스닥글로벌		~~~SKIP!!!
# [891]PLUS 200선물레버리지		~~~SKIP!!!
# [892]HANARO 미국S&amp;P500		~~~SKIP!!!
# [893]RISE 중국MSCI China(H)		~~~SKIP!!!
# [894]1Q 차이나H(H)		~~~SKIP!!!
# [895]TIGER 글로벌자원생산기업(합성 H)		~~~SKIP!!!
# [896]RISE 테슬라고정테크100		~~~SKIP!!!
# [897]메리츠 인버스 미국채30년 ETN(H)		~~~SKIP!!!
# [898]KODEX 한중반도체(합성)		~~~SKIP!!!
# [899]RISE 차이나테크TOP10위클리타겟커버드콜		~~~SKIP!!!
# [900]PLUS K방산소부장		~~~SKIP!!!
# [901]PLUS 미국테크TOP10		~~~SKIP!!!
# [902]TIGER 코리아테크액티브		~~~SKIP!!!
# [903]한투 플래티넘 선물 ETN		~~~SKIP!!!
# [904]KODEX 웹툰&amp;드라마		~~~SKIP!!!
# [905]KB 블룸버그 레버리지 천연가스 선물 ETN		~~~SKIP!!!
# [906]키움 KPOP ETN		~~~SKIP!!!
# [907]TIGER 일본TOPIX(합성 H)		~~~SKIP!!!
# [908]삼성 나스닥 100 TR ETN		~~~SKIP!!!
# [909]TIGER 금은선물(H)		~~~SKIP!!!
# [910]삼양사우		~~~SKIP!!!
# [911]ACE 미국친환경그린테마INDXX		~~~SKIP!!!
# [912]마이티 코스피100		~~~SKIP!!!
# [913]KoAct 글로벌친환경전력인프라액티브		~~~SKIP!!!
# [914]RISE 200선물인버스2X		~~~SKIP!!!
# [915]메리츠 레버리지 멕시코 페소화 ETN		~~~SKIP!!!
# [916]삼성 iSelect 조선 TOP10 TR ETN		~~~SKIP!!!
# [917]NPC우		~~~SKIP!!!
# [918]RISE 유로스탁스50(H)		~~~SKIP!!!
# [919]대신 인버스 2X 코스닥 150 선물 ETN		~~~SKIP!!!
# [920]TREX 펀더멘탈 200		~~~SKIP!!!
# [921]메리츠 인버스 미국채10년 ETN(H)		~~~SKIP!!!
# [922]RISE 국채선물10년인버스		~~~SKIP!!!
# [923]TIGER 미국캐시카우100		~~~SKIP!!!
# [924]KODEX 미국S&amp;P500유틸리티		~~~SKIP!!!
# [925]KODEX 미국S&amp;P500필수소비재		~~~SKIP!!!
# [926]한투 인버스 2X 구리 선물 ETN		~~~SKIP!!!
# [927]SOL 국제금		~~~SKIP!!!
# [928]FOCUS ESG리더스		~~~SKIP!!!
# [929]에셋플러스 글로벌영에이지액티브		~~~SKIP!!!
# [930]KB 인버스 2X KOSDAQ 150 선물 ETN		~~~SKIP!!!
# [931]ACE 글로벌브랜드TOP10블룸버그		~~~SKIP!!!
# [932]KB 인버스 2X 나스닥 100 ETN		~~~SKIP!!!
# [933]TIGER 차이나항셍30		~~~SKIP!!!
# [934]HANARO Fn K-게임		~~~SKIP!!!
# [935]TIGER S&amp;P글로벌인프라(합성)		~~~SKIP!!!
# [936]KODEX 가치주		~~~SKIP!!!
# [937]LX홀딩스1우		~~~SKIP!!!
# [938]KODEX iShares미국인플레이션국채액티브		~~~SKIP!!!
# [939]한투 구리 선물 ETN		~~~SKIP!!!
# [940]HK 베스트일레븐액티브		~~~SKIP!!!
# [941]RISE 국채30년레버리지(합성)		~~~SKIP!!!
# [942]KODEX 미국S&amp;P500경기소비재		~~~SKIP!!!
# [943]ACE 미국중심중소형제조업		~~~SKIP!!!
# [944]KB STAR 50 ETN		~~~SKIP!!!
# [945]신한 인버스 2X 다우존스지수 선물 ETN(H)		~~~SKIP!!!
# [946]JW중외제약2우B		~~~SKIP!!!
# [947]ACE 애플밸류체인액티브		~~~SKIP!!!
# [948]ACE 국고채3년		~~~SKIP!!!
# [949]ACE 골드선물 레버리지(합성 H)		~~~SKIP!!!
# [950]마이티 바이오시밀러&amp;CDMO액티브		~~~SKIP!!!
# [951]RISE 국고채3년선물인버스		~~~SKIP!!!
# [952]한투 S&amp;P 인버스 2X 엔달러 선물 ETN(H)		~~~SKIP!!!
# [953]TIGER 코스피대형주		~~~SKIP!!!
# [954]메리츠 KAP 레버리지 중국 위안화 ETN		~~~SKIP!!!
# [955]KODEX 기후변화솔루션		~~~SKIP!!!
# [956]삼성 인버스 2X 일본니케이225선물 ETN(H)		~~~SKIP!!!
# [957]미래에셋 인도네시아 Top5 ETN		~~~SKIP!!!
# [958]신한 S&amp;P 레버리지 유로 선물 ETN(H)		~~~SKIP!!!
# [959]PLUS 미국S&amp;P500미국채혼합50액티브		~~~SKIP!!!
# [960]미래에셋 -2X 미국 AI TOP3 ETN		~~~SKIP!!!
# [961]HANARO KOFR금리액티브(합성)		~~~SKIP!!!
# [962]ACE 코리아밸류업		~~~SKIP!!!
# [963]KIWOOM 미국달러선물레버리지		~~~SKIP!!!
# [964]한투 블룸버그 인도네시아 대표원자재 ETN		~~~SKIP!!!
# [965]메리츠 3X 레버리지 국채10년 ETN		~~~SKIP!!!
# [966]KIWOOM 블루칩		~~~SKIP!!!
# [967]KODEX 대만테크고배당다우존스		~~~SKIP!!!
# [968]파워 고배당저변동성		~~~SKIP!!!
# [969]삼성 일본니케이225선물 ETN(H)		~~~SKIP!!!
# [970]메리츠 멕시코 페소화 ETN		~~~SKIP!!!
# [971]KIWOOM 물가채KIS		~~~SKIP!!!
# [972]ACE 삼성그룹동일가중		~~~SKIP!!!
# [973]PLUS 미국양자컴퓨팅TOP10		~~~SKIP!!!
# [974]메리츠 국채5년 ETN		~~~SKIP!!!
# [975]메리츠 3X 레버리지 국채5년 ETN		~~~SKIP!!!
# [976]신한 S&amp;P 유로 선물 ETN(H)		~~~SKIP!!!
# [977]한투 S&amp;P 유럽탄소배출권 선물 ETN(H)		~~~SKIP!!!
# [978]TIGER 이머징마켓MSCI레버리지(합성 H)		~~~SKIP!!!
# [979]메리츠 S&amp;P 유럽탄소배출권 선물 ETN(H)		~~~SKIP!!!
# [980]키움 레버리지 바이오TOP10 ETN		~~~SKIP!!!
# [981]메리츠 인버스 국채30년 ETN		~~~SKIP!!!
# [982]RISE 엔비디아고정테크100		~~~SKIP!!!
# [983]TIGER 탄소효율그린뉴딜		~~~SKIP!!!
# [984]에셋플러스 인도일등기업포커스20액티브		~~~SKIP!!!
# [985]대상홀딩스우		~~~SKIP!!!
# [986]KIWOOM 미국달러선물인버스2X		~~~SKIP!!!
# [987]메리츠 KAP 중국 위안화 ETN		~~~SKIP!!!
# [988]TIGER LG그룹+펀더멘털		~~~SKIP!!!
# [989]HANARO 바이오코리아액티브		~~~SKIP!!!
# [990]ACE 장기자산배분액티브		~~~SKIP!!!
# [991]메리츠 3X 레버리지 국채3년 ETN		~~~SKIP!!!
# [992]메리츠 국채3년 ETN		~~~SKIP!!!
# [993]KODEX 미국클린에너지나스닥		~~~SKIP!!!
# [994]KIWOOM 코스피100		~~~SKIP!!!
# [995]코오롱글로벌우		~~~SKIP!!!
# [996]KODEX 미국S&amp;P500커뮤니케이션		~~~SKIP!!!
# [997]TIGER MKF배당귀족		~~~SKIP!!!
# [998]KoAct 글로벌양자컴퓨팅액티브		~~~SKIP!!!
# [999]SOL KRX300		~~~SKIP!!!
# [1000]ACE 글로벌AI맞춤형반도체		~~~SKIP!!!
# [1001]신한 코스닥 150 TR ETN		~~~SKIP!!!
# [1002]PLUS 미국나스닥100미국채혼합50		~~~SKIP!!!
# [1003]RISE 테슬라애플아마존채권혼합		~~~SKIP!!!
# [1004]삼성 인버스 2X 금 선물 ETN(H)		~~~SKIP!!!
# [1005]KIWOOM 미국테크100월간목표헤지액티브		~~~SKIP!!!
# [1006]VITA 밸류알파액티브		~~~SKIP!!!
# [1007]PLUS 미국로보택시		~~~SKIP!!!
# [1008]메리츠 미국채10년 ETN		~~~SKIP!!!
# [1009]PLUS 차이나AI테크TOP10		~~~SKIP!!!
# [1010]TIGER KRX300		~~~SKIP!!!
# [1011]대신 천연가스 선물 ETN(H)		~~~SKIP!!!
# [1012]KODEX 아시아AI반도체exChina액티브		~~~SKIP!!!
# [1013]키움 레버리지 리츠부동산인프라 ETN		~~~SKIP!!!
# [1014]한투 레버리지국채30년 ETN		~~~SKIP!!!
# [1015]TIMEFOLIO K이노베이션액티브		~~~SKIP!!!
# [1016]삼성 중국 자동차 TOP5 TR ETN(H)		~~~SKIP!!!
# [1017]메리츠 인버스 2X 구리 선물 ETN(H)		~~~SKIP!!!
# [1018]KB 코스닥 150 TR ETN		~~~SKIP!!!
# [1019]KODEX 혁신기술테마액티브		~~~SKIP!!!
# [1020]N2 인버스 레버리지 구리 선물 ETN(H)		~~~SKIP!!!
# [1021]RISE 코리아밸류업위클리고정커버드콜		~~~SKIP!!!
# [1022]RISE 미국양자컴퓨팅		~~~SKIP!!!
# [1023]메리츠 솔랙티브 WTI원유 선물 ETN(H)		~~~SKIP!!!
# [1024]메리츠 미국채30년 ETN		~~~SKIP!!!
# [1025]RISE 중소형고배당		~~~SKIP!!!
# [1026]KB 미국채 10년 ETN		~~~SKIP!!!
# [1027]ACE TDF2030액티브		~~~SKIP!!!
# [1028]RISE TDF2040액티브		~~~SKIP!!!
# [1029]삼성 인버스 2X S&amp;P500 선물 ETN		~~~SKIP!!!
# [1030]삼성 구리 선물 ETN(H)		~~~SKIP!!!
# [1031]KB 레버리지 미국채 10년 ETN		~~~SKIP!!!
# [1032]HANARO 유럽방산		~~~SKIP!!!
# [1033]RISE 미국천연가스밸류체인		~~~SKIP!!!
# [1034]삼성 중국 AI 테크 TOP5 TR ETN(H)		~~~SKIP!!!
# [1035]미래에셋 레버리지 옥수수 선물 ETN		~~~SKIP!!!
# [1036]KoAct 브로드컴밸류체인액티브		~~~SKIP!!!
# [1037]유유제약1우		~~~SKIP!!!
# [1038]메리츠 인버스 국채10년 ETN		~~~SKIP!!!
# [1039]신한 레버리지 Russell 2000 ETN B		~~~SKIP!!!
# [1040]삼성 블룸버그 WTI원유 선물 ETN B		~~~SKIP!!!
# [1041]메리츠 CSI 300 ETN		~~~SKIP!!!
# [1042]키움 리츠부동산인프라 ETN		~~~SKIP!!!
# [1043]메리츠 KAP 일본 엔화 ETN		~~~SKIP!!!
# [1044]대신 밀 선물 ETN(H)		~~~SKIP!!!
# [1045]N2 레버리지 국채30년 ETN		~~~SKIP!!!
# [1046]RISE 미국은행TOP10		~~~SKIP!!!
# [1047]신한 S&amp;P 인버스 유로 선물 ETN(H)		~~~SKIP!!!
# [1048]덕성우		~~~SKIP!!!
# [1049]N2 레버리지 국채10년 ETN		~~~SKIP!!!
# [1050]더제이 중소형포커스액티브		~~~SKIP!!!
# [1051]ACE 인도시장대표BIG5그룹액티브		~~~SKIP!!!
# [1052]태양금속우		~~~SKIP!!!
# [1053]WON AI ESG액티브		~~~SKIP!!!
# [1054]KODEX 운송		~~~SKIP!!!
# [1055]PLUS 고배당저변동50		~~~SKIP!!!
# [1056]KB 레버리지 미국채 10년 선물 ETN		~~~SKIP!!!
# [1057]HK S&amp;P코리아로우볼		~~~SKIP!!!
# [1058]PLUS S&amp;P글로벌인프라		~~~SKIP!!!
# [1059]삼성 미국다우존스 TR ETN		~~~SKIP!!!
# [1060]HANARO 탄소효율그린뉴딜		~~~SKIP!!!
# [1061]한투 인버스 2X 일본 엔선물 ETN		~~~SKIP!!!
# [1062]메리츠 인도 루피화 ETN		~~~SKIP!!!
# [1063]KIWOOM K-테크TOP10		~~~SKIP!!!
# [1064]메리츠 인버스 3X 일본 국채 10년 ETN		~~~SKIP!!!
# [1065]TIGER 차이나CSI300인버스(합성)		~~~SKIP!!!
# [1066]N2 블룸버그 2X 천연가스 선물 ETN(H)		~~~SKIP!!!
# [1067]메리츠 레버리지 인도 루피화 ETN		~~~SKIP!!!
# [1068]대덕1우		~~~SKIP!!!
# [1069]미래에셋 -2X 미국 자율주행대표기업 ETN		~~~SKIP!!!
# [1070]메리츠 인버스 일본 국채 10년 ETN		~~~SKIP!!!
# [1071]메리츠 일본 국채 10년 ETN		~~~SKIP!!!
# [1072]메리츠 STAR 50 ETN		~~~SKIP!!!
# [1073]삼성 KRX 2차전지 TOP10 TR ETN		~~~SKIP!!!
# [1074]메리츠 KAP 인버스 2X 일본 엔화 ETN		~~~SKIP!!!
# [1075]메리츠 인버스 국채5년 ETN		~~~SKIP!!!
# [1076]KB 미국채 30년 ETN		~~~SKIP!!!
# [1077]메리츠 3X 레버리지 일본 국채 10년 ETN		~~~SKIP!!!
# [1078]RISE 주식혼합		~~~SKIP!!!
# [1079]빅솔론(093190)		 start!!!
# [1080]삼아제약(009300)		 start!!!
# [1081]FSN(214270)		 start!!!
# [1082]티에스아이(277880)		 start!!!
# [1083]DXVX(180400)		 start!!!
# [1084]리드코프(012700)		 start!!!
# [1085]인크레더블버즈(064090)		 start!!!
# [1086]제이아이테크(417500)		 start!!!
# [1087]켐트로스(220260)		 start!!!
# [1088]비엠티(086670)		 start!!!
# [1089]케이엔에스(432470)		 start!!!
# [1090]에스트래픽(234300)		 start!!!
# [1091]특수건설(026150)		 start!!!
# [1092]참좋은여행(094850)		 start!!!
# [1093]유아이엘(049520)		 start!!!
# [1094]테라젠이텍스(066700)		 start!!!
# [1095]우리손에프앤지(073560)		 start!!!
# [1096]세종텔레콤(036630)		 start!!!
# [1097]인성정보(033230)		 start!!!
# [1098]위닉스(044340)		 start!!!
# [1099]새로닉스(042600)		 start!!!
# [1100]안국약품(001540)		 start!!!
# [1101]에이텍(045660)		 start!!!
# [1102]SV인베스트먼트(289080)		 start!!!
# [1103]서원인텍(093920)		 start!!!
# [1104]지앤비에스 에코(382800)		 start!!!
# [1105]코스텍시스(355150)		 start!!!
# [1106]토마토시스템(393210)		 start!!!
# [1107]라온테크(232680)		 start!!!
# [1108]이녹스(088390)		 start!!!
# [1109]비아트론(141000)		 start!!!
# [1110]화일약품(061250)		 start!!!
# [1111]셀바스헬스케어(208370)		 start!!!
# [1112]크리스에프앤씨(110790)		 start!!!
# [1113]피앤에스로보틱스(460940)		 start!!!
# [1114]스톰테크(352090)		 start!!!
# [1115]코메론(049430)		 start!!!
# [1116]지에프씨생명과학(388610)		 start!!!
# [1117]에프앤가이드(064850)		 start!!!
# [1118]모베이스전자(012860)		 start!!!
# [1119]제이엔케이글로벌(126880)		 start!!!
# [1120]그래피(318060)		 start!!!
# [1121]대한뉴팜(054670)		 start!!!
# [1122]동아화성(041930)		 start!!!
# [1123]아모센스(357580)		 start!!!
# [1124]팬스타엔터프라이즈(054300)		 start!!!
# [1125]정상제이엘에스(040420)		 start!!!
# [1126]레이(228670)		 start!!!
# [1127]M83(476080)		 start!!!
# [1128]컴퍼니케이(307930)		 start!!!
# [1129]남화산업(111710)		 start!!!
# [1130]에스엠코어(007820)		 start!!!
# [1131]나노팀(417010)		 start!!!
# [1132]화성밸브(039610)		 start!!!
# [1133]레이언스(228850)		 start!!!
# [1134]와이엠텍(273640)		 start!!!
# [1135]공구우먼(366030)		 start!!!
# [1136]예스24(053280)		 start!!!
# [1137]유라테크(048430)		 start!!!
# [1138]메디아나(041920)		 start!!!
# [1139]제이씨현시스템(033320)		 start!!!
# [1140]KNN(058400)		 start!!!
# [1141]디케이락(105740)		 start!!!
# [1142]트루엔(417790)		 start!!!
# [1143]3S(060310)		 start!!!
# [1144]아스타(246720)		 start!!!
# [1145]네온테크(306620)		 start!!!
# [1146]율호(072770)		 start!!!
# [1147]씨피시스템(413630)		 start!!!
# [1148]이엘씨(041520)		 start!!!
# [1149]씨씨에스(066790)		 start!!!
# [1150]저스템(417840)		 start!!!
# [1151]인크로스(216050)		 start!!!
# [1152]HLB제넥스(187420)		 start!!!
# [1153]엔브이에이치코리아(067570)		 start!!!
# [1154]이닉스(452400)		 start!!!
# [1155]엔지켐생명과학(183490)		 start!!!
# [1156]베노티앤알(206400)		 start!!!
# [1157]블랙야크아이앤씨(478560)		 start!!!
# [1158]서플러스글로벌(140070)		 start!!!
# [1159]중앙백신(072020)		 start!!!
# [1160]코어라인소프트(384470)		 start!!!
# [1161]위더스제약(330350)		 start!!!
# [1162]대성창투(027830)		 start!!!
# [1163]키이스트(054780)		 start!!!
# [1164]서한(011370)		 start!!!
# [1165]하이로닉(149980)		 start!!!
# [1166]웨이브일렉트로(095270)		 start!!!
# [1167]부방(014470)		 start!!!
# [1168]삼보모터스(053700)		 start!!!
# [1169]티사이언티픽(057680)		 start!!!
# [1170]현대공업(170030)		 start!!!
# [1171]드림씨아이에스(223250)		 start!!!
# [1172]오르비텍(046120)		 start!!!
# [1173]대정화금(120240)		 start!!!
# [1174]창해에탄올(004650)		 start!!!
# [1175]대진첨단소재(393970)		 start!!!
# [1176]브이원텍(251630)		 start!!!
# [1177]옵티코어(380540)		 start!!!
# [1178]케이사인(192250)		 start!!!
# [1179]오리엔트정공(065500)		 start!!!
# [1179]오리엔트정공???????
# [1180]녹십자엠에스(142280)		 start!!!
# [1181]유성티엔에스(024800)		 start!!!
# [1182]중앙에너비스(000440)		 start!!!
# [1183]위드텍(348350)		 start!!!
# [1184]APS(054620)		 start!!!
# [1185]제로투세븐(159580)		 start!!!
# [1186]퀀타매트릭스(317690)		 start!!!
# [1187]광림(014200)		 start!!!
# [1188]LK삼양(225190)		 start!!!
# [1189]내츄럴엔도텍(168330)		 start!!!
# [1190]아티스트컴퍼니(321820)		 start!!!
# [1191]HC홈센타(060560)		 start!!!
# [1192]레이저옵텍(199550)		 start!!!
# [1193]제이피아이헬스케어(0010V0)		 start!!!
# !!!!!!1193]제이피아이헬스케어
# [1194]팅크웨어(084730)		 start!!!
# [1195]유비벨록스(089850)		 start!!!
# [1196]지오엘리먼트(311320)		 start!!!
# [1197]에르코스(435570)		 start!!!
# [1198]아이비김영(339950)		 start!!!
# [1199]SCL사이언스(246960)		 start!!!
# [1200]덴티스(261200)		 start!!!
# [1201]디바이스(187870)		 start!!!
# [1202]위너스(479960)		 start!!!
# [1203]폴라리스세원(234100)		 start!!!
# [1204]아이엠티(451220)		 start!!!
# [1205]키스트론(475430)		 start!!!
# [1206]아미노로직스(074430)		 start!!!
# [1207]나이스디앤비(130580)		 start!!!
# [1208]데이원컴퍼니(373160)		 start!!!
# [1209]HRS(036640)		 start!!!
# [1210]폴라리스AI파마(041910)		 start!!!
# [1211]에이스토리(241840)		 start!!!
# [1212]텔콘RF제약(200230)		 start!!!
# [1213]알에프텍(061040)		 start!!!
# [1214]정다운(208140)		 start!!!
# [1215]산돌(419120)		 start!!!
# [1216]와이랩(432430)		 start!!!
# [1217]셀바이오휴먼텍(318160)		 start!!!
# [1218]꿈비(407400)		 start!!!
# [1219]피엔케이피부임상연구센타(347740)		 start!!!
# [1220]데이타솔루션(263800)		 start!!!
# [1221]신신제약(002800)		 start!!!
# [1222]모비스(250060)		 start!!!
# [1223]메가터치(446540)		 start!!!
# [1224]신스틸(162300)		 start!!!
# [1225]피에스텍(002230)		 start!!!
# [1226]에이치시티(072990)		 start!!!
# [1227]세코닉스(053450)		 start!!!
# [1228]하이딥(365590)		 start!!!
# [1229]세원물산(024830)		 start!!!
# [1230]에이엘티(172670)		 start!!!
# [1231]위지트(036090)		 start!!!
# [1232]오파스넷(173130)		 start!!!
# [1233]한국첨단소재(062970)		 start!!!
# [1234]솔디펜스(215090)		 start!!!
# [1235]네오이뮨텍(950220)		 start!!!
# [1236]비트컴퓨터(032850)		 start!!!
# [1237]금강철강(053260)		 start!!!
# [1238]파워넷(037030)		 start!!!
# [1239]한국피아이엠(448900)		 start!!!
# [1240]센코(347000)		 start!!!
# [1241]에이프로(262260)		 start!!!
# [1242]소노스퀘어(007720)		 start!!!
# [1243]TJ미디어(032540)		 start!!!
# [1244]엠투엔(033310)		 start!!!
# [1245]SDN(099220)		 start!!!
# [1246]쎄크(081180)		 start!!!
# [1247]대창솔루션(096350)		 start!!!
# [1248]지놈앤컴퍼니(314130)		 start!!!
# [1249]아티스트스튜디오(200350)		 start!!!
# [1250]에스퓨얼셀(288620)		 start!!!
# [1251]서울리거(043710)		 start!!!
# [1252]제이엔비(452160)		 start!!!
# [1253]SKAI(357880)		 start!!!
# [1254]케이엔더블유(105330)		 start!!!
# [1255]코스맥스엔비티(222040)		 start!!!
# [1256]경남스틸(039240)		 start!!!
# [1257]지에스이(053050)		 start!!!
# [1258]지엘팜텍(204840)		 start!!!
# [1259]큐라클(365270)		 start!!!
# [1260]한국컴퓨터(054040)		 start!!!
# [1261]아이씨디(040910)		 start!!!
# [1262]우듬지팜(403490)		 start!!!
# [1263]라온피플(300120)		 start!!!
# [1264]엔투텍(227950)		 start!!!
# [1265]지아이텍(382480)		 start!!!
# [1266]세토피아(222810)		 start!!!
# [1267]팬젠(222110)		 start!!!
# [1268]아이큐어(175250)		 start!!!
# [1268]아이큐어???????
# [1269]티이엠씨씨엔에스(241790)		 start!!!
# [1270]엠오티(413390)		 start!!!
# [1271]알엔투테크놀로지(148250)		 start!!!
# [1272]모델솔루션(417970)		 start!!!
# [1273]위츠(459100)		 start!!!
# [1274]노브랜드(145170)		 start!!!
# [1275]제일엠앤에스(412540)		 start!!!
# [1276]영화테크(265560)		 start!!!
# [1277]JW신약(067290)		 start!!!
# [1278]스톤브릿지벤처스(330730)		 start!!!
# [1279]한국전자인증(041460)		 start!!!
# [1280]바이오스마트(038460)		 start!!!
# [1281]미래에셋드림스팩1호(442900)		 start!!!
# [1281]미래에셋드림스팩1호???????
# [1282]유니테크노(241690)		 start!!!
# [1283]에스넷(038680)		 start!!!
# [1284]자연과환경(043910)		 start!!!
# [1285]서울평가정보(036120)		 start!!!
# [1286]국순당(043650)		 start!!!
# [1287]제너셈(217190)		 start!!!
# [1288]바이젠셀(308080)		 start!!!
# [1289]오픈베이스(049480)		 start!!!
# [1290]한켐(457370)		 start!!!
# [1291]앱토크롬(109960)		 start!!!
# [1292]라이온켐텍(171120)		 start!!!
# [1293]제이씨케미칼(137950)		 start!!!
# [1294]iMBC(052220)		 start!!!
# [1295]NPX(222160)		 start!!!
# [1296]동방선기(099410)		 start!!!
# [1297]강동씨앤엘(198440)		 start!!!
# [1298]재영솔루텍(049630)		 start!!!
# [1299]엔에스이엔엠(078860)		 start!!!
# [1300]성도이엔지(037350)		 start!!!
# [1301]한국가구(004590)		 start!!!
# [1302]삼양케이씨아이(036670)		 start!!!
# [1303]진양제약(007370)		 start!!!
# [1304]선바이오(067370)		 start!!!
# [1305]예림당(036000)		 start!!!
# [1306]피제이전자(006140)		 start!!!
# [1307]세아메카닉스(396300)		 start!!!
# [1308]모베이스(101330)		 start!!!
# [1309]시공테크(020710)		 start!!!
# [1310]아진엑스텍(059120)		 start!!!
# [1311]린드먼아시아(277070)		 start!!!
# [1312]에이아이코리아(364950)		 start!!!
# [1313]우리산업(215360)		 start!!!
# [1314]유니크(011320)		 start!!!
# [1315]동일스틸럭스(023790)		 start!!!
# [1316]토탈소프트(045340)		 start!!!
# [1317]제노레이(122310)		 start!!!
# [1318]아크솔루션스(203690)		 start!!!
# [1319]이노메트리(302430)		 start!!!
# [1320]크라우드웍스(355390)		 start!!!
# [1321]HLB파나진(046210)		 start!!!
# [1322]민테크(452200)		 start!!!
# [1323]옵티팜(153710)		 start!!!
# [1324]링네트(042500)		 start!!!
# [1325]해성에어로보틱스(059270)		 start!!!
# [1326]화인써키트(127980)		 start!!!
# [1327]한울반도체(320000)		 start!!!
# [1328]성호전자(043260)		 start!!!
# [1329]큐라티스(348080)		 start!!!
# [1330]일신바이오(068330)		 start!!!
# [1331]파로스아이바이오(388870)		 start!!!
# [1332]티플랙스(081150)		 start!!!
# [1333]SM Life Design(063440)		 start!!!
# [1334]우양(103840)		 start!!!
# [1335]에너토크(019990)		 start!!!
# [1336]뱅크웨어글로벌(199480)		 start!!!
# [1337]엔시스(333620)		 start!!!
# [1338]크레오에스지(040350)		 start!!!
# [1339]한울소재과학(091440)		 start!!!
# [1340]이삭엔지니어링(351330)		 start!!!
# [1341]차백신연구소(261780)		 start!!!
# [1342]셀로맥스사이언스(471820)		 start!!!
# [1343]신일제약(012790)		 start!!!
# [1344]유라클(088340)		 start!!!
# [1345]SGC E&amp;C		~~~SKIP!!!
# [1346]우리넷(115440)		 start!!!
# [1347]동일금속(109860)		 start!!!
# [1348]러셀(217500)		 start!!!
# [1349]비투엔(307870)		 start!!!
# [1350]라이콤(388790)		 start!!!
# [1351]엘컴텍(037950)		 start!!!
# [1352]한싹(430690)		 start!!!
# [1353]큐에스아이(066310)		 start!!!
# [1354]사이냅소프트(466410)		 start!!!
# [1355]와이어블(065530)		 start!!!
# [1356]리튬포어스(073570)		 start!!!
# [1357]오리콤(010470)		 start!!!
# [1358]푸른기술(094940)		 start!!!
# [1359]흥국에프엔비(189980)		 start!!!
# [1360]동아엘텍(088130)		 start!!!
# [1361]한일단조(024740)		 start!!!
# [1362]덕우전자(263600)		 start!!!
# [1363]NEW(160550)		 start!!!
# [1364]케이엘넷(039420)		 start!!!
# [1365]오하임앤컴퍼니(309930)		 start!!!
# [1366]와이엠씨(155650)		 start!!!
# [1367]삼현철강(017480)		 start!!!
# [1368]그린플러스(186230)		 start!!!
# [1369]차이커뮤니케이션(351870)		 start!!!
# [1370]코데즈컴바인(047770)		 start!!!
# [1371]아이티센엔텍(010280)		 start!!!
# [1372]슈프리마에이치큐(094840)		 start!!!
# [1373]자이글(234920)		 start!!!
# [1374]아이엘(307180)		 start!!!
# [1375]다보링크(340360)		 start!!!
# [1376]가온그룹(078890)		 start!!!
# [1377]소마젠(950200)		 start!!!
# [1378]우림피티에스(101170)		 start!!!
# [1379]피제이메탈(128660)		 start!!!
# [1380]쓰리에이로직스(177900)		 start!!!
# [1381]모바일어플라이언스(087260)		 start!!!
# [1382]미래생명자원(218150)		 start!!!
# [1383]코렌텍(104540)		 start!!!
# [1384]코콤(015710)		 start!!!
# [1385]푸드웰(005670)		 start!!!
# [1386]서남(294630)		 start!!!
# [1387]아이진(185490)		 start!!!
# [1388]케이씨티(089150)		 start!!!
# [1389]수산아이앤티(050960)		 start!!!
# [1390]상지건설(042940)		 start!!!
# [1391]오아(342870)		 start!!!
# [1392]홈캐스트(064240)		 start!!!
# [1393]심플랫폼(444530)		 start!!!
# [1394]RF시스템즈(474610)		 start!!!
# [1395]더블유에스아이(299170)		 start!!!
# [1396]코디(080530)		 start!!!
# [1397]액토즈소프트(052790)		 start!!!
# [1398]테라사이언스(073640)		 start!!!
# [1399]모비데이즈(363260)		 start!!!
# [1400]수성웹툰(084180)		 start!!!
# [1401]티비씨(033830)		 start!!!
# [1402]디알젬(263690)		 start!!!
# [1403]아이에이(038880)		 start!!!
# [1404]지니너스(389030)		 start!!!
# [1405]알비더블유(361570)		 start!!!
# [1406]SGA솔루션즈(184230)		 start!!!
# [1407]네오오토(212560)		 start!!!
# [1408]아이디피(332370)		 start!!!
# [1409]사토시홀딩스(223310)		 start!!!
# [1410]옵트론텍(082210)		 start!!!
# [1411]알리코제약(260660)		 start!!!
# [1412]HLB펩(196300)		 start!!!
# [1413]KBI메탈(024840)		 start!!!
# [1414]KH 건설(226360)		 start!!!
# ...
# [1624]케이피엠테크(042040)		 start!!!
# [1625]엑시온그룹(069920)		 start!!!
# [1626]신라섬유(001000)		 start!!!
# [1627]E8(418620)		 start!!!
# [1628]애드바이오텍(179530)		 start!!!
# [1629]제이엠티(094970)		 start!!!
# [1630]CSA 코스믹(083660)		 start!!!
# [1631]NHN벅스(104200)		 start!!!
# [1632]EG(037370)		 start!!!
# [1633]파루(043200)		 start!!!
# [1634]경남제약(053950)		 start!!!
# [1635]PN풍년(024940)		 start!!!
# [1636]상신전자(263810)		 start!!!
# [1637]프롬바이오(377220)		 start!!!
# [1638]빛과전자(069540)		 start!!!
# [1639]시선AI(340810)		 start!!!
# [1640]코스나인(082660)		 start!!!
# [1641]인산가(277410)		 start!!!
# [1642]얼라인드(238120)		 start!!!
# [1643]휴엠앤씨(263920)		 start!!!
# [1644]그리티(204020)		 start!!!
# [1645]에쎈테크(043340)		 start!!!
# [1646]프리엠스(053160)		 start!!!
# [1647]케이이엠텍(106080)		 start!!!
# [1648]오션인더블유(052300)		 start!!!
# [1649]테크엘(064520)		 start!!!
# [1650]모아텍(033200)		 start!!!
# [1651]케이씨피드(025880)		 start!!!
# [1652]화신정공(126640)		 start!!!
# [1653]남화토건(091590)		 start!!!
# [1654]오픈놀(440320)		 start!!!
# [1655]리더스코스메틱(016100)		 start!!!
# [1656]메가엠디(133750)		 start!!!
# [1657]대창스틸(140520)		 start!!!
# [1658]오텍(067170)		 start!!!
# [1659]브레인즈컴퍼니(099390)		 start!!!
# [1660]파인디앤씨(049120)		 start!!!
# [1661]제이티(089790)		 start!!!
# [1662]파인메딕스(387570)		 start!!!
# [1662]파인메딕스???????
# [1663]유니온바이오메트릭스(203450)		 start!!!
# [1664]플레이위드(023770)		 start!!!
# [1665]디케이앤디(263020)		 start!!!
# [1666]국영지앤엠(006050)		 start!!!
# [1667]코맥스(036690)		 start!!!
# [1668]버넥트(438700)		 start!!!
# [1669]아이앤씨(052860)		 start!!!
# [1670]위즈코프(038620)		 start!!!
# [1671]제놀루션(225220)		 start!!!
# [1672]아이퀘스트(262840)		 start!!!
# [1673]오늘이엔엠(192410)		 start!!!
# [1674]아이빔테크놀로지(460470)		 start!!!
# [1675]티엔엔터테인먼트(131100)		 start!!!
# [1676]컬러레이(900310)		 start!!!
# [1677]아세아텍(050860)		 start!!!
# [1678]시큐레터(418250)		 start!!!
# [1679]백금T&amp;A		~~~SKIP!!!
# [1680]이루온(065440)		 start!!!
# [1681]코아시아씨엠(196450)		 start!!!
# [1682]엔젠바이오(354200)		 start!!!
# [1683]마니커에프앤지(195500)		 start!!!
# [1684]코리아에셋투자증권(190650)		 start!!!
# [1685]엠젠솔루션(032790)		 start!!!
# [1686]서연탑메탈(019770)		 start!!!
# [1687]KBG(318000)		 start!!!
# [1688]케이디켐(221980)		 start!!!
# [1689]네오티스(085910)		 start!!!
# [1690]YW(051390)		 start!!!
# [1691]폴라리스우노(114630)		 start!!!
# [1692]휴맥스(115160)		 start!!!
# [1693]힘스(238490)		 start!!!
# [1694]캡스톤파트너스(452300)		 start!!!
# [1695]앤디포스(238090)		 start!!!
# [1696]카티스(140430)		 start!!!
# [1697]하이즈항공(221840)		 start!!!
# [1698]헝셩그룹(900270)		 start!!!
# [1699]아이지넷(462980)		 start!!!
# [1700]티케이지애강(022220)		 start!!!
# [1701]오공(045060)		 start!!!
# [1702]넥사다이내믹스(351320)		 start!!!
# [1703]피델릭스(032580)		 start!!!
# [1704]진시스템(363250)		 start!!!
# [1705]동국알앤에스(075970)		 start!!!
# [1706]코셈(360350)		 start!!!
# [1707]아이즈비전(031310)		 start!!!
# [1708]삼일기업공사(002290)		 start!!!
# [1709]에이텀(355690)		 start!!!
# [1710]자비스(254120)		 start!!!
# [1711]핑거스토리(417180)		 start!!!
# [1712]와토스코리아(079000)		 start!!!
# [1713]비씨월드제약(200780)		 start!!!
# [1714]뉴온(123840)		 start!!!
# [1715]뷰티스킨(406820)		 start!!!
# [1716]휴네시온(290270)		 start!!!
# [1717]서진오토모티브(122690)		 start!!!
# [1718]기가레인(049080)		 start!!!
# [1719]쏘닉스(088280)		 start!!!
# [1720]케이엠(083550)		 start!!!
# [1721]벡트(457600)		 start!!!
# [1722]한국맥널티(222980)		 start!!!
# [1723]스페코(013810)		 start!!!
# [1724]원티드랩(376980)		 start!!!
# [1725]협진(138360)		 start!!!
# [1726]이원컴포텍(088290)		 start!!!
# [1727]엠아이큐브솔루션(373170)		 start!!!
# [1728]DGP(060900)		 start!!!
# [1729]아이씨에이치(368600)		 start!!!
# [1730]디티앤씨알오(383930)		 start!!!
# [1731]이노시뮬레이션(274400)		 start!!!
# [1732]캐스텍코리아(071850)		 start!!!
# [1733]파버나인(177830)		 start!!!
# [1734]빛샘전자(072950)		 start!!!
# [1735]에이루트(096690)		 start!!!
# [1736]성우전자(081580)		 start!!!
# [1737]윙스풋(335870)		 start!!!
# [1738]에스제이그룹(306040)		 start!!!
# [1739]에스에너지(095910)		 start!!!
# [1740]모비릭스(348030)		 start!!!
# [1741]셀루메드(049180)		 start!!!
# [1742]모코엠시스(333050)		 start!!!
# [1743]씨싸이트(109670)		 start!!!
# [1744]GH신소재(130500)		 start!!!
# [1745]파인텍(131760)		 start!!!
# [1746]KB오토시스(024120)		 start!!!
# [1747]오토앤(353590)		 start!!!
# [1748]아이크래프트(052460)		 start!!!
# [1749]모아데이타(288980)		 start!!!
# [1750]피엔티엠에스(257370)		 start!!!
# [1751]알파칩스(117670)		 start!!!
# [1752]글로본(019660)		 start!!!
# [1753]아이컴포넌트(059100)		 start!!!
# [1754]한창산업(079170)		 start!!!
# [1755]원바이오젠(307280)		 start!!!
# [1756]오디텍(080520)		 start!!!
# [1757]바른손(018700)		 start!!!
# [1758]한국큐빅(021650)		 start!!!
# [1759]신진에스엠(138070)		 start!!!
# [1760]프럼파스트(035200)		 start!!!
# [1761]신한제11호스팩(452980)		 start!!!
# [1761]신한제11호스팩???????
# [1762]쎄노텍(222420)		 start!!!
# [1763]플래티어(367000)		 start!!!
# [1764]피씨디렉트(051380)		 start!!!
# [1765]프리시젼바이오(335810)		 start!!!
# [1766]씨유메디칼(115480)		 start!!!
# [1767]체리부로(066360)		 start!!!
# [1768]대신정보통신(020180)		 start!!!
# [1769]에이치와이티씨(148930)		 start!!!
# [1770]진바이오텍(086060)		 start!!!
# [1771]루멘스(038060)		 start!!!
# [1772]DH오토리드(290120)		 start!!!
# [1773]ES큐브(050120)		 start!!!
# [1774]로스웰(900260)		 start!!!
# [1775]DH오토웨어(025440)		 start!!!
# [1776]더바이오메드(214610)		 start!!!
# [1777]케이쓰리아이(431190)		 start!!!
# [1778]삼진(032750)		 start!!!
# [1779]아시아경제(127710)		 start!!!
# [1780]엠브레인(169330)		 start!!!
# [1781]원일특강(012620)		 start!!!
# [1782]엑스큐어(070300)		 start!!!
# [1783]TPC(048770)		 start!!!
# [1784]나래나노텍(137080)		 start!!!
# [1785]포메탈(119500)		 start!!!
# [1786]서울제약(018680)		 start!!!
# [1787]NE능률(053290)		 start!!!
# [1788]우리이앤엘(153490)		 start!!!
# [1789]아이티아이즈(372800)		 start!!!
# [1790]동양파일(228340)		 start!!!
# [1791]유투바이오(221800)		 start!!!
# [1792]에스지헬스케어(398120)		 start!!!
# [1793]대동스틸(048470)		 start!!!
# [1794]피플바이오(304840)		 start!!!
# [1795]세화피앤씨(252500)		 start!!!
# [1796]애머릿지(900100)		 start!!!
# [1797]디에이테크놀로지(196490)		 start!!!
# [1798]대한과학(131220)		 start!!!
# [1799]신화콘텍(187270)		 start!!!
# [1800]이화공영(001840)		 start!!!
# [1801]카이노스메드(284620)		 start!!!
# [1802]엑셀세라퓨틱스(373110)		 start!!!
# [1803]조아제약(034940)		 start!!!
# [1804]셀피글로벌(068940)		 start!!!
# [1805]드림인사이트(362990)		 start!!!
# [1806]본느(226340)		 start!!!
# [1807]엠에프씨(432980)		 start!!!
# [1808]스코넥(276040)		 start!!!
# [1809]무림SP(001810)		 start!!!
# [1810]모헨즈(006920)		 start!!!
# [1811]오가닉티코스메틱(900300)		 start!!!
# [1812]누리플랜(069140)		 start!!!
# [1813]진영(285800)		 start!!!
# [1814]파인디지털(038950)		 start!!!
# [1815]에스에이티(060540)		 start!!!
# [1816]바른손이앤에이(035620)		 start!!!
# [1817]아이윈플러스(123010)		 start!!!
# [1818]이지트로닉스(377330)		 start!!!
# [1819]솔트웨어(328380)		 start!!!
# [1820]웰크론한텍(076080)		 start!!!
# [1821]멕아이씨에스(058110)		 start!!!
# [1822]동양에스텍(060380)		 start!!!
# [1823]아이윈(090150)		 start!!!
# [1824]넥스턴바이오(089140)		 start!!!
# [1825]나라셀라(405920)		 start!!!
# [1826]성창오토텍(080470)		 start!!!
# [1827]디티앤씨(187220)		 start!!!
# [1828]지니틱스(303030)		 start!!!
# [1829]정원엔시스(045510)		 start!!!
# [1830]디모아(016670)		 start!!!
# [1831]영우디에스피(143540)		 start!!!
# [1832]부스타(008470)		 start!!!
# [1833]에스앤더블류(103230)		 start!!!
# [1834]이씨에스(067010)		 start!!!
# [1835]시큐브(131090)		 start!!!
# [1836]키네마스터(139670)		 start!!!
# [1837]비피도(238200)		 start!!!
# [1838]플라즈맵(405000)		 start!!!
# [1839]이노룰스(296640)		 start!!!
# [1840]소프트캠프(258790)		 start!!!
# [1840]소프트캠프???????
# [1841]서산(079650)		 start!!!
# [1842]한울앤제주(276730)		 start!!!
# [1843]한빛소프트(047080)		 start!!!
# [1844]삼보산업(009620)		 start!!!
# [1845]아우딘퓨쳐스(227610)		 start!!!
# [1846]형지I&amp;C		~~~SKIP!!!
# [1847]유진테크놀로지(240600)		 start!!!
# [1848]성우테크론(045300)		 start!!!
# [1849]휴럼(353190)		 start!!!
# [1850]시지트로닉스(429270)		 start!!!
# [1851]한일화학(007770)		 start!!!
# [1852]팜스빌(318010)		 start!!!
# [1853]신원종합개발(017000)		 start!!!
# [1854]베셀(177350)		 start!!!
# [1855]알로이스(297570)		 start!!!
# [1856]배럴(267790)		 start!!!
# [1857]THE E&amp;M		~~~SKIP!!!
# [1858]캐리(313760)		 start!!!
# [1859]카스(016920)		 start!!!
# [1860]대호특수강(021040)		 start!!!
# [1861]압타머사이언스(291650)		 start!!!
# [1862]소프트센(032680)		 start!!!
# [1863]알티캐스트(085810)		 start!!!
# [1864]넥스트아이(137940)		 start!!!
# [1865]밸로프(331520)		 start!!!
# [1866]아이티센피엔에스(232830)		 start!!!
# [1867]케이바이오(038530)		 start!!!
# [1868]율촌(146060)		 start!!!
# [1869]대성미생물(036480)		 start!!!
# [1870]에스엘에스바이오(246250)		 start!!!
# [1871]서전기전(189860)		 start!!!
# [1872]큐로홀딩스(051780)		 start!!!
# [1873]엔에이치스팩29호(451700)		 start!!!
# [1873]엔에이치스팩29호???????
# [1874]피엠티(147760)		 start!!!
# [1875]풍강(093380)		 start!!!
# [1876]우정바이오(215380)		 start!!!
# [1877]피앤씨테크(237750)		 start!!!
# [1878]이미지스(115610)		 start!!!
# [1879]오스템(031510)		 start!!!
# [1880]윈하이텍(192390)		 start!!!
# [1881]링크드(193250)		 start!!!
# [1882]로지시스(067730)		 start!!!
# [1883]S&amp;K폴리텍		~~~SKIP!!!
# [1884]에프알텍(073540)		 start!!!
# [1885]아즈텍WB(032080)		 start!!!
# [1886]비스토스(419540)		 start!!!
# [1887]우리엔터프라이즈(037400)		 start!!!
# [1888]휴림에이텍(078590)		 start!!!
# [1889]케이웨더(068100)		 start!!!
# [1890]딜리(131180)		 start!!!
# [1891]캔버스엔(210120)		 start!!!
# [1892]한주라이트메탈(198940)		 start!!!
# [1893]에이에프더블류(312610)		 start!!!
# [1894]디와이디(219550)		 start!!!
# [1895]씨엔플러스(115530)		 start!!!
# [1896]포톤(208710)		 start!!!
# [1897]알파녹스(043100)		 start!!!
# [1898]우진비앤지(018620)		 start!!!
# [1899]유디엠텍(389680)		 start!!!
# [1900]세중(039310)		 start!!!
# [1901]아이톡시(052770)		 start!!!
# [1902]제이엠아이(033050)		 start!!!
# [1903]티에스넥스젠(043220)		 start!!!
# [1904]에스폴리텍(050760)		 start!!!
# [1905]전진바이오팜(110020)		 start!!!
# [1906]신시웨이(290560)		 start!!!
# [1907]선샤인푸드(217620)		 start!!!
# [1908]지란지교시큐리티(208350)		 start!!!
# [1909]기산텔레콤(035460)		 start!!!
# [1910]디지캡(197140)		 start!!!
# [1911]KB제27호스팩(464680)		 start!!!
# [1911]KB제27호스팩???????
# [1912]크린앤사이언스(045520)		 start!!!
# [1913]소니드(060230)		 start!!!
# [1914]디와이씨(310870)		 start!!!
# [1915]에코글로우(159910)		 start!!!
# [1916]디젠스(113810)		 start!!!
# [1917]신도기연(290520)		 start!!!
# [1918]한솔인티큐브(070590)		 start!!!
# [1919]셀레믹스(331920)		 start!!!
# [1920]에이치케이(044780)		 start!!!
# [1921]핀텔(291810)		 start!!!
# [1922]아시아종묘(154030)		 start!!!
# [1923]뉴인텍(012340)		 start!!!
# [1924]아이스크림에듀(289010)		 start!!!
# [1925]인콘(083640)		 start!!!
# [1926]해성옵틱스(076610)		 start!!!
# [1927]바이오인프라(199730)		 start!!!
# [1928]에스티오(098660)		 start!!!
# [1929]브이씨(365900)		 start!!!
# [1930]한국정보공학(039740)		 start!!!
# [1931]TS트릴리온(317240)		 start!!!
# [1932]젠큐릭스(229000)		 start!!!
# [1933]한탑(002680)		 start!!!
# [1934]인바이오(352940)		 start!!!
# [1935]네오리진(094860)		 start!!!
# [1936]세동(053060)		 start!!!
# [1937]글로벌에스엠(900070)		 start!!!
# [1938]인터엠(017250)		 start!!!
# [1939]BF랩스(139050)		 start!!!
# [1940]스타플렉스(115570)		 start!!!
# [1941]라닉스(317120)		 start!!!
# [1942]패션플랫폼(225590)		 start!!!
# [1943]메디앙스(014100)		 start!!!
# [1944]비츠로시스(054220)		 start!!!
# [1945]엑사이엔씨(054940)		 start!!!
# [1946]스튜디오산타클로스(204630)		 start!!!
# [1947]판타지오(032800)		 start!!!
# [1948]휴맥스홀딩스(028080)		 start!!!
# [1949]대산F&amp;B		~~~SKIP!!!
# [1950]세종메디칼(258830)		 start!!!
# [1951]빌리언스(044480)		 start!!!
# [1952]티피씨글로벌(130740)		 start!!!
# [1953]지엔코(065060)		 start!!!
# [1954]나노캠텍(091970)		 start!!!
# [1955]듀오백(073190)		 start!!!
# [1956]엔시트론(101400)		 start!!!
# [1957]삼일(032280)		 start!!!
# [1958]레이저쎌(412350)		 start!!!
# [1959]오에스피(368970)		 start!!!
# [1960]나노씨엠에스(247660)		 start!!!
# [1961]삼영에스앤씨(361670)		 start!!!
# [1962]엔피케이(048830)		 start!!!
# [1963]다산솔루에타(154040)		 start!!!
# [1964]원풍물산(008290)		 start!!!
# [1965]이엠앤아이(083470)		 start!!!
# [1966]한국유니온제약(080720)		 start!!!
# [1967]뉴보텍(060260)		 start!!!
# [1968]KD(044180)		 start!!!
# [1969]비유테크놀러지(230980)		 start!!!
# [1970]웹스(196700)		 start!!!
# [1971]이노진(344860)		 start!!!
# [1972]신라에스지(025870)		 start!!!
# [1973]알톤(123750)		 start!!!
# [1974]토박스코리아(215480)		 start!!!
# [1975]이퓨쳐(134060)		 start!!!
# [1976]삼진엘앤디(054090)		 start!!!
# [1977]에스에스알(275630)		 start!!!
# [1978]디지아이(043360)		 start!!!
# [1979]한국정밀기계(101680)		 start!!!
# [1980]유비온(084440)		 start!!!
# [1981]벨로크(424760)		 start!!!
# [1982]에스디시스템(121890)		 start!!!
# [1983]플루토스(019570)		 start!!!
# [1984]유안타제13호스팩(449020)		 start!!!
# [1984]유안타제13호스팩???????
# [1985]코이즈(121850)		 start!!!
# [1986]파인테크닉스(106240)		 start!!!
# [1987]에스아이리소스(065420)		 start!!!
# [1988]케이피티유(054410)		 start!!!
# [1989]엘디티(096870)		 start!!!
# [1990]세진티에스(067770)		 start!!!
# [1991]대동금속(020400)		 start!!!
# [1992]비엘팜텍(065170)		 start!!!
# [1993]이엘피(063760)		 start!!!
# [1994]대신밸런스제18호스팩(478780)		 start!!!
# [1994]대신밸런스제18호스팩???????
# [1995]육일씨엔에쓰(191410)		 start!!!
# [1996]국일신동(060480)		 start!!!
# [1997]씨엑스아이(900120)		 start!!!
# [1998]CS(065770)		 start!!!
# [1999]골드앤에스(035290)		 start!!!
# [2000]엔에이치스팩30호(466910)		 start!!!
# [2000]엔에이치스팩30호???????
# [2001]웰킵스하이텍(043590)		 start!!!
# [2002]케스피온(079190)		 start!!!
# [2003]세니젠(188260)		 start!!!
# [2004]비케이홀딩스(050090)		 start!!!
# [2005]케이엠제약(225430)		 start!!!
# [2006]광진실업(026910)		 start!!!
# [2007]이노인스트루먼트(215790)		 start!!!
# [2008]피씨엘(241820)		 start!!!
# [2009]유아이디(069330)		 start!!!
# [2010]미래에셋비전스팩4호(477380)		 start!!!
# [2010]미래에셋비전스팩4호???????
# [2011]하나28호스팩(454750)		 start!!!
# [2011]하나28호스팩???????
# [2012]미래에셋비전스팩7호(482680)		 start!!!
# [2012]미래에셋비전스팩7호???????
# [2013]한주에이알티(058450)		 start!!!
# [2014]노블엠앤비(106520)		 start!!!
# [2015]대신밸런스제16호스팩(457630)		 start!!!
# [2015]대신밸런스제16호스팩???????
# [2016]인베니아(079950)		 start!!!
# [2017]예선테크(250930)		 start!!!
# [2018]서울전자통신(027040)		 start!!!
# [2019]더코디(224060)		 start!!!
# [2020]에이치엠씨제7호스팩(477340)		 start!!!
# [2020]에이치엠씨제7호스팩???????
# [2021]앤씨앤(092600)		 start!!!
# [2022]스튜디오삼익(415380)		 start!!!
# [2023]하나30호스팩(469880)		 start!!!
# [2023]하나30호스팩???????
# [2024]삼성스팩10호(0044K0)		 start!!!
# !!!!!!2024]삼성스팩10호
# [2024]삼성스팩10호???????
# [2025]파커스(065690)		 start!!!
# [2026]퀀텀온(227100)		 start!!!
# [2027]디에이치엑스컴퍼니(031860)		 start!!!
# [2028]유안타제15호스팩(473050)		 start!!!
# [2028]유안타제15호스팩???????
# [2029]미래에셋비전스팩6호(478440)		 start!!!
# [2029]미래에셋비전스팩6호???????
# [2030]한국제15호스팩(479880)		 start!!!
# [2030]한국제15호스팩???????
# [2031]셀레스트라(352770)		 start!!!
# [2032]키움제11호스팩(489480)		 start!!!
# [2032]키움제11호스팩???????
# [2033]바이온(032980)		 start!!!
# [2034]엔에이치스팩31호(481890)		 start!!!
# [2034]엔에이치스팩31호???????
# [2035]드래곤플라이(030350)		 start!!!
# [2036]대신밸런스제17호스팩(471050)		 start!!!
# [2036]대신밸런스제17호스팩???????
# [2037]디비금융제13호스팩(489730)		 start!!!
# [2037]디비금융제13호스팩???????
# [2038]KB제29호스팩(478390)		 start!!!
# [2038]KB제29호스팩???????
# [2039]하나26호스팩(446750)		 start!!!
# [2039]하나26호스팩???????
# [2040]KB제32호스팩(0037T0)		 start!!!
# !!!!!!2040]KB제32호스팩
# [2040]KB제32호스팩???????
# [2041]메디콕스(054180)		 start!!!
# [2042]에이디칩스(054630)		 start!!!
# [2043]KB제31호스팩(492220)		 start!!!
# [2043]KB제31호스팩???????
# [2044]교보16호스팩(482520)		 start!!!
# [2044]교보16호스팩???????
# [2045]삼영이엔씨(065570)		 start!!!
# [2046]DB금융스팩12호		~~~SKIP!!!
# [2047]하나35호스팩(0041L0)		 start!!!
# !!!!!!2047]하나35호스팩
# [2048]대신밸런스제19호스팩(482690)		 start!!!
# [2048]대신밸런스제19호스팩???????
# [2049]하나27호스팩(448370)		 start!!!
# [2049]하나27호스팩???????
# [2050]장원테크(174880)		 start!!!
# [2051]신한제12호스팩(474660)		 start!!!
# [2051]신한제12호스팩???????
# [2052]스타코링크(060240)		 start!!!
# [2053]하나31호스팩(469900)		 start!!!
# [2053]하나31호스팩???????
# [2054]신한제14호스팩(487360)		 start!!!
# [2054]신한제14호스팩???????
# [2055]미래에셋비전스팩5호(477470)		 start!!!
# [2055]미래에셋비전스팩5호???????
# [2056]하나29호스팩(454640)		 start!!!
# [2056]하나29호스팩???????
# [2057]신한제16호스팩(496070)		 start!!!
# [2057]신한제16호스팩???????
# [2058]유안타제16호스팩(474490)		 start!!!
# [2058]유안타제16호스팩???????
# [2059]유안타제12호스팩(446150)		 start!!!
# [2059]유안타제12호스팩???????
# [2060]유안타제11호스팩(444920)		 start!!!
# [2060]유안타제11호스팩???????
# [2061]해성산업1우		~~~SKIP!!!
# [2062]상상인제4호스팩(452670)		 start!!!
# [2062]상상인제4호스팩???????
# [2063]KB제30호스팩(486630)		 start!!!
# [2063]KB제30호스팩???????
# [2064]유안타제17호스팩(493790)		 start!!!
# [2064]유안타제17호스팩???????
# [2065]디비금융제14호스팩(0004Y0)		 start!!!
# !!!!!!2065]디비금융제14호스팩
# [2065]디비금융제14호스팩???????
# [2066]교보17호스팩(489210)		 start!!!
# [2066]교보17호스팩???????
# [2067]미래에셋비전스팩3호(448830)		 start!!!
# [2067]미래에셋비전스팩3호???????
# [2068]하이제8호스팩(450050)		 start!!!
# [2068]하이제8호스팩???????
# [2069]한화플러스제4호스팩(455310)		 start!!!
# [2069]한화플러스제4호스팩???????
# [2070]에스케이증권제9호스팩		~~~SKIP!!!
# [2071]교보18호스팩(0041B0)		 start!!!
# !!!!!!2071]교보18호스팩
# [2071]교보18호스팩???????
# [2072]신영스팩10호(472220)		 start!!!
# [2072]신영스팩10호???????
# [2073]이베스트스팩6호(478110)		 start!!!
# [2073]이베스트스팩6호???????
# [2074]IBKS제22호스팩(448760)		 start!!!
# [2074]IBKS제22호스팩???????
# [2075]한화플러스제5호스팩(498390)		 start!!!
# [2075]한화플러스제5호스팩???????
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-3180540748.py in <cell line: 0>()
#     130             worksheet.write_url(row_num + 1, 0, url, string=name)  # col=0 → '종목명' 열
#     131
# --> 132     send_email(excelName)
#     133
#     134     print("##################################")
#
# /tmp/ipython-input-1104238764.py in send_email(file_name)
#      33
#      34     with open(filename, 'rb') as excel_file :
# ---> 35         attachment = MIMEApplication( excel_file.read() )
#      36         #첨부파일의 정보를 헤더로 추가
#      37         attachment.add_header('Content-Disposition','attachment', filename=file_name)
#
# NameError: name 'MIMEApplication' is not defined

# %%
excelName = '주식_정보_20250920.xlsx'
send_email(excelName)
# Out:
# 메일 전송 완료 ✅

# %%
# klist = fetch_krx_list()
# klist[klist['종목코드'] == '025530']
