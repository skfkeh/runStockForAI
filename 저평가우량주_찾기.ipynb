# %% [markdown]
# <a href="https://colab.research.google.com/github/skfkeh/runStockForAI/blob/main/%EC%A0%80%ED%8F%89%EA%B0%80%EC%9A%B0%EB%9F%89%EC%A3%BC_%EC%B0%BE%EA%B8%B0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## 사용방법
# 1. 분석하길 원하는 패턴을 선택한다.<br>
#   (1: 코스피/코스닥 전체, 2: 특정 종목만(엑셀 필요), 3: 테마별)
# 2. 패턴 선택
#   *   패턴 1 선택 시, 아래 셀에서 '1'로 넣는다.
#   *   패턴 2 선택 시, 아래 셀에서 '2'로 넣고 종목을 엑셀파일로 만들어 놓는다.
#   <br>양식은 다음과 같음.<br>
#    ![예시 스크린샷.png](data:image/png;base64,...)
#   *   패턴 3 선택 시, 아래 셀에서 '3'로 넣는다. -> 준비 중
# 2. 좌측탭 메뉴의 "폴더" 아이콘을 클릭하여, 만들어둔 엑셀파일을 업로드한다.
# 3. 업로드한 파일의 경로(path)를 복사하여, 아래 셀에 붙여넣는다.
# 4. 경로를 붙여넣었다면 상단 메뉴탭에 잇는 "모두 실행"을 눌러 전체 실행을 한다.

# %%
#### 원하는 패턴을 ▼ 여기에 숫자로 입력해주세요!!!
pattern =       1
##### 입력한 엑셀파일의 경로를 여기 ▼▼▼ 작은따옴표('') 안에 넣어주세요!!!
filePath = '/content/자동화댕 돌리기.xlsx'

# %%
####################
## 0.선언부        ##
####################
## dart 정보 가져오기
## 참고 사이트
## https://dart-fss.readthedocs.io/en/latest/dart_api.html
import pandas as pd
import requests
from bs4 import BeautifulSoup
import re
import math
import time

start = time.time() ## 시작시점

# !pip install dart-fss --quiet

## 하이퍼링크 추가용
# !pip install XlsxWriter --quiet

import dart_fss as dart
from datetime import datetime
from dateutil.relativedelta import relativedelta
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 148.0/148.0 kB 2.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 161.7/161.7 kB 8.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.7/5.7 MB 41.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 103.8/103.8 kB 6.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 175.3/175.3 kB 3.0 MB/s eta 0:00:00
# WARNING:fake_useragent:Error occurred during getting browser(s): random, but was suppressed with fallback.

# %%
####################
## 1.조회 종목 설정  ##
####################

## html 태그 제거하는 function
def cleanhtml(raw_html):
  cleanr = re.compile('<.*?>')
  cleantext = re.sub(cleanr, '', raw_html).replace('[','').replace(']','').replace(',','')
  return cleantext

## excel file 읽어오는 function
def read_excel(file_path):
    # excel 파일을 읽어 조회대상 기업을 리스트화
    df = pd.read_excel(file_path, header=None)
    # print(df.head())
    return df.iloc[:, 0]

def getStockListFromNaver():
    headers = {'User-Agent': 'Mozilla/5.0'}

    stock_list = []

    for stockInfo in range(2):
      if   stockInfo == 0: print(' $$$ 코스피 조회 시작 $$$ ')
      elif stockInfo == 1: print(' @@@ 코스닥 조회 시작 @@@ ')
#######
#######   코스닥 확인 필요 / ex, 16페이지, 참좋은여행 or 옵투스제약 등 안나옴
#######
      for page in range(1,50):
        URL = f'https://finance.naver.com/sise/sise_market_sum.naver?sosok={stockInfo}&page={page}'
        response = requests.get(URL, headers=headers)
        soup = BeautifulSoup(response.text, 'html.parser')

        ### 페이지 시작 및 확인
        pageChk = 0
        if (page%10) == 0: print('')
        print('page[' + str(page) + ']', end=" \t ")

        for i in range(2, 80):
          stockName = soup.select(f'#contentarea > div.box_type_l > table.type_2 > tbody > tr:nth-child({i}) > td:nth-child(2) > a')
          stockName = cleanhtml(str(stockName))
          stockTotalPrise = soup.select(f'#contentarea > div.box_type_l > table.type_2 > tbody > tr:nth-child({i}) > td:nth-child(7)')
          stockTotalPrise = cleanhtml(str(stockTotalPrise))

          if (stockName != '') or (stockTotalPrise != ''):
            ### 조회 중
            pageChk += 1
            # print(f'{stockName}: {stockTotalPrise} $$ {pageChk}')

            ### 시가총액 100~1100억 사이만 가져오면
            if (int(stockTotalPrise) >= 100) and (int(stockTotalPrise) <= 1100):
              stock_list.append(stockName) #(, stockTotalPrise)) # 시가총액까지 담는건 불필요

        ## 조회하는게 없으면 종료
        if pageChk == 0:
          if   stockInfo == 0: print('\n $$$ 코스피 조회 종료 $$$ ')
          elif stockInfo == 1: print('\n @@@ 코스닥 조회 종료 @@@ ')
          break

    return stock_list

# %%
corp_list = []
if pattern == 1:
  corp_list = getStockListFromNaver()
# Out:
#  $$$ 코스피 조회 시작 $$$
# page[1] 	 page[2] 	 page[3] 	 page[4] 	 page[5] 	 page[6] 	 page[7] 	 page[8] 	 page[9]
# page[10] 	 page[11] 	 page[12] 	 page[13] 	 page[14] 	 page[15] 	 page[16] 	 page[17] 	 page[18] 	 page[19]
# page[20] 	 page[21] 	 page[22] 	 page[23] 	 page[24] 	 page[25] 	 page[26] 	 page[27] 	 page[28] 	 page[29]
# page[30] 	 page[31] 	 page[32] 	 page[33] 	 page[34] 	 page[35] 	 page[36] 	 page[37] 	 page[38] 	 page[39]
# page[40] 	 page[41] 	 page[42] 	 page[43] 	 page[44] 	 page[45] 	 page[46] 	 page[47] 	 page[48] 	 page[49]
#  $$$ 코스피 조회 종료 $$$
#  @@@ 코스닥 조회 시작 @@@
# page[1] 	 page[2] 	 page[3] 	 page[4] 	 page[5] 	 page[6] 	 page[7] 	 page[8] 	 page[9]
# page[10] 	 page[11] 	 page[12] 	 page[13] 	 page[14] 	 page[15] 	 page[16] 	 page[17] 	 page[18] 	 page[19]
# page[20] 	 page[21] 	 page[22] 	 page[23] 	 page[24] 	 page[25] 	 page[26] 	 page[27] 	 page[28] 	 page[29]
# page[30] 	 page[31] 	 page[32] 	 page[33] 	 page[34] 	 page[35] 	 page[36] 	 page[37] 	 page[38]
#  @@@ 코스닥 조회 종료 @@@

# %%
corp_list = []
if pattern == 1:
  corp_list = getStockListFromNaver()
elif pattern == 2:
  corp_list = read_excel(filePath)

print('조회 종목 수 : ' + str(len(corp_list)))
# Out:
#  $$$ 코스피 조회 시작 $$$
# page[1] 	 page[2] 	 page[3] 	 page[4] 	 page[5] 	 page[6] 	 page[7] 	 page[8] 	 page[9]
# page[10] 	 page[11] 	 page[12] 	 page[13] 	 page[14] 	 page[15] 	 page[16] 	 page[17] 	 page[18] 	 page[19]
# page[20] 	 page[21] 	 page[22] 	 page[23] 	 page[24] 	 page[25] 	 page[26] 	 page[27] 	 page[28] 	 page[29]
# page[30] 	 page[31] 	 page[32] 	 page[33] 	 page[34] 	 page[35] 	 page[36] 	 page[37] 	 page[38] 	 page[39]
# page[40] 	 page[41] 	 page[42] 	 page[43] 	 page[44] 	 page[45] 	 page[46] 	 page[47] 	 page[48] 	 page[49]
#  $$$ 코스피 조회 종료 $$$
#  @@@ 코스닥 조회 시작 @@@
# page[1] 	 page[2] 	 page[3] 	 page[4] 	 page[5] 	 page[6] 	 page[7] 	 page[8] 	 page[9]
# page[10] 	 page[11] 	 page[12] 	 page[13] 	 page[14] 	 page[15] 	 page[16] 	 page[17] 	 page[18] 	 page[19]
# page[20] 	 page[21] 	 page[22] 	 page[23] 	 page[24] 	 page[25] 	 page[26] 	 page[27] 	 page[28] 	 page[29]
# page[30] 	 page[31] 	 page[32] 	 page[33] 	 page[34] 	 page[35] 	 page[36] 	 page[37] 	 page[38]
#  @@@ 코스닥 조회 종료 @@@
# 조회 종목 수 : 2106

# %%
#######################
## 2.dart 정보 조회하기 ##
#######################

# API 키 설정 (개발자 포털에서 발급받은 키로 교체)
api_key = '34862215a48286de874cbf0fee6ffbbecb793b24'
dart.set_api_key(api_key=api_key)

def check_capital_changes(start_date: str, end_date: str, corp_codes: list = None):
    """
    유상증자/무상감자 공시 확인 함수
    :param start_date: 검색 시작일 (YYYYMMDD)
    :param end_date: 검색 종료일 (YYYYMMDD)
    :param corp_codes: 특정 기업 검색시 사용(8자리 corp_code 리스트)
    :return: 검색 결과 DataFrame
    """
    # 공시 검색 조건 설정
    search_params = {
        'bgn_de': start_date,
        'end_de': end_date,
        # 'pblntf_detail_ty': ['A001', 'A002', 'A003'],  # 사업/반기/분기 보고서
        'page_count': 100  # 최대 100건까지 조회
    }

    if corp_codes:
        search_params['corp_code'] = corp_codes

    # 공시 검색 실행
    results = dart.filings.search(**search_params)

    # 결과 필터링
    capital_changes = []
    keywords = ['유상증자','무상감자','단기차입금','전환사채','교환사채','신주인수권부사채','전환청구권','교환청구권','부적정','채무보증','담보제공','횡령','배임','단기과열종목','금전대여']

    for report in results.report_list:
        if any(keyword in report.report_nm for keyword in keywords):
            capital_changes.append({
                # '회사명': report.corp_name,
                # '종목코드': report.corp_code,
                '공시일': report.rcept_dt,
                '보고서명': report.report_nm
            })
    return pd.DataFrame(capital_changes)
    # return capital_changes['공시일']+' / '+capital_changes['보고서명']

# %%
#############################################
## 3.종목코드를 가져오기 위해 한국거래소 정보 조회하기 ##
#############################################

chk_code = []

## 한국거래소 data import하여 상장된 기업의 종목 정보 가져오기
def fetch_krx_list():
    """
    한국거래소 KIND에서 상장회사 리스트 (회사명, 종목코드, 상장일) 가져오기
    """
    url = "https://kind.krx.co.kr/corpgeneral/corpList.do?method=download"
    headers = {
        "User-Agent": "Mozilla/5.0"
    }
    response = requests.get(url, headers=headers)
    response.raise_for_status()

    # 경고 무시
    # 이 옵션을 주석처리하면 종목코드와 상장일 col에서 경고 발생
    pd.set_option('mode.chained_assignment',  None)

    # response.text로 html을 읽고 pandas로 테이블 파싱
    tables = pd.read_html(response.text)
    df = tables[0]  # 첫 번째 테이블이 우리가 원하는 데이터

    # 필요한 열만 추리기
    df = df[['회사명', '종목코드']]

    # try:
    #   df['종목코드'] = df['종목코드'].apply(lambda x: f'{int(x):06d}')  # 종목코드 6자리 문자열
    # except:
    #   chk_code.append(df)
      # print('!!!!! ' + df['회사명'] + '(' + df['종목코드'] + ') 종목코드 확인 필요')
    # df['상장일'] = pd.to_datetime(df['상장일']).dt.strftime('%Y-%m-%d')  # 상장일 포맷 정리

    return df

# %%
## 항목 구분 체크 function
def check_stock_info(chk_var, chk_li):
  if chk_var == 'f':
    if float(chk_li) > 200.0:
      return False
  else:
    if (i > 0 for i in chk_li):
      return False
  return True

## main에서도 사용하기 위해 전역변수로 변경
now = datetime.now()

###############################
## 5.네이버 증권에서 종목정보 크롤링 ##
###############################
def get_stock_info(code):
  # 회사 이름 URL 인코딩
  url = f"https://finance.naver.com/item/main.nhn?code={code}"
  headers = {
      "User-Agent": "Mozilla/5.0"
  }

  response = requests.get(url, headers=headers)
  response.encoding = 'euc-kr'
  soup = BeautifulSoup(response.text, 'html.parser')
  err_list = []
  # 검색 결과 영역에서 주식 링크 찾기 (종목 코드 포함된 링크 찾기)
  link_tag = soup.select_one('#content > div.section.cop_analysis > div.sub_section > table > tbody')
  try:
      link_tag_li = link_tag.find_all("tr")
  except:
      link_tag_li = 'NA'
      err_list.append(str(code) + '_link')

  main_li = []  # 전체 output용
  title_li = [] # 파트 타이틀
  a_li = [] # 매출액
  b_li = [] # 영업이익
  c_li = [] # 당기순이익
  d_li = [] # 현재가
  e_li = [] # 재무제표 결과
  f_li = [] # 부채비율
  h_li = [] # 52주간 최고가
  g_li = [] # 최고가 대비
  i_li = [] # 특이사항
  j_li = [] # 시가총액

  # 내용 담는 용도
  tmp_a_li = []
  tmp_b_li = []
  tmp_c_li = []
  tmp_d_li = []
  tmp_e_li = []
  tmp_f_li = []
  tmp_g_li = []
  tmp_i_li = []

  for i in range(3):
    try:
      tmp_a_li.append(cleanhtml(link_tag_li[0].find_all('td')[i].text).replace('\n', '').replace('\t', '').replace(',', '')) if cleanhtml(link_tag_li[0].find_all('td')[i].text).replace('\n', '').replace('\t', '').replace(',', '') != '' else tmp_a_li.append('NA')
      tmp_b_li.append(cleanhtml(link_tag_li[1].find_all('td')[i].text).replace('\n', '').replace('\t', '').replace(',', '')) if cleanhtml(link_tag_li[1].find_all('td')[i].text).replace('\n', '').replace('\t', '').replace(',', '') != '' else tmp_b_li.append('NA')
      tmp_c_li.append(cleanhtml(link_tag_li[2].find_all('td')[i].text).replace('\n', '').replace('\t', '').replace(',', '')) if cleanhtml(link_tag_li[2].find_all('td')[i].text).replace('\n', '').replace('\t', '').replace(',', '') != '' else tmp_c_li.append('NA')
      tmp_f_li.append(cleanhtml(link_tag_li[6].find_all('td')[i].text).replace('\n', '').replace('\t', '').replace(',', '')) if cleanhtml(link_tag_li[6].find_all('td')[i].text).replace('\n', '').replace('\t', '').replace(',', '') != '' else tmp_f_li.append('NA')
    except:
      # print('!!!!!!!' + code)
      err_list.append(str(code))
      tmp_a_li.append('NA')
      tmp_b_li.append('NA')
      tmp_c_li.append('NA')
      tmp_f_li.append('NA')

  a_li.append(tmp_a_li) # 매출액
  b_li.append(tmp_b_li) # 영업이익
  c_li.append(tmp_c_li) # 당기순이익

  # 시가총액
  try:
      tmp_j_li = cleanhtml(soup.select_one('#_market_sum').text).strip().replace('\n', '').replace('\t', '').replace(',', '').replace('조', '')
  except:
      tmp_j_li = 'NA'
  j_li.append(tmp_j_li)

  # 종목 현재가
  try:
      tmp_d_li = cleanhtml(soup.select_one('#rate_info_krx > div > p.no_today > em.X > span.blind').text)
  except:
      try:
        tmp_d_li = cleanhtml(soup.select_one('#rate_info_krx > div > p.no_today > em.no_up > span.blind').text)
      except:
        try:
          tmp_d_li = cleanhtml(soup.select_one('#rate_info_krx > div > p.no_today > em.no_down > span.blind').text)
        except:
          tmp_d_li = 'NA'
          err_list.append(str(code) + '_now')
  d_li.append(tmp_d_li) # 현재가

  ############# 52주 최고가 왼쪽 : 재무제표 = 매출액, 영업이익, 당기순이익 모두 >0 & 부채비율<200
  chk_stock_status_val = 0
  for a in tmp_a_li:
    try:
      if a == 'NA' or a == '-' or a == '':
        break
      chk_stock_status_val += 1 if int(a) <= 0 else 0
    except:
      chk_stock_status_val += 1
  for b in tmp_b_li:
    try:
      if b == 'NA' or b == '-' or b == '':
        break
      chk_stock_status_val += 1 if int(b) <= 0 else 0
    except:
      chk_stock_status_val += 1
  for c in tmp_c_li:
    try:
      if c == 'NA'or c == '-' or c == '':
        break
      chk_stock_status_val += 1 if int(c) <= 0 else 0
    except:
      chk_stock_status_val += 1
  for f in tmp_f_li:
    # if f == 'NA':
    #   break
    if f == 'NA':
      continue
    elif float(f) > 200.0:
      chk_stock_status_val += 1

  tmp_e_li = 'X' if chk_stock_status_val > 0 else 'O'

  f_li.append(tmp_f_li) # 부채비율
  e_li.append(tmp_e_li) # 재무제표 결과


  #### g.현재가/52주 최고가 start ####
  high_52 = soup.select_one('#tab_con1 > div:nth-child(4) > table')
  try:
      high_52_li = high_52.find_all("em")
      h_li.append(cleanhtml(high_52_li[2].text))
  except:
      high_52_li = 'NA'
      err_list.append(str(code) + '_h_li')

  try:
      tmp_g_li = str(int(round(float(tmp_d_li.replace(',', ''))/float(h_li[0].replace(',', ''))*100, 0))) # 현재가/52주 최고가
      g_li.append(tmp_g_li) # 현재가/52주 최고가
  except:
      tmp_g_li = 'NA'
      err_list.append(str(code) + '_g_li')
  #### g.현재가/52주 최고가 end ####

  #### i.특이사항 start ####
  now_date = now.strftime('%Y%m%d')
  before_date = (now - relativedelta(years=5)).strftime('%Y%m%d')

  # try:
  tmp_i_li = check_capital_changes(before_date, now_date, code)

  if tmp_i_li.empty == True:
    tmp_i_li = 'O'
  i_li.append(tmp_i_li)
  #   i_li.append(tmp_i_li['공시일'] + ' / ' + tmp_i_li['보고서명']) # 특이사항
  # # except:
  # #     tmp_i_li = 'NA'
  # #     err_list.append(str(code) + '_i_li') ## df empty일 경우 모두 append 하므로 주석처리
  #### i.특이사항 end ####

  if len(err_list) > 0:
    print(err_list)

  return a_li[0], b_li[0], c_li[0], d_li, e_li, f_li[0], h_li, g_li, i_li, j_li

# %%
# ### KRX 상에 특수한 기업명으로 되어 있어 데이터를 못가져오는 경우 발생
abnormalStockList = {'KCC':'케이씨씨', 'KCTC':'케이씨티씨', '삼화페인트':'삼화페인트공업', '한국전력':'한국전력공사'}
def abnormalStockName(stockName):
  abnormalStockList = {'KCC':'케이씨씨', 'KCTC':'케이씨티씨', '삼화페인트':'삼화페인트공업', '한국전력':'한국전력공사'}
  if stockName in abnormalStockList.keys():
    return abnormalStockList[stockName]
  return None

# if 'KCC' in abnormalStockList.keys():
#   print(abnormalStockList['KCC'])

# %%
from email.mime.text import MIMEText
from email.mime.multipart import MIMEMultipart
from email.mime.application import MIMEApplication
import smtplib

def send_email(file_name):
    sender_email = "your_email" #"skfkeh0512@naver.com"
    receiver_email = "another email" #"skfkeh0512@naver.com"
    password = "your_password" # 앱 비밀번호

    # 메일 기본 정보
    message = MIMEMultipart()
    message["From"] = sender_email
    message["To"] = receiver_email
    message["Subject"] = file_name

    # 본문 작성
    body = """안녕하세요, '저평가 우량주 자동 발송' 시스템으로 발송된 메일입니다.
저평가우량주 주식 정보가 담겨있는 엑셀파일을 첨부했습니다.
함께 확인해 주세요!"""
    message.attach(MIMEText(body, "plain"))

    # 첨부파일 추가 (MIMEApplication 사용)
    file_path = "/content/" + file_name
    with open(file_path, "rb") as f:
        part = MIMEApplication(f.read(), _subtype="vnd.openxmlformats-officedocument.spreadsheetml.sheet")
        part.add_header("Content-Disposition", "attachment", filename=file_name)
        message.attach(part)

    try:
        with smtplib.SMTP("smtp.naver.com", 587) as server:
            server.starttls()
            server.login(sender_email, password)
            server.sendmail(sender_email, receiver_email, message.as_string())
        print("메일 전송 완료 ✅")
    except smtplib.SMTPAuthenticationError as e:
        print("인증 실패:", e)
    except Exception as e:
        print("오류 발생:", e)

# %%
if __name__ == "__main__":
    ### 파일명 변경될 수 있으므로 상단으로 옮김
    # corp_list = read_excel('/content/250602 코스피.xlsx')   # windows 기준

    # 한국거래소에 상장된 리스트 가져오기
    krx_list = fetch_krx_list()

    # dart 정보 가져오기
    # df_listed: 상장, df_non_listed: 비상장
    # df_listed, df_non_listed = dart_info()

    main_li = []
    for i in range(len(corp_list)):
      if corp_list[i].replace('*', '').strip() in abnormalStockList.keys():
        tmp_corp_name = corp_list[i]
        print(tmp_corp_name + '/' + corp_list[i])
        corp_list[i] = abnormalStockList[corp_list[i].replace('*', '').strip()]

      if corp_list[i].replace('*', '').strip() in krx_list['회사명'].values:
        if (corp_list[i] == '옵'):
          print("**********************")
        code = krx_list.loc[krx_list['회사명'] == corp_list[i].replace('*', '').strip(), '종목코드'].values[0]
        ##print('[' + str(i+1) + ']' + corp_list[i] + "(" + code + ")\t\t start!!!")
        try:
          df = get_stock_info(code)
        except:
          print('!!!!!!' + str(i+1) + ']' + corp_list[i])
        try:
          data = {
              '종목명': corp_list[i],
              '종목코드': code,
              '현재가': df[3][0],
              '시가총액': df[9][0],
              '매출액(2022)': df[0][0],
              '매출액(2023)': df[0][1],
              '매출액(2024)': df[0][2],
              '영업이익(2022)': df[1][0],
              '영업이익(2023)': df[1][1],
              '영업이익(2024)': df[1][2],
              '당기순이익(2022)': df[2][0],
              '당기순이익(2023)': df[2][1],
              '당기순이익(2024)': df[2][2],
              '부채비율(2022)': df[5][0],
              '부채비율(2023)': df[5][1],
              '부채비율(2024)': df[5][2],
              '재무제표': df[4][0],
              '전자공시': df[8][0],
              '52주 최고가': df[6][0],
              '최고가 대비': df[7][0],
              # PER: 시가총액 / 당기순이익(최근) : 소수점 첫째자리까지 (둘째자리에서 반올림)
              # PSR: 시가총액 / 매출액(최근) : 소수점 둘째자리까지 (셋째자리에서 반올림)
              'PER': round(int(df[9][0]) / int(df[2][2]), 1),
              'PSR': round(int(df[9][0]) / int(df[0][2]), 2)
          }

        except:
          print('[' + str(i+1) + ']' + corp_list[i] + '???????')
          data = {
              '종목명': corp_list[i],
              '종목코드': 'NA',
              '현재가': 'NA',
              '시가총액': 'NA',
              '매출액(2022)': 'NA',
              '매출액(2023)': 'NA',
              '매출액(2024)': 'NA',
              '영업이익(2022)': 'NA',
              '영업이익(2023)': 'NA',
              '영업이익(2024)': 'NA',
              '당기순이익(2022)': 'NA',
              '당기순이익(2023)': 'NA',
              '당기순이익(2024)': 'NA',
              '부채비율(2022)': 'NA',
              '부채비율(2023)': 'NA',
              '부채비율(2024)': 'NA',
              '재무제표': 'NA',
              '전자공시': 'NA',
              '52주 최고가': 'NA',
              '최고가 대비': 'NA',
              'PER': 'NA',
              'PSR': 'NA'
          }
        main_li.append(data)
      else:
        print('[' + str(i+1) + ']' + corp_list[i] + "\t\t~~~SKIP!!!")
        data = {
              '종목명': corp_list[i],
              '종목코드': 'NA',
              '현재가': 'NA',
              '시가총액': 'NA',
              '매출액(2022)': 'NA',
              '매출액(2023)': 'NA',
              '매출액(2024)': 'NA',
              '영업이익(2022)': 'NA',
              '영업이익(2023)': 'NA',
              '영업이익(2024)': 'NA',
              '당기순이익(2022)': 'NA',
              '당기순이익(2023)': 'NA',
              '당기순이익(2024)': 'NA',
              '부채비율(2022)': 'NA',
              '부채비율(2023)': 'NA',
              '부채비율(2024)': 'NA',
              '재무제표': 'NA',
              '전자공시': 'NA',
              '52주 최고가': 'NA',
              '최고가 대비': 'NA',
              'PER': 'NA',
              'PSR': 'NA'
          }
        main_li.append(data)
      # if i == 40:
      #   break
    main_df = pd.DataFrame(main_li)


    # hyperlinkInsert(main_df)
    # main_df.to_excel(f'주식_정보.xlsx', index=False)

    # 엑셀로 저장 (xlsxwriter 사용)
    excelName = '주식_정보_' + now.strftime("%Y%m%d") + '.xlsx'
    with pd.ExcelWriter(excelName, engine='xlsxwriter') as writer:
        main_df.to_excel(writer, sheet_name=now.strftime("%Y%m%d"), index=False, startrow=0)

        # 워크북과 시트 객체 얻기
        workbook  = writer.book
        worksheet = writer.sheets[now.strftime("%Y%m%d")]

        # 반복문으로 하이퍼링크 삽입 (row=2부터 데이터 시작)
        for row_num, (code, name) in enumerate(zip(main_df['종목코드'], main_df['종목명']), start=0):
            url = f"https://finance.naver.com/item/main.nhn?code={code}"
            worksheet.write_url(row_num + 1, 0, url, string=name)  # col=0 → '종목명' 열

    send_email(excelName)

    print("##################################")
    print("############## Done ##############")
    print("##################################")

    end = time.time()   ## 종료시점

    print(f"\n프로그램이 종료되었습니다.\n{int((end - start)/60)} 분 {int((end - start)%60)} 초 ({end - start:.5f} sec) 소요")
# Out:
# /tmp/ipython-input-624711923.py:24: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   tables = pd.read_html(response.text)
# [3]ACE 미국빅테크TOP7 Plus레버리지(합성)		~~~SKIP!!!
# [4]마이티 26-09 특수채(AAA)액티브		~~~SKIP!!!
# [5]BNK 26-06 특수채(AAA이상)액티브		~~~SKIP!!!
# [7]TIGER 차이나CSI300레버리지(합성)		~~~SKIP!!!
# [8]메리츠 미국채30년 ETN(H)		~~~SKIP!!!
# [9]세이브존I&amp;C		~~~SKIP!!!
# ['396690_link', '396690', '396690', '396690', '396690_h_li', '396690_g_li']
# [11]미래에셋글로벌리츠???????
# [12]신한 WTI원유 선물 ETN		~~~SKIP!!!
# [13]ACE 11월만기자동연장회사채AA-이상액티브		~~~SKIP!!!
# [15]삼성 인버스 2X 천연가스 선물 ETN D		~~~SKIP!!!
# [16]KODEX 코리아배당성장채권혼합		~~~SKIP!!!
# [18]ACE 우량회사채(AA-이상)액티브		~~~SKIP!!!
# [21]HANARO 종합채권(AA-이상)액티브		~~~SKIP!!!
# [22]TIMEFOLIO 코스피액티브		~~~SKIP!!!
# [24]KODEX 메타버스액티브		~~~SKIP!!!
# [25]삼성 레버리지 은 선물 ETN(H)		~~~SKIP!!!
# [28]TIGER 차이나반도체FACTSET		~~~SKIP!!!
# [29]TIGER 2차전지TOP10레버리지		~~~SKIP!!!
# [31]TIGER 리츠부동산인프라TOP10액티브		~~~SKIP!!!
# [37]RISE 대형고배당10TR		~~~SKIP!!!
# [39]KB 레버리지 나스닥 100 ETN		~~~SKIP!!!
# [41]TIGER 인터넷TOP10		~~~SKIP!!!
# [42]미래에셋 레버리지 코스피200 선물 ETN		~~~SKIP!!!
# [43]키움 레버리지 조선TOP10 ETN		~~~SKIP!!!
# [47]KIWOOM 단기채권ESG액티브		~~~SKIP!!!
# [49]삼성 레버리지 금 선물 ETN(H)		~~~SKIP!!!
# [54]TIGER 글로벌AI&amp;로보틱스 INDXX		~~~SKIP!!!
# [56]SOL CD금리&amp;머니마켓액티브		~~~SKIP!!!
# [60]KODEX 미국10년국채선물		~~~SKIP!!!
# [62]RISE 코스닥150선물레버리지		~~~SKIP!!!
# [63]TIGER 200선물레버리지		~~~SKIP!!!
# [64]SOL K방산		~~~SKIP!!!
# [65]SK우		~~~SKIP!!!
# [66]파워 200		~~~SKIP!!!
# [69]RISE 미국S&amp;P500(H)		~~~SKIP!!!
# ['338100_link', '338100', '338100', '338100', '338100_h_li', '338100_g_li']
# [71]NH프라임리츠???????
# [73]HL D&amp;I		~~~SKIP!!!
# [74]한투 인버스 2X 코스닥150선물 ETN		~~~SKIP!!!
# [75]TIGER 증권		~~~SKIP!!!
# [77]RISE 2차전지TOP10인버스(합성)		~~~SKIP!!!
# [78]KODEX TRF5050		~~~SKIP!!!
# [79]RISE 미국배당100데일리고정커버드콜		~~~SKIP!!!
# [81]TIGER 중국소비테마		~~~SKIP!!!
# [82]RISE 플랫폼테마		~~~SKIP!!!
# [84]KODEX 미국S&amp;P500변동성확대시커버드콜		~~~SKIP!!!
# [85]TIGER 차이나바이오테크SOLACTIVE		~~~SKIP!!!
# [86]두산퓨얼셀1우		~~~SKIP!!!
# [88]ACE 미국반도체데일리타겟커버드콜(합성)		~~~SKIP!!!
# [89]PLUS 코스피TR		~~~SKIP!!!
# [91]KODEX 미국나스닥AI테크액티브		~~~SKIP!!!
# [92]SK이노베이션우		~~~SKIP!!!
# [93]KODEX K원자력SMR		~~~SKIP!!!
# [94]ACE 포스코그룹포커스		~~~SKIP!!!
# [95]KODEX iShares미국하이일드액티브		~~~SKIP!!!
# [96]TIGER Fn메타버스		~~~SKIP!!!
# [100]TIGER AI반도체핵심공정		~~~SKIP!!!
# [101]RISE 고배당		~~~SKIP!!!
# [103]신한 레버리지 S&amp;P500 선물 ETN		~~~SKIP!!!
# [104]KODEX 차이나테크TOP10		~~~SKIP!!!
# [105]KODEX 헬스케어		~~~SKIP!!!
# [107]TIGER 글로벌4차산업혁신기술(합성 H)		~~~SKIP!!!
# [108]KB 레버리지 S&amp;P 500 선물 ETN(H)		~~~SKIP!!!
# [109]KB 블룸버그 인버스2X 천연가스선물 ETN(H)		~~~SKIP!!!
# [110]SOL 미국TOP5채권혼합40 Solactive		~~~SKIP!!!
# [113]KoAct K수출핵심기업TOP30액티브		~~~SKIP!!!
# [116]신한 레버리지 코스닥 150 선물 ETN		~~~SKIP!!!
# [119]PLUS 자사주매입고배당주		~~~SKIP!!!
# [120]TIGER 차이나전기차레버리지(합성)		~~~SKIP!!!
# [122]KoAct 글로벌AI&amp;로봇액티브		~~~SKIP!!!
# [124]PLUS 신흥국MSCI(합성 H)		~~~SKIP!!!
# [126]ACE 8월만기자동연장회사채AA-이상액티브		~~~SKIP!!!
# [127]ACE 주주환원가치주액티브		~~~SKIP!!!
# [128]RISE ESG사회책임투자		~~~SKIP!!!
# [131]SOL 미국S&amp;P500ESG		~~~SKIP!!!
# [132]신한 S&amp;P500 VIX S/T 선물 ETN E		~~~SKIP!!!
# [133]RISE 중국본토대형주CSI100		~~~SKIP!!!
# [134]한투 레버리지 금 선물 ETN		~~~SKIP!!!
# [135]부국증권우		~~~SKIP!!!
# [137]TIMEFOLIO 미국나스닥100채권혼합50액티브		~~~SKIP!!!
# [138]한투 인버스2X천연가스선물 ETN B		~~~SKIP!!!
# [139]ACE 미국30년국채선물레버리지(합성 H)		~~~SKIP!!!
# [141]GS우		~~~SKIP!!!
# [142]신한 WTI원유 선물 ETN(H)		~~~SKIP!!!
# [143]KODEX K콘텐츠		~~~SKIP!!!
# [144]TIGER 200선물인버스2X		~~~SKIP!!!
# [146]ACE 단기채권알파액티브		~~~SKIP!!!
# [147]IHQ		~~~SKIP!!!
# [148]TIGER 글로벌온디바이스AI		~~~SKIP!!!
# [149]태양금속		~~~SKIP!!!
# [152]ACE 원자력테마딥서치		~~~SKIP!!!
# [155]ACE 미국주식베스트셀러		~~~SKIP!!!
# [156]TIGER 현대차그룹+펀더멘털		~~~SKIP!!!
# [159]TIMEFOLIO K컬처액티브		~~~SKIP!!!
# [160]남양유업우		~~~SKIP!!!
# [162]KODEX 미국달러선물인버스		~~~SKIP!!!
# [163]KIWOOM 미국S&amp;P500		~~~SKIP!!!
# [167]RISE 버크셔포트폴리오TOP10		~~~SKIP!!!
# [169]HANARO 머니마켓액티브		~~~SKIP!!!
# [171]아모레퍼시픽홀딩스우		~~~SKIP!!!
# [173]KODEX TRF7030		~~~SKIP!!!
# [174]TIMEFOLIO 미국S&amp;P500액티브		~~~SKIP!!!
# [177]KODEX 국채선물10년		~~~SKIP!!!
# [178]KODEX 미국S&amp;P500버퍼3월액티브		~~~SKIP!!!
# [179]HANARO Fn K-POP&amp;미디어		~~~SKIP!!!
# [180]삼성 미국 대형 성장주 ETN		~~~SKIP!!!
# [182]KB Wise 분할매매 ETN		~~~SKIP!!!
# ['357250_link', '357250', '357250', '357250', '357250_h_li', '357250_g_li']
# [185]미래에셋맵스리츠???????
# [186]RISE 미국AI밸류체인TOP3Plus		~~~SKIP!!!
# [187]TIGER 차이나글로벌리더스TOP3+		~~~SKIP!!!
# [188]PLUS 미국S&amp;P500(H)		~~~SKIP!!!
# [189]KIWOOM 미국나스닥100(H)		~~~SKIP!!!
# [191]KODEX 미국AI소프트웨어TOP10		~~~SKIP!!!
# [192]WON 대한민국국고채액티브		~~~SKIP!!!
# [193]TIGER 미국배당다우존스타겟커버드콜1호		~~~SKIP!!!
# [194]RISE 5G테크		~~~SKIP!!!
# [197]미래에셋 인버스 2X 코스닥150 선물 ETN		~~~SKIP!!!
# [200]미래에셋 레버리지 KRX 금현물 ETN		~~~SKIP!!!
# [201]1Q 미국S&amp;P500미국채혼합50액티브		~~~SKIP!!!
# [202]PLUS 고배당주위클리고정커버드콜		~~~SKIP!!!
# [205]ACE 글로벌인컴TOP10 SOLACTIVE		~~~SKIP!!!
# [207]미래에셋 레버리지 코스닥150 선물 ETN		~~~SKIP!!!
# [208]HANARO CAPEX설비투자iSelect		~~~SKIP!!!
# [209]KODEX 코스피TR		~~~SKIP!!!
# [210]TIGER 미국나스닥바이오		~~~SKIP!!!
# [212]메리츠 KAP 통안채 3개월 ETN		~~~SKIP!!!
# [214]PLUS 미국채30년액티브		~~~SKIP!!!
# [215]TIGER 코스닥150 레버리지		~~~SKIP!!!
# [216]KODEX 글로벌비만치료제TOP2 Plus		~~~SKIP!!!
# [217]한투 레버리지일본니케이225선물 ETN(H)		~~~SKIP!!!
# [218]HANARO 200선물레버리지		~~~SKIP!!!
# [220]N2 레버리지 금 선물 ETN(H)		~~~SKIP!!!
# [221]KODEX 아시아달러채권ESG플러스액티브		~~~SKIP!!!
# [222]ACE 200TR		~~~SKIP!!!
# [223]TIGER 경기방어		~~~SKIP!!!
# [224]코오롱인더우		~~~SKIP!!!
# [225]삼성 KRX 금현물 ETN		~~~SKIP!!!
# [227]ACE 중장기국공채액티브		~~~SKIP!!!
# [228]메리츠 레버리지 금 선물 ETN(H)		~~~SKIP!!!
# [229]N2 방위산업 Top5 ETN		~~~SKIP!!!
# [230]KODEX WTI원유선물(H)		~~~SKIP!!!
# [232]TIGER 미국S&amp;P500레버리지(합성 H)		~~~SKIP!!!
# [236]서울식품		~~~SKIP!!!
# [237]KB 인버스 천연가스 선물 ETN		~~~SKIP!!!
# ['481850_link', '481850', '481850', '481850', '481850_h_li', '481850_g_li']
# [239]신한글로벌액티브리츠???????
# [240]TIGER 코스피고배당		~~~SKIP!!!
# [241]미래에셋 0.5X 코스피200 선물 ETN		~~~SKIP!!!
# [243]KODEX 친환경조선해운액티브		~~~SKIP!!!
# [245]SOL 자동차TOP3플러스		~~~SKIP!!!
# [246]KODEX Top10동일가중		~~~SKIP!!!
# [247]KIWOOM 코리아밸류업		~~~SKIP!!!
# [251]TIGER 글로벌비만치료제TOP2Plus		~~~SKIP!!!
# [252]한투 인버스2X 나스닥100 ETN B		~~~SKIP!!!
# [253]DL이앤씨2우(전환)		~~~SKIP!!!
# [254]에셋플러스 글로벌플랫폼액티브		~~~SKIP!!!
# [256]TIGER 레버리지		~~~SKIP!!!
# [257]KODEX 미국달러선물		~~~SKIP!!!
# [259]마이다스 코스피액티브		~~~SKIP!!!
# [260]키움 미국달러선물 ETN B		~~~SKIP!!!
# [263]KODEX TDF2040액티브		~~~SKIP!!!
# [264]삼화전자		~~~SKIP!!!
# [265]TIGER 일본엔선물		~~~SKIP!!!
# [266]하나 레버리지 반도체 ETN		~~~SKIP!!!
# [267]KODEX 코리아배당성장		~~~SKIP!!!
# [268]한화솔루션우		~~~SKIP!!!
# [269]키움 코스피 200 TR ETN		~~~SKIP!!!
# [270]하나 Solactive US Tech Top 10 ETN(H)		~~~SKIP!!!
# [273]KODEX TDF2030액티브		~~~SKIP!!!
# [276]KIWOOM 미국달러선물인버스		~~~SKIP!!!
# [277]삼성 인버스0.5X S&amp;P500 VIX S/T선물 ETN B		~~~SKIP!!!
# [281]삼성 미국 대형 성장주 ETN(H)		~~~SKIP!!!
# [282]HANARO K-뷰티		~~~SKIP!!!
# [283]HANARO e커머스		~~~SKIP!!!
# [284]메리츠 3X 레버리지 미국채30년 ETN		~~~SKIP!!!
# [286]RISE 미국30년국채커버드콜(합성)		~~~SKIP!!!
# [289]WON 종합채권(AA-이상)액티브		~~~SKIP!!!
# [290]아이엠에셋 200		~~~SKIP!!!
# [292]SJM		~~~SKIP!!!
# [293]TIGER 배당성장		~~~SKIP!!!
# [296]ACE AI반도체포커스		~~~SKIP!!!
# [297]신풍제약우		~~~SKIP!!!
# [299]신한 금 선물 ETN(H)		~~~SKIP!!!
# [300]KODEX 미국S&amp;P500버퍼6월액티브		~~~SKIP!!!
# [302]ACE 삼성그룹섹터가중		~~~SKIP!!!
# [303]TIGER Fn신재생에너지		~~~SKIP!!!
# [305]SK케미칼우		~~~SKIP!!!
# [306]미래에셋 0.5X 코스닥150 선물 ETN		~~~SKIP!!!
# [308]SOL 미국30년국채액티브(H)		~~~SKIP!!!
# [309]현대건설우		~~~SKIP!!!
# [310]미래에셋 미국 테크&amp;반도체 TOP3 ETN		~~~SKIP!!!
# [311]TIGER 엔비디아미국채커버드콜밸런스(합성)		~~~SKIP!!!
# [312]삼성 블룸버그 인버스2X WTI원유선물 ETN B		~~~SKIP!!!
# [313]SJM홀딩스		~~~SKIP!!!
# [314]TIGER 차이나HSCEI		~~~SKIP!!!
# [318]BYC우		~~~SKIP!!!
# [319]미래에셋 CAPE 실러 US Core Sector ETN		~~~SKIP!!!
# [320]KODEX 차이나H레버리지(H)		~~~SKIP!!!
# [321]신한 레버리지 다우존스지수 선물 ETN(H)		~~~SKIP!!!
# [324]WON 200		~~~SKIP!!!
# [326]롯데칠성우		~~~SKIP!!!
# [327]PLUS 우주항공&amp;UAM		~~~SKIP!!!
# [331]1Q 종합채권(AA-이상)액티브		~~~SKIP!!!
# [332]ACE 라이프자산주주가치액티브		~~~SKIP!!!
# [333]SOL 미국나스닥100		~~~SKIP!!!
# [334]ACE 인도컨슈머파워액티브		~~~SKIP!!!
# [335]삼성 미국 대형 가치주 ETN		~~~SKIP!!!
# [336]RISE 미국달러SOFR금리액티브(합성)		~~~SKIP!!!
# [339]KIWOOM 국고채30년액티브		~~~SKIP!!!
# [341]삼성 레버리지 나스닥 100 TR ETN		~~~SKIP!!!
# [342]KODEX 차이나H		~~~SKIP!!!
# [343]SOL 한국형글로벌반도체액티브		~~~SKIP!!!
# [344]미래에셋-0.5X S&amp;P500 VIX S/T선물 ETN(H)B		~~~SKIP!!!
# [345]신한 블룸버그 2X 천연가스 선물 ETN		~~~SKIP!!!
# [346]SOL 팔란티어미국채커버드콜혼합		~~~SKIP!!!
# [347]미래에셋 2X 미국 테크&amp;반도체 TOP3 ETN		~~~SKIP!!!
# [350]삼성 레버리지 코스피200 선물 ETN		~~~SKIP!!!
# [351]신한 레버리지 코스피 200 선물 ETN		~~~SKIP!!!
# [352]한투 레버리지 은 선물 ETN		~~~SKIP!!!
# [353]삼성 레버리지 항셍테크 TR ETN(H) B		~~~SKIP!!!
# [354]RISE 국고채3년		~~~SKIP!!!
# [355]SK디스커버리우		~~~SKIP!!!
# [356]RISE 2차전지TOP10		~~~SKIP!!!
# [357]미래에셋 인버스 천연가스 선물 ETN B		~~~SKIP!!!
# [359]신한 은 선물 ETN(H)		~~~SKIP!!!
# [361]KODEX 200IT TR		~~~SKIP!!!
# [362]SOL 코리아밸류업TR		~~~SKIP!!!
# [363]ACE 2월만기자동연장회사채AA-이상액티브		~~~SKIP!!!
# [364]미래에셋 -1.5X 천연가스 선물 ETN		~~~SKIP!!!
# [365]HANARO MSCI Korea TR		~~~SKIP!!!
# [366]KODEX K방산TOP10레버리지		~~~SKIP!!!
# [367]메리츠 레버리지 미국채30년 ETN(H)		~~~SKIP!!!
# [368]유안타증권우		~~~SKIP!!!
# [370]KIWOOM 고배당		~~~SKIP!!!
# [372]PLUS 단기채권액티브		~~~SKIP!!!
# [373]한투 블룸버그레버리지WTI원유선물 ETN B		~~~SKIP!!!
# [374]KODEX 미국S&amp;P500헬스케어		~~~SKIP!!!
# [375]TIGER 반도체TOP10레버리지		~~~SKIP!!!
# ['357430_link', '357430', '357430', '357430', '357430_h_li', '357430_g_li']
# [376]마스턴프리미어리츠???????
# [379]삼성 레버리지 China A50 선물 ETN(H)		~~~SKIP!!!
# ['145270_link', '145270', '145270', '145270', '145270_h_li', '145270_g_li']
# [381]케이탑리츠???????
# [383]ACE 미국배당퀄리티+커버드콜액티브		~~~SKIP!!!
# [384]PLUS 글로벌원자력밸류체인		~~~SKIP!!!
# [386]메리츠 국채30년 ETN		~~~SKIP!!!
# [387]SOL 의료기기소부장Fn		~~~SKIP!!!
# [388]유화증권우		~~~SKIP!!!
# [389]미래에셋 미국 AI TOP3 ETN		~~~SKIP!!!
# [390]KoAct 코리아밸류업액티브		~~~SKIP!!!
# [391]신한 인버스 2X 코스닥 150 선물 ETN		~~~SKIP!!!
# [394]RISE 금융채액티브		~~~SKIP!!!
# [395]미래에셋 2X 홍콩H 선물 ETN		~~~SKIP!!!
# [396]PLUS 국고채10년액티브		~~~SKIP!!!
# [397]진양폴리		~~~SKIP!!!
# [398]KIWOOM 통안채1년		~~~SKIP!!!
# [399]SOL 코리아고배당		~~~SKIP!!!
# [400]DAISHIN343 K200		~~~SKIP!!!
# [401]KODEX 차이나심천ChiNext(합성)		~~~SKIP!!!
# [402]한화투자증권우		~~~SKIP!!!
# [403]HANARO 글로벌생성형AI액티브		~~~SKIP!!!
# [404]KODEX 200ESG		~~~SKIP!!!
# [405]삼성 미국 대형 가치주 ETN(H)		~~~SKIP!!!
# [406]KODEX 미국러셀2000(H)		~~~SKIP!!!
# [408]KODEX 미국S&amp;P500금융		~~~SKIP!!!
# [409]TIGER 구리실물		~~~SKIP!!!
# [410]삼성 레버리지 S&amp;P500 선물 ETN		~~~SKIP!!!
# [411]ACE 5월만기자동연장회사채AA-이상액티브		~~~SKIP!!!
# [412]신한 구리 선물 ETN(H)		~~~SKIP!!!
# [413]KB 레버리지 FANG 플러스 ETN(H)		~~~SKIP!!!
# [415]WON K-글로벌수급상위		~~~SKIP!!!
# [416]1Q 미국메디컬AI		~~~SKIP!!!
# [417]TIGER 인버스		~~~SKIP!!!
# [418]RISE TDF2050액티브		~~~SKIP!!!
# [419]PLUS 글로벌방산		~~~SKIP!!!
# [420]KODEX 미국S&amp;P500산업재(합성)		~~~SKIP!!!
# [421]WON 미국S&amp;P500		~~~SKIP!!!
# [422]WON 반도체밸류체인액티브		~~~SKIP!!!
# [423]삼성 S&amp;P500 VIX S/T 선물 ETN B		~~~SKIP!!!
# [424]미래에셋 미국 방위산업 TOP3 ETN		~~~SKIP!!!
# [425]메리츠 레버리지 은 선물 ETN(H)		~~~SKIP!!!
# [426]ACE 글로벌자율주행액티브		~~~SKIP!!!
# [427]한투 레버리지 플래티넘 선물 ETN		~~~SKIP!!!
# [429]TIGER 차이나항셍테크레버리지(합성 H)		~~~SKIP!!!
# [430]N2 레버리지 은 선물 ETN(H)		~~~SKIP!!!
# [431]SOL 한국원자력SMR		~~~SKIP!!!
# [432]한투 코스피 양매도 3% OTM ETN		~~~SKIP!!!
# [433]KoAct 미국나스닥성장기업액티브		~~~SKIP!!!
# [434]DL이앤씨우		~~~SKIP!!!
# [436]KoAct 팔란티어밸류체인액티브		~~~SKIP!!!
# [438]삼성 China A50 선물 ETN(H)		~~~SKIP!!!
# [439]신한 인버스 2X WTI원유 선물 ETN(H)		~~~SKIP!!!
# [440]KB 인버스 2X 천연가스 선물 ETN B		~~~SKIP!!!
# [442]ACE 미국배당퀄리티		~~~SKIP!!!
# [443]DL우		~~~SKIP!!!
# [444]RISE 중국본토CSI300		~~~SKIP!!!
# [447]N2 미국 IT TOP5 ETN(H)		~~~SKIP!!!
# [448]RISE 컨택트대표		~~~SKIP!!!
# [450]HANARO 글로벌금채굴기업		~~~SKIP!!!
# [451]WON 국공채머니마켓액티브		~~~SKIP!!!
# [453]KODEX 건설		~~~SKIP!!!
# [456]ACE 인도네시아MSCI(합성)		~~~SKIP!!!
# [457]HANARO Fn K-뉴딜디지털플러스		~~~SKIP!!!
# [458]1Q 코리아밸류업		~~~SKIP!!!
# [459]KB 일본 로보틱스 TOP 10 ETN		~~~SKIP!!!
# [460]KB 천연가스 선물 ETN(H)		~~~SKIP!!!
# [461]TIGER 200 헬스케어		~~~SKIP!!!
# [462]미래에셋 레버리지 미국 AI TOP3 ETN		~~~SKIP!!!
# [463]미래에셋 미국 자율주행대표기업 ETN		~~~SKIP!!!
# [464]N2 전력인프라 Top5 ETN		~~~SKIP!!!
# [465]KIWOOM 미국달러선물		~~~SKIP!!!
# [466]RISE 팔란티어고정테크100		~~~SKIP!!!
# [467]TIGER 게임TOP10		~~~SKIP!!!
# [468]TIGER 유로스탁스50(합성 H)		~~~SKIP!!!
# [471]한투 일본니케이225선물 ETN(H)		~~~SKIP!!!
# [472]KODEX 미국S&amp;P500배당귀족커버드콜(합성 H)		~~~SKIP!!!
# [474]KODEX 차이나2차전지MSCI(합성)		~~~SKIP!!!
# [475]FOCUS AI코리아액티브		~~~SKIP!!!
# [477]TIGER 200타겟위클리커버드콜		~~~SKIP!!!
# [478]SOL 국제금커버드콜액티브		~~~SKIP!!!
# [480]RISE 글로벌리얼티인컴		~~~SKIP!!!
# [481]TIGER 글로벌AI사이버보안		~~~SKIP!!!
# [484]TIGER 200 건설		~~~SKIP!!!
# [485]KODEX 미국달러선물레버리지		~~~SKIP!!!
# [486]하나 블룸버그 -2X 천연가스 선물 ETN(H)		~~~SKIP!!!
# [488]RISE 미국30년국채액티브		~~~SKIP!!!
# [491]PLUS 코리아밸류업		~~~SKIP!!!
# [492]KODEX 일본부동산리츠(H)		~~~SKIP!!!
# [493]메리츠 3X 레버리지 미국채10년 ETN		~~~SKIP!!!
# [494]메리츠 블룸버그 -2X 천연가스 선물 ETN(H)		~~~SKIP!!!
# [495]삼성 인버스 2X 나스닥 100 TR ETN		~~~SKIP!!!
# [496]RISE 코리아금융고배당		~~~SKIP!!!
# [497]KODEX 미국부동산리츠(H)		~~~SKIP!!!
# [498]미래에셋 천연가스 선물 ETN B		~~~SKIP!!!
# [499]SOL 반도체전공정		~~~SKIP!!!
# [500]KODEX 인도타타그룹		~~~SKIP!!!
# [501]SOL KIS단기통안채		~~~SKIP!!!
# [503]대신 S&amp;P 인버스 2X 천연가스 선물 ETN		~~~SKIP!!!
# [505]RISE 미국AI테크액티브		~~~SKIP!!!
# [507]한투 레버리지 천연가스 선물 ETN B		~~~SKIP!!!
# [508]세방우		~~~SKIP!!!
# [509]키움 레버리지 반도체TOP10 ETN		~~~SKIP!!!
# [510]KODEX 한국대만IT프리미어		~~~SKIP!!!
# [511]N2 월간 레버리지 코스피 200 선물 ETN		~~~SKIP!!!
# [512]KODEX 미국S&amp;P500테크놀로지		~~~SKIP!!!
# [514]KODEX 구리선물(H)		~~~SKIP!!!
# [516]KoAct 배당성장액티브		~~~SKIP!!!
# [517]HANARO 32-10 국고채액티브		~~~SKIP!!!
# [518]하나 레버리지 코스닥150 선물 ETN		~~~SKIP!!!
# [520]SOL 미국배당다우존스2호		~~~SKIP!!!
# [521]KODEX 보험		~~~SKIP!!!
# [523]한투 레버리지 코스닥150선물 ETN		~~~SKIP!!!
# [524]미래에셋 레버리지 미국 방위산업 TOP3 ETN		~~~SKIP!!!
# [525]두산퓨얼셀2우B		~~~SKIP!!!
# [526]KIWOOM 국고채10년레버리지		~~~SKIP!!!
# [527]PLUS 미국나스닥테크		~~~SKIP!!!
# [528]PLUS 미국단기회사채(AAA~A)		~~~SKIP!!!
# [530]삼성 레버리지 코스닥150 선물 ETN		~~~SKIP!!!
# [531]PLUS 미국장기우량회사채		~~~SKIP!!!
# [532]메리츠 KAP 통안채 6개월 ETN		~~~SKIP!!!
# [533]WON 미국우주항공방산		~~~SKIP!!!
# [534]삼성 iSelect 레버리지 조선 TOP10 TR ETN		~~~SKIP!!!
# [536]KB 레버리지 금 선물 ETN(H)		~~~SKIP!!!
# [537]호텔신라우		~~~SKIP!!!
# [538]SUN&amp;L		~~~SKIP!!!
# [539]KODEX 200롱코스닥150숏선물		~~~SKIP!!!
# [540]WON 미국빌리어네어		~~~SKIP!!!
# [541]삼성 코스닥 150 TR ETN		~~~SKIP!!!
# [542]HANARO 전력설비투자		~~~SKIP!!!
# [543]TIMEFOLIO K신재생에너지액티브		~~~SKIP!!!
# [544]KIWOOM 독일DAX		~~~SKIP!!!
# [545]KODEX 차이나AI테크액티브		~~~SKIP!!!
# [546]키움 INDXX 미국테크탑10 ETN		~~~SKIP!!!
# [547]HANARO 코리아밸류업		~~~SKIP!!!
# [549]TIGER 코스닥150바이오테크		~~~SKIP!!!
# [550]신한 레버리지 미국달러 선물 ETN		~~~SKIP!!!
# [551]미래에셋 인버스 2X 옥수수 선물 ETN		~~~SKIP!!!
# [552]1Q 미국나스닥100		~~~SKIP!!!
# [553]KODEX 3대농산물선물(H)		~~~SKIP!!!
# [554]TIGER 200 금융		~~~SKIP!!!
# [555]KODEX TDF2060액티브		~~~SKIP!!!
# [556]솔루스첨단소재1우		~~~SKIP!!!
# [557]한투 레버리지 베트남 VN30 선물 ETN(H)		~~~SKIP!!!
# [558]KODEX 일본TOPIX100		~~~SKIP!!!
# [559]미래에셋 레버리지 은 선물 ETN B		~~~SKIP!!!
# [560]SOL 전고체배터리&amp;실리콘음극재		~~~SKIP!!!
# [561]TIGER 200IT레버리지		~~~SKIP!!!
# [562]메리츠 KAP 레버리지 일본 엔화 ETN		~~~SKIP!!!
# [563]미래에셋 인버스 2X 코스피200 선물 ETN		~~~SKIP!!!
# [565]KIWOOM 국고채3년		~~~SKIP!!!
# [566]KIWOOM 미국S&amp;P500(H)		~~~SKIP!!!
# [567]RISE AI반도체TOP10		~~~SKIP!!!
# [570]TIGER 글로벌클라우드컴퓨팅INDXX		~~~SKIP!!!
# [571]TIGER 코리아배당다우존스위클리커버드콜		~~~SKIP!!!
# [572]RISE 미국반도체NYSE(H)		~~~SKIP!!!
# [573]TIGER 모멘텀		~~~SKIP!!!
# [574]TIGER 인도니프티50레버리지(합성)		~~~SKIP!!!
# [575]N2 코스피 200 TR ETN		~~~SKIP!!!
# [576]KODEX 미국테크TOP3플러스		~~~SKIP!!!
# [577]ACE 미국10년국채액티브		~~~SKIP!!!
# [578]메리츠 인버스 2X 대표 농산물 선물 ETN(H)		~~~SKIP!!!
# [579]RISE 내수주플러스		~~~SKIP!!!
# [580]하나 레버리지 K방산TOP10 ETN		~~~SKIP!!!
# [581]PLUS 미국S&amp;P500성장주		~~~SKIP!!!
# [582]KODEX IT		~~~SKIP!!!
# [583]삼성 코리아 밸류업 TR ETN		~~~SKIP!!!
# [584]DAISHIN343 AI반도체&amp;인프라액티브		~~~SKIP!!!
# [585]RISE 게임테마		~~~SKIP!!!
# [586]RISE 글로벌테크놀로지(합성 H)		~~~SKIP!!!
# [587]마이티 다이나믹퀀트액티브		~~~SKIP!!!
# [588]KODEX 탄소효율그린뉴딜		~~~SKIP!!!
# [589]KODEX 33-06 국고채액티브		~~~SKIP!!!
# [590]ACE 일본TOPIX레버리지(H)		~~~SKIP!!!
# [591]KODEX 유럽탄소배출권선물ICE(H)		~~~SKIP!!!
# [592]KB 일본 컨슈머 TOP 10 ETN		~~~SKIP!!!
# [593]RISE 200선물레버리지		~~~SKIP!!!
# [595]SOL 미국AI반도체칩메이커		~~~SKIP!!!
# [596]TBH글로벌		~~~SKIP!!!
# [597]메리츠 레버리지 국채30년 ETN		~~~SKIP!!!
# [598]한투 레버리지 나스닥100 ETN B		~~~SKIP!!!
# [599]TIGER 차이나AI소프트웨어		~~~SKIP!!!
# [600]KODEX 미국S&amp;P500에너지(합성)		~~~SKIP!!!
# [601]ACE BYD밸류체인액티브		~~~SKIP!!!
# [602]한투 블룸버그인버스2XWTI원유선물 ETN B		~~~SKIP!!!
# [603]TIMEFOLIO 코리아밸류업액티브		~~~SKIP!!!
# [604]TIGER 유로스탁스배당30		~~~SKIP!!!
# [605]PLUS 코스피50		~~~SKIP!!!
# [606]ACE 구글밸류체인액티브		~~~SKIP!!!
# [607]SOL 코스닥150		~~~SKIP!!!
# [608]KODEX KRX300		~~~SKIP!!!
# [609]KIWOOM 글로벌AI반도체		~~~SKIP!!!
# [610]KODEX 미국금융테크액티브		~~~SKIP!!!
# [611]미래에셋 미국 제약 TOP3 ETN		~~~SKIP!!!
# [612]한투 인버스2X일본니케이225선물 ETN(H)		~~~SKIP!!!
# [613]메리츠 레버리지 미국채30년 스트립 ETN(H)		~~~SKIP!!!
# [615]KIWOOM 한국고배당&amp;미국AI테크		~~~SKIP!!!
# [616]미래에셋 2X 미국 자율주행대표기업 ETN		~~~SKIP!!!
# [617]삼성 레버리지 일본니케이225선물 ETN(H)		~~~SKIP!!!
# [618]TIGER AI코리아그로스액티브		~~~SKIP!!!
# [619]미래에셋 -2X 미국채울트라30년 선물 ETN		~~~SKIP!!!
# [620]대한항공우		~~~SKIP!!!
# [623]KODEX 에너지화학		~~~SKIP!!!
# [624]코오롱우		~~~SKIP!!!
# [625]키움 인버스 미국달러선물 ETN		~~~SKIP!!!
# [626]ACE 미국하이일드액티브(H)		~~~SKIP!!!
# [627]메리츠 미국채10년 ETN(H)		~~~SKIP!!!
# [628]KB 레버리지 항셍테크 선물 ETN(H) B		~~~SKIP!!!
# [629]하나 인버스 2X 옥수수 선물 ETN(H)		~~~SKIP!!!
# [630]KODEX 미국나스닥100선물인버스(H)		~~~SKIP!!!
# [631]KODEX 글로벌로봇(합성)		~~~SKIP!!!
# [632]ACE 코스닥150		~~~SKIP!!!
# [633]RISE 미국단기투자등급회사채액티브		~~~SKIP!!!
# [634]PLUS 200TR		~~~SKIP!!!
# [635]KODEX 철강		~~~SKIP!!!
# [636]미래에셋 인버스 2X 원유선물혼합 ETN(H)		~~~SKIP!!!
# [639]RISE 중장기국공채액티브		~~~SKIP!!!
# [640]KoAct 미국천연가스인프라액티브		~~~SKIP!!!
# [641]KODEX 차이나A50		~~~SKIP!!!
# [642]ACE ESG액티브		~~~SKIP!!!
# [643]메리츠 인플레이션 국채 ETN		~~~SKIP!!!
# [644]롯데지주우		~~~SKIP!!!
# [645]TIGER 글로벌이노베이션액티브		~~~SKIP!!!
# [646]KB 레버리지 KOSPI 200 선물 ETN		~~~SKIP!!!
# [647]KODEX 미국S&amp;P500액티브		~~~SKIP!!!
# [648]KB 차이나 중형주 CSI 500 ETN		~~~SKIP!!!
# [649]KB 차이나 대형주 CSI 300 ETN		~~~SKIP!!!
# [650]한투 금 선물 ETN		~~~SKIP!!!
# [651]KODEX iShares미국투자등급회사채액티브		~~~SKIP!!!
# [652]미래에셋 S&amp;P500 VIX S/T 선물 ETN(H)		~~~SKIP!!!
# [653]대교우B		~~~SKIP!!!
# [654]KB 인도 디지털 Select 5 ETN		~~~SKIP!!!
# [655]HK 200		~~~SKIP!!!
# [656]미래에셋 코스피200 선물 ETN		~~~SKIP!!!
# [657]KODEX 차이나과창판STAR50(합성)		~~~SKIP!!!
# [658]PLUS KOFR금리		~~~SKIP!!!
# [659]TIGER 미국나스닥100ETF선물		~~~SKIP!!!
# [660]TIGER S&amp;P글로벌헬스케어(합성)		~~~SKIP!!!
# [662]N2 레버리지 코스닥150 선물 ETN		~~~SKIP!!!
# [663]메리츠 솔랙티브 2X WTI원유 선물 ETN(H)		~~~SKIP!!!
# [665]TIGER 200커버드콜		~~~SKIP!!!
# [667]KB S&amp;P 레버리지 WTI원유 선물 ETN B		~~~SKIP!!!
# [668]신한 콩 선물 ETN(H)		~~~SKIP!!!
# [669]한투 FTSE100 ETN		~~~SKIP!!!
# [670]신한 블룸버그 레버리지 WTI원유선물 ETN B		~~~SKIP!!!
# [671]N2 미국달러 SOFR금리 플러스 ETN		~~~SKIP!!!
# [672]KODEX 인도Nifty50레버리지(합성)		~~~SKIP!!!
# [673]삼성 블룸버그 레버리지 WTI원유선물 ETN B		~~~SKIP!!!
# [674]하나 S&amp;P 레버리지 WTI원유 선물 ETN B		~~~SKIP!!!
# [675]TIGER 미국방산TOP10		~~~SKIP!!!
# [676]녹십자홀딩스2우		~~~SKIP!!!
# [677]PLUS 글로벌희토류&amp;전략자원생산기업		~~~SKIP!!!
# [679]KIWOOM 팔란티어미국30년국채혼합액티브(H)		~~~SKIP!!!
# [680]대상우		~~~SKIP!!!
# [681]KODEX KRX300레버리지		~~~SKIP!!!
# [682]KODEX 테슬라밸류체인FactSet		~~~SKIP!!!
# [683]BNK 주주가치액티브		~~~SKIP!!!
# [684]KCGI 미국S&amp;P500 TOP10		~~~SKIP!!!
# [685]KIWOOM 미국성장기업30액티브		~~~SKIP!!!
# [686]한투 인버스일본니케이225선물 ETN(H)		~~~SKIP!!!
# [687]KODEX 게임산업		~~~SKIP!!!
# [688]ACE 일본Nikkei225(H)		~~~SKIP!!!
# [690]TIGER 미국AI반도체팹리스		~~~SKIP!!!
# [691]TIGER 미국달러선물인버스2X		~~~SKIP!!!
# [693]PLUS 선진국MSCI(합성 H)		~~~SKIP!!!
# [694]PLUS 미국S&amp;P500		~~~SKIP!!!
# [696]ACE 미국달러단기채권액티브		~~~SKIP!!!
# [697]RISE 삼성그룹Top3채권혼합		~~~SKIP!!!
# [698]PLUS 글로벌휴머노이드로봇액티브		~~~SKIP!!!
# [699]하나 인버스 2X 천연가스 선물 ETN(H)		~~~SKIP!!!
# [700]메리츠 -2X 천연가스 선물 ETN(H)		~~~SKIP!!!
# [701]HANARO 글로벌피지컬AI액티브		~~~SKIP!!!
# [702]KB 인버스 2X 밀 선물 ETN		~~~SKIP!!!
# [704]신한 33-12 국고채 플러스 ETN		~~~SKIP!!!
# [705]미래에셋 1.5X 천연가스 선물 ETN		~~~SKIP!!!
# [706]RISE 차이나HSCEI(H)		~~~SKIP!!!
# [709]메리츠 국채10년 ETN		~~~SKIP!!!
# [710]SOL 국고채3년		~~~SKIP!!!
# [711]PLUS 국채선물3년		~~~SKIP!!!
# [712]넥센타이어1우B		~~~SKIP!!!
# [713]ACE 미국10년국채액티브(H)		~~~SKIP!!!
# [714]KB 인도 대형 성장주 Select 5 ETN		~~~SKIP!!!
# [715]KODEX WTI원유선물인버스(H)		~~~SKIP!!!
# [716]ACE 마이크로소프트밸류체인액티브		~~~SKIP!!!
# [717]신한 2X 26-05 공사채(AAA) ETN		~~~SKIP!!!
# [718]신한 2X 26-05 은행채(AAA) ETN		~~~SKIP!!!
# [719]신한 금 선물 ETN		~~~SKIP!!!
# [720]신한 26-05 공사채(AAA) ETN		~~~SKIP!!!
# [721]신한 26-05 은행채(AAA) ETN		~~~SKIP!!!
# [722]신한 인버스 옥수수 선물 ETN(H)		~~~SKIP!!!
# [723]삼성 인버스 2X 구리 선물 ETN(H)		~~~SKIP!!!
# [724]신한 레버리지 구리 선물 ETN		~~~SKIP!!!
# [725]한투 레버리지 유로스탁스50 ETN(H) B		~~~SKIP!!!
# [726]메리츠 인버스 국채3년 ETN		~~~SKIP!!!
# [727]KODEX 53-09 국고채액티브		~~~SKIP!!!
# [728]UNICORN SK하이닉스밸류체인액티브		~~~SKIP!!!
# [729]삼성 레버리지 미국다우존스 선물 ETN		~~~SKIP!!!
# [730]SOL 차이나육성산업액티브(합성)		~~~SKIP!!!
# [731]하나 인버스 2X K방산TOP10 ETN		~~~SKIP!!!
# [732]HANARO K고배당		~~~SKIP!!!
# [733]N2 선진국 1등주 ETN		~~~SKIP!!!
# [734]키움 코스닥 150 TR ETN		~~~SKIP!!!
# [735]KB 레버리지 은 선물 ETN(H)		~~~SKIP!!!
# [736]RISE 미국휴머노이드로봇		~~~SKIP!!!
# [737]한투 은 선물 ETN		~~~SKIP!!!
# [738]파워 코스피100		~~~SKIP!!!
# [739]N2 인버스 2X 천연가스 선물 ETN		~~~SKIP!!!
# [740]미래에셋 코스닥150 선물 ETN		~~~SKIP!!!
# [741]N2 코스닥 150 TR ETN		~~~SKIP!!!
# [742]코리아써우		~~~SKIP!!!
# [743]TIMEFOLIO 미국배당다우존스액티브		~~~SKIP!!!
# [744]ACE FTSE WGBI Korea		~~~SKIP!!!
# [745]PLUS 애플채권혼합		~~~SKIP!!!
# [746]TIGER TSMC파운드리밸류체인		~~~SKIP!!!
# [747]삼성 금 선물 ETN(H)		~~~SKIP!!!
# [748]대덕전자1우		~~~SKIP!!!
# [749]에셋플러스 차이나일등기업포커스10액티브		~~~SKIP!!!
# [750]HANARO Fn K-푸드		~~~SKIP!!!
# [751]TIGER 차이나클린에너지SOLACTIVE		~~~SKIP!!!
# [752]KODEX S&amp;P글로벌인프라(합성)		~~~SKIP!!!
# [753]한투 인버스0.5X S&amp;P500 VIX S/T선물 ETN B		~~~SKIP!!!
# [754]N2 월간 레버리지 선진국 1등주 ETN		~~~SKIP!!!
# [755]TIGER 원유선물Enhanced(H)		~~~SKIP!!!
# [756]PLUS TDF2060액티브		~~~SKIP!!!
# [757]TIGER 우선주		~~~SKIP!!!
# [758]N2 레버리지 천연가스 선물 ETN		~~~SKIP!!!
# [759]PLUS 미국다우존스고배당주(합성 H)		~~~SKIP!!!
# [760]PLUS 미국배당증가성장주데일리커버드콜		~~~SKIP!!!
# [761]하나 레버리지 콩 선물 ETN(H)		~~~SKIP!!!
# [762]한투 레버리지 구리 선물 ETN		~~~SKIP!!!
# [763]RISE 바이오TOP10액티브		~~~SKIP!!!
# [764]1Q 샤오미밸류체인액티브		~~~SKIP!!!
# [765]RISE 차이나항셍테크		~~~SKIP!!!
# [766]KB 레버리지 2차전지 TOP 10 TR ETN		~~~SKIP!!!
# [767]삼성 KRX 레버리지 2차전지 TOP10 TR ETN		~~~SKIP!!!
# [768]KODEX 코스피대형주		~~~SKIP!!!
# [769]KODEX 인도Nifty미드캡100		~~~SKIP!!!
# [770]ACE 레버리지		~~~SKIP!!!
# [771]메리츠 미국 인플레이션 국채 ETN(H)		~~~SKIP!!!
# [772]PLUS 글로벌수소&amp;차세대연료전지		~~~SKIP!!!
# [773]TIGER 200 에너지화학		~~~SKIP!!!
# [774]RISE 미국반도체NYSE		~~~SKIP!!!
# [775]HANARO 글로벌럭셔리S&amp;P(합성)		~~~SKIP!!!
# [776]PLUS 일본엔화초단기국채(합성)		~~~SKIP!!!
# [777]TIGER 코스닥150선물인버스		~~~SKIP!!!
# [778]삼성 인버스 2X 코스피200 선물 ETN		~~~SKIP!!!
# [779]삼성 은 선물 ETN(H)		~~~SKIP!!!
# [780]한진칼우		~~~SKIP!!!
# [781]RISE 글로벌수소경제		~~~SKIP!!!
# [782]RISE 차이나테크TOP10위클리타겟커버드콜		~~~SKIP!!!
# [783]LX하우시스우		~~~SKIP!!!
# [784]PLUS 미국테크TOP10레버리지(합성)		~~~SKIP!!!
# [785]넥센우		~~~SKIP!!!
# [787]TIGER 리츠부동산인프라채권		~~~SKIP!!!
# [788]하나 레버리지 천연가스 선물 ETN(H)		~~~SKIP!!!
# [789]RISE 200고배당커버드콜ATM		~~~SKIP!!!
# [790]TIGER 한중반도체(합성)		~~~SKIP!!!
# [791]ACE 미국IT인터넷S&amp;P(합성 H)		~~~SKIP!!!
# [793]하이트진로2우B		~~~SKIP!!!
# [794]메리츠 2X 천연가스 선물 ETN(H)		~~~SKIP!!!
# [795]RISE 200금융		~~~SKIP!!!
# [796]삼성 인버스 2X 미국다우존스 선물 ETN		~~~SKIP!!!
# [797]ACE 아시아TOP50S&amp;P		~~~SKIP!!!
# [798]RISE 테슬라미국채타겟커버드콜혼합(합성)		~~~SKIP!!!
# [799]RISE 글로벌주식분산액티브		~~~SKIP!!!
# [800]에셋플러스 코리아플랫폼액티브		~~~SKIP!!!
# [801]삼성 항셍테크 TR ETN(H) B		~~~SKIP!!!
# [802]KIWOOM 미국고배당&amp;AI테크		~~~SKIP!!!
# [803]PLUS 우량회사채50		~~~SKIP!!!
# [804]KODEX 필수소비재		~~~SKIP!!!
# [805]삼성 S&amp;P500 TR ETN		~~~SKIP!!!
# [806]키움 조선TOP10 ETN		~~~SKIP!!!
# [807]KODEX 자율주행액티브		~~~SKIP!!!
# [808]TIMEFOLIO 글로벌소비트렌드액티브		~~~SKIP!!!
# [809]SOL 미국S&amp;P500미국채혼합50		~~~SKIP!!!
# [810]PLUS 국고채30년액티브		~~~SKIP!!!
# [811]HANARO 코스닥150		~~~SKIP!!!
# [812]RISE 미국S&amp;P원유생산기업(합성 H)		~~~SKIP!!!
# [813]TIGER 글로벌멀티에셋TIF액티브		~~~SKIP!!!
# [814]RISE 미국고정배당우선증권		~~~SKIP!!!
# ['152550_link', '152550', '152550', '152550', '152550_h_li', '152550_g_li']
# [815]한국ANKOR유전???????
# [816]KODEX 미국S&amp;P바이오(합성)		~~~SKIP!!!
# [817]KIWOOM 코스닥150		~~~SKIP!!!
# [818]TIGER 은행		~~~SKIP!!!
# [819]KB 인버스 2X 콩 선물 ETN		~~~SKIP!!!
# [820]한투 일본종합상사TOP5 ETN		~~~SKIP!!!
# [821]HANARO Fn전기&amp;수소차		~~~SKIP!!!
# [822]RISE 채권혼합		~~~SKIP!!!
# [823]신한 인버스 콩 선물 ETN(H)		~~~SKIP!!!
# [824]ACE TDF2050액티브		~~~SKIP!!!
# [825]KB 레버리지 KOSDAQ 150 선물 ETN		~~~SKIP!!!
# [826]대한제당우		~~~SKIP!!!
# [827]TIGER 일본반도체FACTSET		~~~SKIP!!!
# [828]VITA MZ소비액티브		~~~SKIP!!!
# [829]N2 인버스 2X 코스닥150 선물 ETN		~~~SKIP!!!
# [830]RISE 미국S&amp;P배당킹		~~~SKIP!!!
# [831]ACE 중국과창판STAR50		~~~SKIP!!!
# ['204210_link', '204210', '204210', '204210', '204210_h_li', '204210_g_li']
# [832]스타에스엠리츠???????
# [833]메리츠 레버리지 구리 선물 ETN(H)		~~~SKIP!!!
# [834]ACE 미국배당퀄리티채권혼합50		~~~SKIP!!!
# [835]메리츠 인버스 2X 미국채30년 ETN(H)		~~~SKIP!!!
# [836]삼성 레버리지 구리 선물 ETN(H)		~~~SKIP!!!
# [837]ACE 러시아MSCI(합성)		~~~SKIP!!!
# [838]RISE V&amp;S셀렉트밸류채권혼합		~~~SKIP!!!
# [839]미래에셋 인버스 코스피200 선물 ETN		~~~SKIP!!!
# [840]신한 인버스 코스피 200 선물 ETN		~~~SKIP!!!
# [841]한투 플래티넘 선물 ETN		~~~SKIP!!!
# [842]KODEX 우량주		~~~SKIP!!!
# [843]N2 레버리지 구리 선물 ETN(H)		~~~SKIP!!!
# [844]TIGER 금은선물(H)		~~~SKIP!!!
# [845]KIWOOM KRX100		~~~SKIP!!!
# [846]파워 K-주주가치액티브		~~~SKIP!!!
# [847]PLUS 미국양자컴퓨팅TOP10		~~~SKIP!!!
# [848]KODEX 기계장비		~~~SKIP!!!
# [849]KIWOOM 200선물레버리지		~~~SKIP!!!
# [850]PLUS K방산소부장		~~~SKIP!!!
# [851]ACE 차이나항셍테크		~~~SKIP!!!
# [852]KODEX MSCI Korea		~~~SKIP!!!
# [853]SOL 반도체후공정		~~~SKIP!!!
# [854]ACE 2차전지&amp;친환경차액티브		~~~SKIP!!!
# [855]TIGER 리츠부동산인프라10채권혼합액티브		~~~SKIP!!!
# [856]메리츠 인버스 2X 미국채10년 ETN(H)		~~~SKIP!!!
# [857]KODEX 200exTOP		~~~SKIP!!!
# [858]KODEX 200가치저변동		~~~SKIP!!!
# [859]HANARO 200 TOP10		~~~SKIP!!!
# [860]신한 옥수수 선물 ETN(H)		~~~SKIP!!!
# [861]TIGER KEDI혁신기업ESG30		~~~SKIP!!!
# [862]RISE 5대그룹주		~~~SKIP!!!
# [863]에셋플러스 글로벌일등기업포커스10액티브		~~~SKIP!!!
# [864]ACE 멕시코MSCI(합성)		~~~SKIP!!!
# [865]신한 레버리지 Russell 2000 ETN		~~~SKIP!!!
# [866]신한 인버스 코스닥 150 선물 ETN		~~~SKIP!!!
# [867]RISE 헬스케어채권혼합		~~~SKIP!!!
# [868]하나 인버스 2X 콩 선물 ETN(H)		~~~SKIP!!!
# [869]KoAct 글로벌양자컴퓨팅액티브		~~~SKIP!!!
# [870]미래에셋 인버스 코스닥150 선물 ETN		~~~SKIP!!!
# [871]KODEX 200 중소형		~~~SKIP!!!
# [872]신한 코스피 200 TR ETN		~~~SKIP!!!
# [873]RISE 테슬라고정테크100		~~~SKIP!!!
# [874]삼성 코스피 200 TR ETN		~~~SKIP!!!
# [875]RISE 유로스탁스50(H)		~~~SKIP!!!
# [876]TRUSTON 주주가치액티브		~~~SKIP!!!
# [877]하나 반도체 ETN		~~~SKIP!!!
# [878]에셋플러스 글로벌대장장이액티브		~~~SKIP!!!
# [879]메리츠 솔랙티브 -2X WTI원유 선물 ETN(H)		~~~SKIP!!!
# [880]PLUS 일본반도체소부장		~~~SKIP!!!
# [881]미래에셋 2X 미국채울트라30년 선물 ETN		~~~SKIP!!!
# [882]한투 S&amp;P500 VIX S/T선물 ETN(H) B		~~~SKIP!!!
# [883]KODEX 한중반도체(합성)		~~~SKIP!!!
# [884]ITF 200		~~~SKIP!!!
# [885]ACE 코스피		~~~SKIP!!!
# [886]TIGER K게임		~~~SKIP!!!
# [887]TIGER 퓨처모빌리티액티브		~~~SKIP!!!
# [888]KODEX 미국ETF산업Top10 Indxx		~~~SKIP!!!
# [889]KoAct 글로벌친환경전력인프라액티브		~~~SKIP!!!
# [890]에셋플러스 코리아대장장이액티브		~~~SKIP!!!
# [891]PLUS 태양광&amp;ESS		~~~SKIP!!!
# [892]KODEX 모멘텀주		~~~SKIP!!!
# [893]한투 베트남 VN30 선물 ETN(H)		~~~SKIP!!!
# [894]TIGER 글로벌자원생산기업(합성 H)		~~~SKIP!!!
# [895]PLUS 200선물레버리지		~~~SKIP!!!
# ['140910_link', '140910', '140910', '140910', '140910_h_li', '140910_g_li']
# [896]에이리츠???????
# [897]HANARO 미국S&amp;P500		~~~SKIP!!!
# [898]RISE 중국MSCI China(H)		~~~SKIP!!!
# [899]TIGER 농산물선물Enhanced(H)		~~~SKIP!!!
# [900]솔루스첨단소재2우B		~~~SKIP!!!
# [901]TIGER 코리아테크액티브		~~~SKIP!!!
# [902]KODEX 유럽명품TOP10 STOXX		~~~SKIP!!!
# [903]1Q 차이나H(H)		~~~SKIP!!!
# [904]메리츠 인버스 미국채30년 ETN(H)		~~~SKIP!!!
# [905]RISE 배터리 리사이클링		~~~SKIP!!!
# [906]PLUS 미국테크TOP10		~~~SKIP!!!
# [907]TIGER 미국캐시카우100		~~~SKIP!!!
# [908]미래에셋 레버리지 미국 제약 TOP3 ETN		~~~SKIP!!!
# [909]미래에셋 S&amp;P 유럽탄소배출권 선물 ETN		~~~SKIP!!!
# [910]SOL 국제금		~~~SKIP!!!
# [911]KB 차이나 과창판 STAR 50 ETN		~~~SKIP!!!
# [912]KODEX 코스닥글로벌		~~~SKIP!!!
# [913]대신 인버스 2X 코스닥 150 선물 ETN		~~~SKIP!!!
# [914]KODEX 미국S&amp;P500유틸리티		~~~SKIP!!!
# [915]ITF K-AI반도체코어테크		~~~SKIP!!!
# [916]KB S&amp;P 인버스 2X WTI원유 선물 ETN B		~~~SKIP!!!
# [917]ACE 미국친환경그린테마INDXX		~~~SKIP!!!
# [918]KODEX 미국S&amp;P500필수소비재		~~~SKIP!!!
# [919]ACE 애플밸류체인액티브		~~~SKIP!!!
# [920]하나 S&amp;P 인버스 2X WTI원유 선물 ETN B		~~~SKIP!!!
# [921]메리츠 레버리지 멕시코 페소화 ETN		~~~SKIP!!!
# [922]ACE 골드선물 레버리지(합성 H)		~~~SKIP!!!
# [923]신한 블룸버그 인버스2X WTI원유선물 ETN B		~~~SKIP!!!
# [924]KB 인버스 2X KOSDAQ 150 선물 ETN		~~~SKIP!!!
# [925]삼성 나스닥 100 TR ETN		~~~SKIP!!!
# [926]한투 구리 선물 ETN		~~~SKIP!!!
# [927]TIGER 일본TOPIX(합성 H)		~~~SKIP!!!
# [928]마이티 코스피100		~~~SKIP!!!
# [929]삼양사우		~~~SKIP!!!
# [930]TRUSTON 코리아밸류업액티브		~~~SKIP!!!
# [931]RISE 200선물인버스2X		~~~SKIP!!!
# [932]KODEX 웹툰&amp;드라마		~~~SKIP!!!
# [933]PLUS 차이나AI테크TOP10		~~~SKIP!!!
# [934]PLUS 미국S&amp;P500미국채혼합50액티브		~~~SKIP!!!
# [935]NPC우		~~~SKIP!!!
# [936]RISE 국채선물10년인버스		~~~SKIP!!!
# [937]TREX 펀더멘탈 200		~~~SKIP!!!
# [938]메리츠 인버스 미국채10년 ETN(H)		~~~SKIP!!!
# [939]TIGER S&amp;P글로벌인프라(합성)		~~~SKIP!!!
# [940]ACE 글로벌브랜드TOP10블룸버그		~~~SKIP!!!
# [941]KODEX iShares미국인플레이션국채액티브		~~~SKIP!!!
# [942]미래에셋 인버스 2X 은 선물 ETN B		~~~SKIP!!!
# [943]TIGER 차이나항셍30		~~~SKIP!!!
# [944]KB 블룸버그 레버리지 천연가스 선물 ETN		~~~SKIP!!!
# [945]삼성 iSelect 조선 TOP10 TR ETN		~~~SKIP!!!
# [946]PLUS 미국로보택시		~~~SKIP!!!
# [947]에셋플러스 글로벌영에이지액티브		~~~SKIP!!!
# [948]KB 인버스 2X 나스닥 100 ETN		~~~SKIP!!!
# [949]KODEX 미국S&amp;P500경기소비재		~~~SKIP!!!
# [950]FOCUS ESG리더스		~~~SKIP!!!
# [951]JW중외제약2우B		~~~SKIP!!!
# [952]KODEX 가치주		~~~SKIP!!!
# [953]LX홀딩스1우		~~~SKIP!!!
# [954]ACE 미국중심중소형제조업		~~~SKIP!!!
# [955]한투 S&amp;P 인버스 2X 엔달러 선물 ETN(H)		~~~SKIP!!!
# [956]키움 KPOP ETN		~~~SKIP!!!
# [957]ACE 국고채3년		~~~SKIP!!!
# [958]신한 인버스 2X 다우존스지수 선물 ETN(H)		~~~SKIP!!!
# [959]RISE 국고채3년선물인버스		~~~SKIP!!!
# [960]HK 베스트일레븐액티브		~~~SKIP!!!
# [961]PLUS 미국나스닥100미국채혼합50		~~~SKIP!!!
# [962]HANARO Fn K-게임		~~~SKIP!!!
# [963]FOCUS 200		~~~SKIP!!!
# [964]메리츠 KAP 레버리지 중국 위안화 ETN		~~~SKIP!!!
# [965]TIGER 코스피대형주		~~~SKIP!!!
# [966]미래에셋 -2X 미국 AI TOP3 ETN		~~~SKIP!!!
# [967]한투 블룸버그 인도네시아 대표원자재 ETN		~~~SKIP!!!
# [968]KoAct 브로드컴밸류체인액티브		~~~SKIP!!!
# [969]RISE 국채30년레버리지(합성)		~~~SKIP!!!
# [970]삼성 인버스 2X 일본니케이225선물 ETN(H)		~~~SKIP!!!
# [971]HANARO KOFR금리액티브(합성)		~~~SKIP!!!
# [972]ACE 코리아밸류업		~~~SKIP!!!
# [973]KODEX 대만테크고배당다우존스		~~~SKIP!!!
# [974]KODEX 기후변화솔루션		~~~SKIP!!!
# [975]신한 S&amp;P 레버리지 유로 선물 ETN(H)		~~~SKIP!!!
# [976]메리츠 멕시코 페소화 ETN		~~~SKIP!!!
# [977]메리츠 인버스 국채30년 ETN		~~~SKIP!!!
# [978]KODEX 미국클린에너지나스닥		~~~SKIP!!!
# [979]KIWOOM 블루칩		~~~SKIP!!!
# [980]한투 인버스 2X 구리 선물 ETN		~~~SKIP!!!
# [981]삼성 일본니케이225선물 ETN(H)		~~~SKIP!!!
# [982]ACE 삼성그룹동일가중		~~~SKIP!!!
# [983]TIGER 이머징마켓MSCI레버리지(합성 H)		~~~SKIP!!!
# [984]KIWOOM 물가채KIS		~~~SKIP!!!
# [985]HANARO 유럽방산		~~~SKIP!!!
# [986]메리츠 국채5년 ETN		~~~SKIP!!!
# [987]미래에셋 인도네시아 Top5 ETN		~~~SKIP!!!
# [988]TIGER 탄소효율그린뉴딜		~~~SKIP!!!
# [989]RISE 엔비디아고정테크100		~~~SKIP!!!
# [990]파워 고배당저변동성		~~~SKIP!!!
# [991]KIWOOM 미국달러선물레버리지		~~~SKIP!!!
# [992]신한 S&amp;P 유로 선물 ETN(H)		~~~SKIP!!!
# [993]ACE 장기자산배분액티브		~~~SKIP!!!
# [994]메리츠 3X 레버리지 국채10년 ETN		~~~SKIP!!!
# [995]메리츠 3X 레버리지 국채5년 ETN		~~~SKIP!!!
# [996]메리츠 KAP 중국 위안화 ETN		~~~SKIP!!!
# [997]RISE TDF2040액티브		~~~SKIP!!!
# [998]KIWOOM 코스피100		~~~SKIP!!!
# [999]대상홀딩스우		~~~SKIP!!!
# [1000]RISE 미국양자컴퓨팅		~~~SKIP!!!
# [1001]KIWOOM 미국달러선물인버스2X		~~~SKIP!!!
# [1002]RISE 테슬라애플아마존채권혼합		~~~SKIP!!!
# [1003]KODEX 미국S&amp;P500커뮤니케이션		~~~SKIP!!!
# [1004]마이티 바이오시밀러&amp;CDMO액티브		~~~SKIP!!!
# [1005]ACE 차이나AI빅테크TOP2+액티브		~~~SKIP!!!
# [1006]메리츠 국채3년 ETN		~~~SKIP!!!
# [1007]SOL 한국AI소프트웨어		~~~SKIP!!!
# [1008]한투 S&amp;P 유럽탄소배출권 선물 ETN(H)		~~~SKIP!!!
# [1009]KIWOOM 미국테크100월간목표헤지액티브		~~~SKIP!!!
# [1010]메리츠 3X 레버리지 국채3년 ETN		~~~SKIP!!!
# [1011]SOL KRX300		~~~SKIP!!!
# [1012]메리츠 S&amp;P 유럽탄소배출권 선물 ETN(H)		~~~SKIP!!!
# [1013]메리츠 미국채10년 ETN		~~~SKIP!!!
# [1014]VITA 밸류알파액티브		~~~SKIP!!!
# [1015]삼성 중국 자동차 TOP5 TR ETN(H)		~~~SKIP!!!
# [1016]삼성 구리 선물 ETN(H)		~~~SKIP!!!
# [1017]TIGER KRX300		~~~SKIP!!!
# [1018]코오롱글로벌우		~~~SKIP!!!
# [1019]메리츠 솔랙티브 WTI원유 선물 ETN(H)		~~~SKIP!!!
# [1020]TIGER MKF배당귀족		~~~SKIP!!!
# [1021]RISE 미국은행TOP10		~~~SKIP!!!
# [1022]KODEX 운송		~~~SKIP!!!
# [1023]에셋플러스 인도일등기업포커스20액티브		~~~SKIP!!!
# [1024]TIGER LG그룹+펀더멘털		~~~SKIP!!!
# [1025]KODEX 혁신기술테마액티브		~~~SKIP!!!
# [1026]삼성 중국 AI 테크 TOP5 TR ETN(H)		~~~SKIP!!!
# [1027]HANARO 바이오코리아액티브		~~~SKIP!!!
# [1028]신한 코스닥 150 TR ETN		~~~SKIP!!!
# [1029]유유제약1우		~~~SKIP!!!
# [1030]삼성 블룸버그 WTI원유 선물 ETN B		~~~SKIP!!!
# [1031]RISE 미국천연가스밸류체인		~~~SKIP!!!
# [1032]RISE 코리아밸류업위클리고정커버드콜		~~~SKIP!!!
# [1033]KODEX 아시아AI반도체exChina액티브		~~~SKIP!!!
# [1034]대신 천연가스 선물 ETN(H)		~~~SKIP!!!
# [1035]메리츠 CSI 300 ETN		~~~SKIP!!!
# [1036]ACE TDF2030액티브		~~~SKIP!!!
# [1037]KB 코스닥 150 TR ETN		~~~SKIP!!!
# [1038]KB 미국채 10년 ETN		~~~SKIP!!!
# [1039]메리츠 미국채30년 ETN		~~~SKIP!!!
# [1040]메리츠 인버스 국채10년 ETN		~~~SKIP!!!
# [1041]메리츠 STAR 50 ETN		~~~SKIP!!!
# [1042]ACE 글로벌AI맞춤형반도체		~~~SKIP!!!
# [1043]KB 레버리지 미국채 10년 ETN		~~~SKIP!!!
# [1044]키움 레버리지 리츠부동산인프라 ETN		~~~SKIP!!!
# [1045]PLUS 글로벌HBM반도체		~~~SKIP!!!
# [1046]삼성 인버스 2X S&amp;P500 선물 ETN		~~~SKIP!!!
# [1047]키움 레버리지 바이오TOP10 ETN		~~~SKIP!!!
# [1048]신한 S&amp;P 인버스 유로 선물 ETN(H)		~~~SKIP!!!
# [1049]N2 레버리지 국채30년 ETN		~~~SKIP!!!
# [1050]한투 레버리지국채30년 ETN		~~~SKIP!!!
# [1051]삼성 미국다우존스 TR ETN		~~~SKIP!!!
# [1052]미래에셋 레버리지 옥수수 선물 ETN		~~~SKIP!!!
# [1053]신한 레버리지 Russell 2000 ETN B		~~~SKIP!!!
# [1054]메리츠 KAP 일본 엔화 ETN		~~~SKIP!!!
# [1055]PLUS S&amp;P글로벌인프라		~~~SKIP!!!
# [1056]RISE 중소형고배당		~~~SKIP!!!
# [1057]KIWOOM K-테크TOP10		~~~SKIP!!!
# [1058]대신 밀 선물 ETN(H)		~~~SKIP!!!
# [1059]키움 리츠부동산인프라 ETN		~~~SKIP!!!
# [1060]WON AI ESG액티브		~~~SKIP!!!
# [1061]N2 레버리지 국채10년 ETN		~~~SKIP!!!
# [1062]메리츠 인도 루피화 ETN		~~~SKIP!!!
# [1063]대덕1우		~~~SKIP!!!
# [1064]HANARO 탄소효율그린뉴딜		~~~SKIP!!!
# [1065]삼성 인버스 2X 금 선물 ETN(H)		~~~SKIP!!!
# [1066]KB 레버리지 미국채 10년 선물 ETN		~~~SKIP!!!
# [1067]한투 인버스 2X 일본 엔선물 ETN		~~~SKIP!!!
# [1068]더제이 중소형포커스액티브		~~~SKIP!!!
# [1069]메리츠 레버리지 인도 루피화 ETN		~~~SKIP!!!
# [1070]KB 미국채 30년 ETN		~~~SKIP!!!
# [1071]PLUS 고배당저변동50		~~~SKIP!!!
# [1072]메리츠 인버스 3X 일본 국채 10년 ETN		~~~SKIP!!!
# [1073]메리츠 인버스 일본 국채 10년 ETN		~~~SKIP!!!
# [1074]TIGER MSCI KOREA ESG리더스		~~~SKIP!!!
# [1075]TIMEFOLIO K이노베이션액티브		~~~SKIP!!!
# [1076]메리츠 인버스 2X 구리 선물 ETN(H)		~~~SKIP!!!
# [1077]덕성우		~~~SKIP!!!
# [1078]태양금속우		~~~SKIP!!!
# [1079]메리츠 인버스 국채5년 ETN		~~~SKIP!!!
# [1080]메리츠 KAP 인버스 2X 일본 엔화 ETN		~~~SKIP!!!
# [1081]ACE 인도시장대표BIG5그룹액티브		~~~SKIP!!!
# [1082]KODEX 미국스마트모빌리티S&amp;P		~~~SKIP!!!
# [1083]HK S&amp;P코리아로우볼		~~~SKIP!!!
# [1084]메리츠 일본 국채 10년 ETN		~~~SKIP!!!
# [1085]RISE 주식혼합		~~~SKIP!!!
# [1086]N2 인버스 레버리지 구리 선물 ETN(H)		~~~SKIP!!!
# [1238]오리엔트정공???????
# [1246]샤페론???????
# [1282]아이큐어???????
# [1289]미래에셋드림스팩1호???????
# [1383]SGC E&amp;C		~~~SKIP!!!
# [1484]SG&amp;G		~~~SKIP!!!
# [1518]THE CUBE&amp;		~~~SKIP!!!
# [1633]삼성스팩8호???????
# [1649]파인메딕스???????
# [1667]백금T&amp;A		~~~SKIP!!!
# [1685]세림B&amp;G		~~~SKIP!!!
# [1776]신한제11호스팩???????
# [1793]소프트캠프???????
# [1894]THE E&amp;M		~~~SKIP!!!
# [1902]엔에이치스팩29호???????
# [1908]형지I&amp;C		~~~SKIP!!!
# [1920]S&amp;K폴리텍		~~~SKIP!!!
# [1941]KB제27호스팩???????
# [1981]대산F&amp;B		~~~SKIP!!!
# [2007]유안타제13호스팩???????
# [2022]엔에이치스팩30호???????
# [2033]대신밸런스제18호스팩???????
# [2043]미래에셋비전스팩4호???????
# [2044]미래에셋비전스팩7호???????
# [2046]대신밸런스제16호스팩???????
# [2047]하나28호스팩???????
# [2050]에이치엠씨제7호스팩???????
# [2051]하나30호스팩???????
# !!!!!!2053]삼성스팩10호
# [2056]유안타제15호스팩???????
# [2058]미래에셋비전스팩6호???????
# [2059]한국제15호스팩???????
# [2063]키움제11호스팩???????
# [2066]엔에이치스팩31호???????
# [2067]대신밸런스제17호스팩???????
# [2068]KB제29호스팩???????
# [2069]디비금융제13호스팩???????
# [2070]하나26호스팩???????
# !!!!!!2072]KB제32호스팩
# [2074]KB제31호스팩???????
# [2075]교보16호스팩???????
# [2077]DB금융스팩12호		~~~SKIP!!!
# !!!!!!2078]하나35호스팩
# [2079]대신밸런스제19호스팩???????
# [2080]하나27호스팩???????
# [2082]신한제12호스팩???????
# [2083]신한제14호스팩???????
# [2084]하나31호스팩???????
# [2087]미래에셋비전스팩5호???????
# [2088]하나29호스팩???????
# [2089]신한제16호스팩???????
# [2090]유안타제16호스팩???????
# [2091]유안타제12호스팩???????
# [2092]IBKS제22호스팩???????
# [2093]유안타제11호스팩???????
# [2094]해성산업1우		~~~SKIP!!!
# [2095]KB제30호스팩???????
# [2096]상상인제4호스팩???????
# !!!!!!2097]디비금융제14호스팩
# [2097]디비금융제14호스팩???????
# [2098]유안타제17호스팩???????
# [2099]교보17호스팩???????
# [2100]하이제8호스팩???????
# [2101]한화플러스제4호스팩???????
# [2102]에스케이증권제9호스팩		~~~SKIP!!!
# [2103]미래에셋비전스팩3호???????
# !!!!!!2104]교보18호스팩
# [2104]교보18호스팩???????
# [2105]신영스팩10호???????
# [2106]이베스트스팩6호???????
# 메일 전송 완료 ✅
# ##################################
# ############## Done ##############
# ##################################
#
# 프로그램이 종료되었습니다.
# 26 분 44 초 (1604.25152 sec) 소요
